# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.9.11-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-0.9.11

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from PIL import Image
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

import json
import pathlib

import timm
import tqdm
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import ImageFolder
import torchvision
import random

# %% [markdown]
# ## SUPERVISED LEARNING ON 20% OF THE DATASET

# %%
torch.manual_seed(0)

# %%
path_dataset_train = pathlib.Path("/content/gdrive/MyDrive/imagenette2-320/train")
path_dataset_val = pathlib.Path("/content/gdrive/MyDrive/imagenette2-320/val")
path_labels = pathlib.Path("/content/gdrive/MyDrive/imagenette2-320/imagenette_labels.json")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

n_workers = 2

# Data related
with path_labels.open("r") as f:
    label_mapping = json.load(f)

transform_plain = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
        transforms.Resize((224, 224),antialias=True),
    ]
)
dataset_train_plain = ImageFolder(path_dataset_train, transform=transform_plain)
dataset_val_plain = ImageFolder(path_dataset_val, transform=transform_plain)

if dataset_train_plain.classes != dataset_val_plain.classes:
    raise ValueError("Inconsistent classes")

batch_size = 256
data_loader_train_plain = DataLoader(dataset_train_plain,batch_size=256, shuffle = True,drop_last=False,num_workers=n_workers,)
data_loader_val_plain = DataLoader(dataset_val_plain,batch_size=batch_size,drop_last=False,num_workers=n_workers,shuffle = True)
data_loader_val_plain_subset = DataLoader(dataset_val_plain,batch_size=batch_size,drop_last=False,sampler=SubsetRandomSampler(list(range(0, len(dataset_val_plain), 50))),num_workers=n_workers,)

# %%
dataset_val_plain
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3925
#     Root location: /content/gdrive/MyDrive/imagenette2-320/val
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#            )

# %%
class resnet(nn.Module):

    def __init__(self,num_classes,pretrained = False):

        super(resnet, self).__init__()
        self.num_classes = num_classes
        if pretrained :
          self.encoder = torchvision.models.resnet18(weights = "DEFAULT")
        else:
          self.encoder = torchvision.models.resnet18()
        self.activation = nn.ReLU()
        self.classifier = nn.Linear(1000,num_classes)

    def forward(self, x):

        x = self.encoder(x)
        x =  self.activation(x)
        x = self.classifier(x)

        return x
class vit_base(nn.Module):

  def __init__(self,num_classes,pretrained = False):

      super(resnet, self).__init__()
      self.num_classes = num_classes

      self.encoder = timm.create_model('vit_base_patch16_224', pretrained=pretrained)

      self.activation = nn.ReLU()
      self.classifier = nn.Linear(1000,num_classes)

  def forward(self, x):

      x = self.encoder(x)
      x =  self.activation(x)
      x = self.classifier(x)

      return x

# %%
# Splitting dataset
n_train = len(dataset_train_plain)
indices = list(range(n_train))
random.shuffle(indices)

split = int(np.floor(0.2 * n_train))
train_indices, _ = indices[:split], indices[split:]

n_test = len(dataset_val_plain)
indices = list(range(n_test))
random.shuffle(indices)

split = int(np.floor(0.2 * n_test))
test_indices, _ = indices[:split], indices[split:]

train_supervised_sampler = SubsetRandomSampler(train_indices)
test_supervised_sampler = SubsetRandomSampler(test_indices)

data_loader_train_supervised = DataLoader(dataset_train_plain, batch_size=128,sampler=train_supervised_sampler, num_workers=n_workers)
data_loader_test_supervised = DataLoader(dataset_val_plain, batch_size=128,sampler=test_supervised_sampler, num_workers=n_workers)

# %%
print(f'Size of Training Dataset :{len(data_loader_train_supervised)*128}')
print(f'Size of Validation Dataset :{len(data_loader_test_supervised)*128}')
# Out:
# Size of Training Dataset :1920
# Size of Validation Dataset :896

# %%
# Create a model for supervised learning
supervised_model = resnet(num_classes = 10,pretrained = False)
supervised_model = supervised_model.to(device)

optimizer_supervised = torch.optim.Adam(supervised_model.parameters(), lr= 0.001)
criterion = torch.nn.CrossEntropyLoss()

# %%
def test_model_accuracy(test_loader, model, criterion):
    correct_predictions = 0
    total_samples = 0
    average_loss = 0
    model.eval()


    with torch.no_grad():
        for idx, (img, label) in enumerate(test_loader):
            img = img.to(device)
            label = label.to(device)


            output = model(img)
            loss = criterion(output, label)
            average_loss += loss.item()

            # Calculate the accuracy
            _, predicted_labels = output.max(1)
            correct_predictions += (predicted_labels == label).sum().item()

            total_samples += label.size(0)

    test_accuracy = correct_predictions / total_samples
    average_loss /= len(test_loader)
    print(f'Test Accuracy: {test_accuracy:.4f}')
    print(f'Average Test Loss : {average_loss:.4f}')
    return test_accuracy,average_loss

def train(train_loader,val_loader,model,optimizer,criterion,num_epochs):

    training_loss = []
    training_accuracy = []
    testing_accuracy =[]
    testing_loss = []
    for i in range(num_epochs):
        running_loss = 0
        correct_predictions = 0
        model.train()
        for idx, (img,label) in enumerate(train_loader):

            # label = torch.tensor(label)
            bsz = label.shape[0]
            optimizer.zero_grad()
            img = img.to(device)
            label = label.to(device)
            prediction = model(img)

            # Calculate the loss
            loss = criterion(prediction, label)
            running_loss += loss.item()

            # Calculate the accuracy
            _, predicted_labels = prediction.max(1)
            curr_predicted_labels = (predicted_labels == label).sum().item()
            correct_predictions += curr_predicted_labels

            loss.backward()
            optimizer.step()

            if idx%5 == 0:
                print(f"idx : {idx} , Current Loss(batch) : {loss.item()}, Correct Predictions(batch) : {curr_predicted_labels}/{bsz}")

        running_loss /= len(train_loader)
        epoch_accuracy = correct_predictions / (1893)

        print(f'Epoch: {i}, Loss (per batch) : {running_loss:.4f}, Accuracy: {epoch_accuracy:.4f}')

        training_loss.append(running_loss)
        training_accuracy.append(epoch_accuracy)

        # test_accuracy(data_loader_val_subset,model)

        t,l = test_model_accuracy(val_loader,model,criterion)
        testing_accuracy.append(t)
        testing_loss.append(l)

    return training_loss, training_accuracy,testing_accuracy,testing_loss

# %% [markdown]
# # **TRAINING RESNET FROM SCRATCH**
# TRAINING LOSS : 0.03 \\
# TRAINING ACCURACY : 99% \\
# BEST TEST ACCURACY : 70%

# %%
supervised_model = resnet(num_classes = 10,pretrained = False)
supervised_model = supervised_model.to(device)
optimizer_supervised = torch.optim.Adam(supervised_model.parameters(), lr= 0.00005,weight_decay=0.0001)
criterion = torch.nn.CrossEntropyLoss()
a1,b1,c1,d1 = train(data_loader_train_supervised,data_loader_test_supervised,supervised_model,optimizer_supervised,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.0837905406951904, Correct Predictions(batch) : 39/128
# idx : 5 , Current Loss(batch) : 1.90829598903656, Correct Predictions(batch) : 41/128
# idx : 10 , Current Loss(batch) : 1.9454395771026611, Correct Predictions(batch) : 40/128
# Epoch: 0, Loss (per batch) : 1.9312, Accuracy: 0.3170
# Test Accuracy: 0.1287
# Average Test Loss : 4.8453
# idx : 0 , Current Loss(batch) : 1.6776411533355713, Correct Predictions(batch) : 52/128
# idx : 5 , Current Loss(batch) : 1.8509056568145752, Correct Predictions(batch) : 42/128
# idx : 10 , Current Loss(batch) : 1.7008922100067139, Correct Predictions(batch) : 53/128
# Epoch: 1, Loss (per batch) : 1.7340, Accuracy: 0.3941
# Test Accuracy: 0.2599
# Average Test Loss : 2.2175
# idx : 0 , Current Loss(batch) : 1.5756869316101074, Correct Predictions(batch) : 61/128
# idx : 5 , Current Loss(batch) : 1.5255651473999023, Correct Predictions(batch) : 54/128
# idx : 10 , Current Loss(batch) : 1.4662233591079712, Correct Predictions(batch) : 66/128
# Epoch: 2, Loss (per batch) : 1.5457, Accuracy: 0.4696
# Test Accuracy: 0.3338
# Average Test Loss : 2.0663
# idx : 0 , Current Loss(batch) : 1.3946048021316528, Correct Predictions(batch) : 66/128
# idx : 5 , Current Loss(batch) : 1.5746268033981323, Correct Predictions(batch) : 63/128
# idx : 10 , Current Loss(batch) : 1.5664546489715576, Correct Predictions(batch) : 54/128
# Epoch: 3, Loss (per batch) : 1.4591, Accuracy: 0.4881
# Test Accuracy: 0.4331
# Average Test Loss : 1.7146
# idx : 0 , Current Loss(batch) : 1.5415809154510498, Correct Predictions(batch) : 54/128
# idx : 5 , Current Loss(batch) : 1.3490909337997437, Correct Predictions(batch) : 72/128
# idx : 10 , Current Loss(batch) : 1.2781636714935303, Correct Predictions(batch) : 66/128
# Epoch: 4, Loss (per batch) : 1.4004, Accuracy: 0.5077
# Test Accuracy: 0.3720
# Average Test Loss : 2.1312
# idx : 0 , Current Loss(batch) : 1.4941978454589844, Correct Predictions(batch) : 59/128
# idx : 5 , Current Loss(batch) : 1.3770607709884644, Correct Predictions(batch) : 67/128
# idx : 10 , Current Loss(batch) : 1.3519110679626465, Correct Predictions(batch) : 71/128
# Epoch: 5, Loss (per batch) : 1.3455, Accuracy: 0.5288
# Test Accuracy: 0.4051
# Average Test Loss : 1.7979
# idx : 0 , Current Loss(batch) : 1.1125627756118774, Correct Predictions(batch) : 81/128
# idx : 5 , Current Loss(batch) : 1.2799711227416992, Correct Predictions(batch) : 73/128
# idx : 10 , Current Loss(batch) : 1.2045371532440186, Correct Predictions(batch) : 70/128
# Epoch: 6, Loss (per batch) : 1.2100, Accuracy: 0.5800
# Test Accuracy: 0.3389
# Average Test Loss : 2.3436
# idx : 0 , Current Loss(batch) : 1.0706111192703247, Correct Predictions(batch) : 80/128
# idx : 5 , Current Loss(batch) : 1.1563347578048706, Correct Predictions(batch) : 78/128
# idx : 10 , Current Loss(batch) : 1.1298490762710571, Correct Predictions(batch) : 78/128
# Epoch: 7, Loss (per batch) : 1.1612, Accuracy: 0.6101
# Test Accuracy: 0.4522
# Average Test Loss : 1.7855
# idx : 0 , Current Loss(batch) : 1.2114070653915405, Correct Predictions(batch) : 75/128
# idx : 5 , Current Loss(batch) : 1.1576894521713257, Correct Predictions(batch) : 79/128
# idx : 10 , Current Loss(batch) : 0.9716202020645142, Correct Predictions(batch) : 87/128
# Epoch: 8, Loss (per batch) : 1.0786, Accuracy: 0.6403
# Test Accuracy: 0.4204
# Average Test Loss : 2.8886
# idx : 0 , Current Loss(batch) : 0.9384439587593079, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 1.0605851411819458, Correct Predictions(batch) : 75/128
# idx : 10 , Current Loss(batch) : 1.0348594188690186, Correct Predictions(batch) : 82/128
# Epoch: 9, Loss (per batch) : 0.9901, Accuracy: 0.6667
# Test Accuracy: 0.5363
# Average Test Loss : 1.5314
# idx : 0 , Current Loss(batch) : 0.784954845905304, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 1.0017457008361816, Correct Predictions(batch) : 80/128
# idx : 10 , Current Loss(batch) : 0.749374270439148, Correct Predictions(batch) : 94/128
# Epoch: 10, Loss (per batch) : 0.8775, Accuracy: 0.7058
# Test Accuracy: 0.5809
# Average Test Loss : 1.2722
# idx : 0 , Current Loss(batch) : 0.7570728063583374, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 0.8765528798103333, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 0.9150700569152832, Correct Predictions(batch) : 93/128
# Epoch: 11, Loss (per batch) : 0.8359, Accuracy: 0.7285
# Test Accuracy: 0.4395
# Average Test Loss : 2.2995
# idx : 0 , Current Loss(batch) : 0.673957347869873, Correct Predictions(batch) : 102/128
# idx : 5 , Current Loss(batch) : 0.7994346618652344, Correct Predictions(batch) : 90/128
# idx : 10 , Current Loss(batch) : 0.7876575589179993, Correct Predictions(batch) : 92/128
# Epoch: 12, Loss (per batch) : 0.7738, Accuracy: 0.7417
# Test Accuracy: 0.3822
# Average Test Loss : 3.6185
# idx : 0 , Current Loss(batch) : 1.027651309967041, Correct Predictions(batch) : 88/128
# idx : 5 , Current Loss(batch) : 0.785715639591217, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 0.8748266696929932, Correct Predictions(batch) : 92/128
# Epoch: 13, Loss (per batch) : 0.7628, Accuracy: 0.7522
# Test Accuracy: 0.4994
# Average Test Loss : 1.6104
# idx : 0 , Current Loss(batch) : 0.5835570693016052, Correct Predictions(batch) : 107/128
# idx : 5 , Current Loss(batch) : 0.5126155018806458, Correct Predictions(batch) : 107/128
# idx : 10 , Current Loss(batch) : 0.5988234281539917, Correct Predictions(batch) : 101/128
# Epoch: 14, Loss (per batch) : 0.6846, Accuracy: 0.7797
# Test Accuracy: 0.4828
# Average Test Loss : 1.7900
# idx : 0 , Current Loss(batch) : 0.4738915264606476, Correct Predictions(batch) : 105/128
# idx : 5 , Current Loss(batch) : 0.5813809037208557, Correct Predictions(batch) : 103/128
# idx : 10 , Current Loss(batch) : 0.6036157011985779, Correct Predictions(batch) : 102/128
# Epoch: 15, Loss (per batch) : 0.6043, Accuracy: 0.7929
# Test Accuracy: 0.4981
# Average Test Loss : 1.7734
# idx : 0 , Current Loss(batch) : 0.39174747467041016, Correct Predictions(batch) : 115/128
# idx : 5 , Current Loss(batch) : 0.4708567261695862, Correct Predictions(batch) : 107/128
# idx : 10 , Current Loss(batch) : 0.7573872208595276, Correct Predictions(batch) : 92/128
# Epoch: 16, Loss (per batch) : 0.5132, Accuracy: 0.8230
# Test Accuracy: 0.5172
# Average Test Loss : 2.3919
# idx : 0 , Current Loss(batch) : 0.5023577809333801, Correct Predictions(batch) : 102/128
# idx : 5 , Current Loss(batch) : 0.6104941964149475, Correct Predictions(batch) : 99/128
# idx : 10 , Current Loss(batch) : 0.6119533777236938, Correct Predictions(batch) : 97/128
# Epoch: 17, Loss (per batch) : 0.5256, Accuracy: 0.8220
# Test Accuracy: 0.4701
# Average Test Loss : 2.6259
# idx : 0 , Current Loss(batch) : 0.4028662443161011, Correct Predictions(batch) : 111/128
# idx : 5 , Current Loss(batch) : 0.43476924300193787, Correct Predictions(batch) : 111/128
# idx : 10 , Current Loss(batch) : 0.5841366648674011, Correct Predictions(batch) : 106/128
# Epoch: 18, Loss (per batch) : 0.4601, Accuracy: 0.8516
# Test Accuracy: 0.5529
# Average Test Loss : 1.6576
# idx : 0 , Current Loss(batch) : 0.3337397575378418, Correct Predictions(batch) : 116/128
# idx : 5 , Current Loss(batch) : 0.40432506799697876, Correct Predictions(batch) : 108/128
# idx : 10 , Current Loss(batch) : 0.5253493189811707, Correct Predictions(batch) : 108/128
# Epoch: 19, Loss (per batch) : 0.3468, Accuracy: 0.8901
# Test Accuracy: 0.5389
# Average Test Loss : 2.1115
# idx : 0 , Current Loss(batch) : 0.29058748483657837, Correct Predictions(batch) : 118/128
# idx : 5 , Current Loss(batch) : 0.23108811676502228, Correct Predictions(batch) : 116/128
# idx : 10 , Current Loss(batch) : 0.42219066619873047, Correct Predictions(batch) : 109/128
# Epoch: 20, Loss (per batch) : 0.3335, Accuracy: 0.8817
# Test Accuracy: 0.5108
# Average Test Loss : 2.7166
# idx : 0 , Current Loss(batch) : 0.4195936918258667, Correct Predictions(batch) : 109/128
# idx : 5 , Current Loss(batch) : 0.30499783158302307, Correct Predictions(batch) : 115/128
# idx : 10 , Current Loss(batch) : 0.37254202365875244, Correct Predictions(batch) : 117/128
# Epoch: 21, Loss (per batch) : 0.3799, Accuracy: 0.8690
# Test Accuracy: 0.5541
# Average Test Loss : 2.0699
# idx : 0 , Current Loss(batch) : 0.16922953724861145, Correct Predictions(batch) : 121/128
# idx : 5 , Current Loss(batch) : 0.5300301313400269, Correct Predictions(batch) : 108/128
# idx : 10 , Current Loss(batch) : 0.2984018623828888, Correct Predictions(batch) : 117/128
# Epoch: 22, Loss (per batch) : 0.3188, Accuracy: 0.8943
# Test Accuracy: 0.5618
# Average Test Loss : 1.9010
# idx : 0 , Current Loss(batch) : 0.1823810338973999, Correct Predictions(batch) : 118/128
# idx : 5 , Current Loss(batch) : 0.2178289145231247, Correct Predictions(batch) : 118/128
# idx : 10 , Current Loss(batch) : 0.3918841779232025, Correct Predictions(batch) : 112/128
# Epoch: 23, Loss (per batch) : 0.2774, Accuracy: 0.8986
# Test Accuracy: 0.5223
# Average Test Loss : 2.1121
# idx : 0 , Current Loss(batch) : 0.2765030562877655, Correct Predictions(batch) : 114/128
# idx : 5 , Current Loss(batch) : 0.25966230034828186, Correct Predictions(batch) : 113/128
# idx : 10 , Current Loss(batch) : 0.32613420486450195, Correct Predictions(batch) : 114/128
# Epoch: 24, Loss (per batch) : 0.2489, Accuracy: 0.9081
# Test Accuracy: 0.4790
# Average Test Loss : 3.8950
# idx : 0 , Current Loss(batch) : 0.38139456510543823, Correct Predictions(batch) : 112/128
# idx : 5 , Current Loss(batch) : 0.15455883741378784, Correct Predictions(batch) : 123/128
# idx : 10 , Current Loss(batch) : 0.2887797951698303, Correct Predictions(batch) : 119/128
# Epoch: 25, Loss (per batch) : 0.2010, Accuracy: 0.9366
# Test Accuracy: 0.6025
# Average Test Loss : 2.0755
# idx : 0 , Current Loss(batch) : 0.06712552905082703, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.09921620786190033, Correct Predictions(batch) : 124/128
# idx : 10 , Current Loss(batch) : 0.1404276341199875, Correct Predictions(batch) : 122/128
# Epoch: 26, Loss (per batch) : 0.1036, Accuracy: 0.9667
# Test Accuracy: 0.5962
# Average Test Loss : 1.9887
# idx : 0 , Current Loss(batch) : 0.05525039881467819, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.11276640743017197, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.07806343585252762, Correct Predictions(batch) : 122/128
# Epoch: 27, Loss (per batch) : 0.0939, Accuracy: 0.9672
# Test Accuracy: 0.6229
# Average Test Loss : 1.9343
# idx : 0 , Current Loss(batch) : 0.13266855478286743, Correct Predictions(batch) : 122/128
# idx : 5 , Current Loss(batch) : 0.15491311252117157, Correct Predictions(batch) : 122/128
# idx : 10 , Current Loss(batch) : 0.10150212794542313, Correct Predictions(batch) : 124/128
# Epoch: 28, Loss (per batch) : 0.1178, Accuracy: 0.9646
# Test Accuracy: 0.6064
# Average Test Loss : 2.1326
# idx : 0 , Current Loss(batch) : 0.07800024747848511, Correct Predictions(batch) : 124/128
# idx : 5 , Current Loss(batch) : 0.15328431129455566, Correct Predictions(batch) : 121/128
# idx : 10 , Current Loss(batch) : 0.13554002344608307, Correct Predictions(batch) : 125/128
# Epoch: 29, Loss (per batch) : 0.1343, Accuracy: 0.9562
# Test Accuracy: 0.6191
# Average Test Loss : 2.1259
# idx : 0 , Current Loss(batch) : 0.0848550796508789, Correct Predictions(batch) : 123/128
# idx : 5 , Current Loss(batch) : 0.08901648968458176, Correct Predictions(batch) : 124/128
# idx : 10 , Current Loss(batch) : 0.12508690357208252, Correct Predictions(batch) : 122/128
# Epoch: 30, Loss (per batch) : 0.1410, Accuracy: 0.9525
# Test Accuracy: 0.5376
# Average Test Loss : 2.9917
# idx : 0 , Current Loss(batch) : 0.11026553809642792, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.1306549459695816, Correct Predictions(batch) : 123/128
# idx : 10 , Current Loss(batch) : 0.06080113351345062, Correct Predictions(batch) : 124/128
# Epoch: 31, Loss (per batch) : 0.1063, Accuracy: 0.9651
# Test Accuracy: 0.5006
# Average Test Loss : 3.0696
# idx : 0 , Current Loss(batch) : 0.07310596853494644, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.11695245653390884, Correct Predictions(batch) : 120/128
# idx : 10 , Current Loss(batch) : 0.10179821401834488, Correct Predictions(batch) : 124/128
# Epoch: 32, Loss (per batch) : 0.1041, Accuracy: 0.9635
# Test Accuracy: 0.5745
# Average Test Loss : 2.4653
# idx : 0 , Current Loss(batch) : 0.08185421675443649, Correct Predictions(batch) : 124/128
# idx : 5 , Current Loss(batch) : 0.052988748997449875, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.10475461184978485, Correct Predictions(batch) : 127/128
# Epoch: 33, Loss (per batch) : 0.1165, Accuracy: 0.9604
# Test Accuracy: 0.5121
# Average Test Loss : 2.8155
# idx : 0 , Current Loss(batch) : 0.07560597360134125, Correct Predictions(batch) : 124/128
# idx : 5 , Current Loss(batch) : 0.06920715421438217, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.2311554104089737, Correct Predictions(batch) : 122/128
# Epoch: 34, Loss (per batch) : 0.1108, Accuracy: 0.9657
# Test Accuracy: 0.5287
# Average Test Loss : 2.4636
# idx : 0 , Current Loss(batch) : 0.08162045478820801, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.07859912514686584, Correct Predictions(batch) : 124/128
# idx : 10 , Current Loss(batch) : 0.09225790202617645, Correct Predictions(batch) : 124/128
# Epoch: 35, Loss (per batch) : 0.0796, Accuracy: 0.9709
# Test Accuracy: 0.6140
# Average Test Loss : 1.9340
# idx : 0 , Current Loss(batch) : 0.029139239341020584, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.03600451722741127, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.07151363044977188, Correct Predictions(batch) : 124/128
# Epoch: 36, Loss (per batch) : 0.0562, Accuracy: 0.9836
# Test Accuracy: 0.6153
# Average Test Loss : 2.4547
# idx : 0 , Current Loss(batch) : 0.044583458453416824, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.050842925906181335, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.04078243672847748, Correct Predictions(batch) : 125/128
# Epoch: 37, Loss (per batch) : 0.0614, Accuracy: 0.9789
# Test Accuracy: 0.6178
# Average Test Loss : 2.1877
# idx : 0 , Current Loss(batch) : 0.026730109006166458, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.03157537803053856, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.02555268257856369, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0294, Accuracy: 0.9926
# Test Accuracy: 0.6166
# Average Test Loss : 2.1651
# idx : 0 , Current Loss(batch) : 0.01153599377721548, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.004220021888613701, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.014315036125481129, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0239, Accuracy: 0.9926
# Test Accuracy: 0.6191
# Average Test Loss : 2.2093
# idx : 0 , Current Loss(batch) : 0.021048055961728096, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.018467675894498825, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.0074938577599823475, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0111, Accuracy: 0.9984
# Test Accuracy: 0.6586
# Average Test Loss : 1.7727
# idx : 0 , Current Loss(batch) : 0.003107865108177066, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003389375051483512, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.006895432714372873, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0055, Accuracy: 0.9995
# Test Accuracy: 0.6739
# Average Test Loss : 1.9302
# idx : 0 , Current Loss(batch) : 0.0017713053384795785, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0020362879149615765, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004797326400876045, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0032, Accuracy: 1.0000
# Test Accuracy: 0.6790
# Average Test Loss : 1.8428
# idx : 0 , Current Loss(batch) : 0.0014248898951336741, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006475038826465607, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0012513594701886177, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0016, Accuracy: 1.0000
# Test Accuracy: 0.6790
# Average Test Loss : 2.0056
# idx : 0 , Current Loss(batch) : 0.0003815982781816274, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.000699755153618753, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001075949752703309, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.6790
# Average Test Loss : 1.9444
# idx : 0 , Current Loss(batch) : 0.0003788139147218317, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0010354411788284779, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.000490908685605973, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.6854
# Average Test Loss : 1.8007
# idx : 0 , Current Loss(batch) : 0.00013653305359184742, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0005688297096639872, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0002487463934812695, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0003, Accuracy: 1.0000
# Test Accuracy: 0.6854
# Average Test Loss : 1.9679
# idx : 0 , Current Loss(batch) : 0.00019971415167674422, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.001202161656692624, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0004968802677467465, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0005, Accuracy: 1.0000
# Test Accuracy: 0.6866
# Average Test Loss : 1.8881
# idx : 0 , Current Loss(batch) : 0.000226581483730115, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00022433281992562115, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004435840994119644, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0006, Accuracy: 1.0000
# Test Accuracy: 0.7006
# Average Test Loss : 1.8205
# idx : 0 , Current Loss(batch) : 0.00021496866247616708, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00019667070591822267, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00016513392620254308, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0003, Accuracy: 1.0000
# Test Accuracy: 0.6892
# Average Test Loss : 1.8916

# %% [markdown]
# # **FINE-TUNING USING IMAGENET PRETRAINED WEIGHTS**
# TRAINING LOSS : 0.03 \\
# TRAINING ACCURACY : 100% \\
# BEST TEST ACCURACY : 96.31%

# %%
supervised_model = resnet(num_classes = 10,pretrained = True)
supervised_model = supervised_model.to(device)
optimizer_supervised = torch.optim.Adam(supervised_model.parameters(), lr= 0.00005,weight_decay=0.0001)
criterion = torch.nn.CrossEntropyLoss()
a,b,c,d = train(data_loader_train_supervised,data_loader_test_supervised,supervised_model,optimizer_supervised,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.6880009174346924, Correct Predictions(batch) : 18/128
# idx : 5 , Current Loss(batch) : 1.6161912679672241, Correct Predictions(batch) : 59/128
# idx : 10 , Current Loss(batch) : 1.0312111377716064, Correct Predictions(batch) : 94/128
# Epoch: 0, Loss (per batch) : 1.4793, Accuracy: 0.5388
# Test Accuracy: 0.8955
# Average Test Loss : 0.5593
# idx : 0 , Current Loss(batch) : 0.4932309091091156, Correct Predictions(batch) : 116/128
# idx : 5 , Current Loss(batch) : 0.30241039395332336, Correct Predictions(batch) : 123/128
# idx : 10 , Current Loss(batch) : 0.3053094744682312, Correct Predictions(batch) : 119/128
# Epoch: 1, Loss (per batch) : 0.3401, Accuracy: 0.9377
# Test Accuracy: 0.9414
# Average Test Loss : 0.2514
# idx : 0 , Current Loss(batch) : 0.1299310177564621, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.14610449969768524, Correct Predictions(batch) : 124/128
# idx : 10 , Current Loss(batch) : 0.14258304238319397, Correct Predictions(batch) : 125/128
# Epoch: 2, Loss (per batch) : 0.1353, Accuracy: 0.9799
# Test Accuracy: 0.9490
# Average Test Loss : 0.2223
# idx : 0 , Current Loss(batch) : 0.08828561753034592, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.0882522389292717, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.08114390075206757, Correct Predictions(batch) : 127/128
# Epoch: 3, Loss (per batch) : 0.0728, Accuracy: 0.9942
# Test Accuracy: 0.9529
# Average Test Loss : 0.1796
# idx : 0 , Current Loss(batch) : 0.05963192507624626, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.03407255560159683, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.03106941655278206, Correct Predictions(batch) : 128/128
# Epoch: 4, Loss (per batch) : 0.0401, Accuracy: 1.0000
# Test Accuracy: 0.9567
# Average Test Loss : 0.1968
# idx : 0 , Current Loss(batch) : 0.030764756724238396, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.028251681476831436, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.01774495095014572, Correct Predictions(batch) : 128/128
# Epoch: 5, Loss (per batch) : 0.0255, Accuracy: 1.0000
# Test Accuracy: 0.9592
# Average Test Loss : 0.1458
# idx : 0 , Current Loss(batch) : 0.018300209194421768, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.01592870056629181, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0171860009431839, Correct Predictions(batch) : 128/128
# Epoch: 6, Loss (per batch) : 0.0184, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1393
# idx : 0 , Current Loss(batch) : 0.010377111844718456, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.014722415246069431, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.010100772604346275, Correct Predictions(batch) : 128/128
# Epoch: 7, Loss (per batch) : 0.0135, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1274
# idx : 0 , Current Loss(batch) : 0.009687013924121857, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.01220398023724556, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.012030640617012978, Correct Predictions(batch) : 128/128
# Epoch: 8, Loss (per batch) : 0.0109, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1397
# idx : 0 , Current Loss(batch) : 0.010662549175322056, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.008789011277258396, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.006794657092541456, Correct Predictions(batch) : 128/128
# Epoch: 9, Loss (per batch) : 0.0094, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1427
# idx : 0 , Current Loss(batch) : 0.008425243198871613, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.006931282114237547, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.007532793562859297, Correct Predictions(batch) : 128/128
# Epoch: 10, Loss (per batch) : 0.0077, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1734
# idx : 0 , Current Loss(batch) : 0.0075209494680166245, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.006347359158098698, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0066218008287250996, Correct Predictions(batch) : 128/128
# Epoch: 11, Loss (per batch) : 0.0065, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1194
# idx : 0 , Current Loss(batch) : 0.006446166429668665, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.005510176531970501, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.005512493196874857, Correct Predictions(batch) : 128/128
# Epoch: 12, Loss (per batch) : 0.0054, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1132
# idx : 0 , Current Loss(batch) : 0.005097539164125919, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.004771816544234753, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.003939138259738684, Correct Predictions(batch) : 128/128
# Epoch: 13, Loss (per batch) : 0.0047, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1113
# idx : 0 , Current Loss(batch) : 0.0042167166247963905, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0033642100170254707, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004108583088964224, Correct Predictions(batch) : 128/128
# Epoch: 14, Loss (per batch) : 0.0044, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1149
# idx : 0 , Current Loss(batch) : 0.004109106957912445, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003751446260139346, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004659435246139765, Correct Predictions(batch) : 128/128
# Epoch: 15, Loss (per batch) : 0.0040, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1105
# idx : 0 , Current Loss(batch) : 0.002943360712379217, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003292281646281481, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0036009512841701508, Correct Predictions(batch) : 128/128
# Epoch: 16, Loss (per batch) : 0.0034, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1333
# idx : 0 , Current Loss(batch) : 0.0029896837659180164, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003228692105039954, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0030420501716434956, Correct Predictions(batch) : 128/128
# Epoch: 17, Loss (per batch) : 0.0031, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1575
# idx : 0 , Current Loss(batch) : 0.0025653322227299213, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0029012281447649, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0019418273586779833, Correct Predictions(batch) : 128/128
# Epoch: 18, Loss (per batch) : 0.0029, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1185
# idx : 0 , Current Loss(batch) : 0.003159396816045046, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.002494965447112918, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0025216396898031235, Correct Predictions(batch) : 128/128
# Epoch: 19, Loss (per batch) : 0.0027, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1240
# idx : 0 , Current Loss(batch) : 0.0030830895993858576, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0027611078694462776, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.002461498836055398, Correct Predictions(batch) : 128/128
# Epoch: 20, Loss (per batch) : 0.0024, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1276
# idx : 0 , Current Loss(batch) : 0.002254817169159651, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0019531006691977382, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0036181719042360783, Correct Predictions(batch) : 128/128
# Epoch: 21, Loss (per batch) : 0.0023, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1095
# idx : 0 , Current Loss(batch) : 0.0015780829126015306, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.002784570911899209, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0017507000593468547, Correct Predictions(batch) : 128/128
# Epoch: 22, Loss (per batch) : 0.0020, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1082
# idx : 0 , Current Loss(batch) : 0.0018432048382237554, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0023098301608115435, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0025234415661543608, Correct Predictions(batch) : 128/128
# Epoch: 23, Loss (per batch) : 0.0020, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1051
# idx : 0 , Current Loss(batch) : 0.0017833682941272855, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0015872642397880554, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001681328285485506, Correct Predictions(batch) : 128/128
# Epoch: 24, Loss (per batch) : 0.0017, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1082
# idx : 0 , Current Loss(batch) : 0.0017310474067926407, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0015591034898534417, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0016796127893030643, Correct Predictions(batch) : 128/128
# Epoch: 25, Loss (per batch) : 0.0015, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1043
# idx : 0 , Current Loss(batch) : 0.001387100899592042, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0013654031790792942, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0014602505834773183, Correct Predictions(batch) : 128/128
# Epoch: 26, Loss (per batch) : 0.0016, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1086
# idx : 0 , Current Loss(batch) : 0.001985027454793453, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0016077625332400203, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0016602780669927597, Correct Predictions(batch) : 128/128
# Epoch: 27, Loss (per batch) : 0.0017, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1810
# idx : 0 , Current Loss(batch) : 0.00173823197837919, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.001431728946045041, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0015184283256530762, Correct Predictions(batch) : 128/128
# Epoch: 28, Loss (per batch) : 0.0013, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1318
# idx : 0 , Current Loss(batch) : 0.0014452114701271057, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0015016611432656646, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0013450586702674627, Correct Predictions(batch) : 128/128
# Epoch: 29, Loss (per batch) : 0.0014, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1023
# idx : 0 , Current Loss(batch) : 0.0012091355165466666, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0012289268197491765, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0009999530157074332, Correct Predictions(batch) : 128/128
# Epoch: 30, Loss (per batch) : 0.0012, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1043
# idx : 0 , Current Loss(batch) : 0.0009960151510313153, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0013522922527045012, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001013091066852212, Correct Predictions(batch) : 128/128
# Epoch: 31, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1379
# idx : 0 , Current Loss(batch) : 0.0011303202481940389, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0009131330880336463, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0010191334877163172, Correct Predictions(batch) : 128/128
# Epoch: 32, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1158
# idx : 0 , Current Loss(batch) : 0.0014932015910744667, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0011532028438523412, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0007265150779858232, Correct Predictions(batch) : 128/128
# Epoch: 33, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1056
# idx : 0 , Current Loss(batch) : 0.0009817953687161207, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007052383152768016, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001110860612243414, Correct Predictions(batch) : 128/128
# Epoch: 34, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1041
# idx : 0 , Current Loss(batch) : 0.0009266887791454792, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0011029746383428574, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001266399514861405, Correct Predictions(batch) : 128/128
# Epoch: 35, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1412
# idx : 0 , Current Loss(batch) : 0.000759313115850091, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007456832099705935, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0008629928342998028, Correct Predictions(batch) : 128/128
# Epoch: 36, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1064
# idx : 0 , Current Loss(batch) : 0.0008505362784489989, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007078823982737958, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0006119449390098453, Correct Predictions(batch) : 128/128
# Epoch: 37, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1037
# idx : 0 , Current Loss(batch) : 0.0006852232618257403, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0016109845601022243, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0007004272192716599, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1006
# idx : 0 , Current Loss(batch) : 0.0006960220052860677, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007106461562216282, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0007228301838040352, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1018
# idx : 0 , Current Loss(batch) : 0.0006129640969447792, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0005952270585112274, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0009824753506109118, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1232
# idx : 0 , Current Loss(batch) : 0.0005191056989133358, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006489034276455641, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005741316126659513, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1032
# idx : 0 , Current Loss(batch) : 0.0009547706576995552, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0008003293769434094, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00048147127381525934, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1063
# idx : 0 , Current Loss(batch) : 0.0006023883470334113, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007182261324487627, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0004461565113160759, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1175
# idx : 0 , Current Loss(batch) : 0.0006314084748737514, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006089090020395815, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0007645937148481607, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1031
# idx : 0 , Current Loss(batch) : 0.0005358558264560997, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007445117807947099, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0006119427271187305, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0006, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1031
# idx : 0 , Current Loss(batch) : 0.0007076896727085114, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006344760186038911, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00043845473555848, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0006, Accuracy: 1.0000
# Test Accuracy: 0.9605
# Average Test Loss : 0.1002
# idx : 0 , Current Loss(batch) : 0.0005717665189877152, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0005118038970977068, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005333306035026908, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0005, Accuracy: 1.0000
# Test Accuracy: 0.9618
# Average Test Loss : 0.1038
# idx : 0 , Current Loss(batch) : 0.0004696016840171069, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0004224835429340601, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0004988148575648665, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0006, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1130
# idx : 0 , Current Loss(batch) : 0.000702200923115015, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00048644636990502477, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005351133295334876, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0005, Accuracy: 1.0000
# Test Accuracy: 0.9631
# Average Test Loss : 0.1024

# %% [markdown]
# ## **THE BELOW CELLS WERE LOST DUE TO SYNCHRONISATION ERRORS IN GOOGLE COLAB NOTEBOOKS. THE CODE HAS BEEN REPRODUCED. IMPORTANT RESULTS FROM THE OUTPUT HAVE BEEN SUMMARISED**

# %% [markdown]
# ## **TRAINING VIT FROM SCRATCH**

# %%
supervised_model = vit_base(num_classes = 10,pretrained = False)
supervised_model = supervised_model.to(device)
optimizer_supervised = torch.optim.Adam(supervised_model.parameters(), lr= 0.00005,weight_decay=0.0001)
criterion = torch.nn.CrossEntropyLoss()
a1,b1,c1,d1 = train(data_loader_train_supervised,data_loader_test_supervised,supervised_model,optimizer_supervised,criterion,50)

# %% [markdown]
# ## VALIDATION ACCURACY : 52.35 %

# %% [markdown]
# ## **TRAINING VIT USING PRETRAINED WEIGHTS (TRANSFER LEARNING)**

# %%
supervised_model = vit_base(num_classes = 10,pretrained = True)
supervised_model = supervised_model.to(device)
optimizer_supervised = torch.optim.Adam(supervised_model.parameters(), lr= 0.00005,weight_decay=0.0001)
criterion = torch.nn.CrossEntropyLoss()
a1,b1,c1,d1 = train(data_loader_train_supervised,data_loader_test_supervised,supervised_model,optimizer_supervised,criterion,50)

# %% [markdown]
# ## VALIDATION ACCURACY : 98.34%

# %% [markdown]
# # DINO CODE taken from
# <ol>
#   <li>https://github.com/jankrepl/mildlyoverfitted/tree/master/github_adventures/dino</li>
#   <li>https://github.com/facebookresearch/dino</li>
#
# </ol>

# %%
class DataAugmentation:
    """Create crops of an input image together with additional augmentation.

    It generates 2 global crops and `n_local_crops` local crops.

    Parameters
    ----------
    global_crops_scale : tuple
        Range of sizes for the global crops.

    local_crops_scale : tuple
        Range of sizes for the local crops.

    n_local_crops : int
        Number of local crops to create.

    size : int
        The size of the final image.

    Attributes
    ----------
    global_1, global_2 : transforms.Compose
        Two global transforms.

    local : transforms.Compose
        Local transform. Note that the augmentation is stochastic so one
        instance is enough and will lead to different crops.
    """
    def __init__(
        self,
        global_crops_scale=(0.4, 1),
        local_crops_scale=(0.05, 0.4),
        n_local_crops=8,
        size=224,
    ):
        self.n_local_crops = n_local_crops
        RandomGaussianBlur = lambda p: transforms.RandomApply(  # noqa
            [transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 2))],
            p=p,
        )

        flip_and_jitter = transforms.Compose(
            [
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomApply(
                    [
                        transforms.ColorJitter(
                            brightness=0.4,
                            contrast=0.4,
                            saturation=0.2,
                            hue=0.1,
                        ),
                    ]
                ),
                transforms.RandomGrayscale(p=0.2),
            ]
        )

        normalize = transforms.Compose(
            [
                transforms.ToTensor(),
                transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
            ]
        )

        self.global_1 = transforms.Compose(
            [
                transforms.RandomResizedCrop(
                    size,
                    scale=global_crops_scale,
                    interpolation=Image.BICUBIC,
                ),
                flip_and_jitter,
                RandomGaussianBlur(1.0),  # always apply
                normalize,
            ],
        )

        self.global_2 = transforms.Compose(
            [
                transforms.RandomResizedCrop(
                    size,
                    scale=global_crops_scale,
                    interpolation=Image.BICUBIC,
                ),
                flip_and_jitter,
                RandomGaussianBlur(0.1),
                transforms.RandomSolarize(170, p=0.2),
                normalize,
            ],
        )

        self.local = transforms.Compose(
            [
                transforms.RandomResizedCrop(
                    size,
                    scale=local_crops_scale,
                    interpolation=Image.BICUBIC,
                ),
                flip_and_jitter,
                RandomGaussianBlur(0.5),
                normalize,
            ],
        )

    def __call__(self, img):
        """Apply transformation.

        Parameters
        ----------
        img : PIL.Image
            Input image.

        Returns
        -------
        all_crops : list
            List of `torch.Tensor` representing different views of
            the input `img`.
        """
        all_crops = []
        all_crops.append(self.global_1(img))
        all_crops.append(self.global_2(img))

        all_crops.extend([self.local(img) for _ in range(self.n_local_crops)])

        return all_crops

class Head(nn.Module):
    """Network hooked up to the CLS token embedding.

    Just a MLP with the last layer being normalized in a particular way.

    Parameters
    ----------
    in_dim : int
        The dimensionality of the token embedding.

    out_dim : int
        The dimensionality of the final layer (we compute the softmax over).

    hidden_dim : int
        Dimensionality of the hidden layers.

    bottleneck_dim : int
        Dimensionality of the second last layer.

    n_layers : int
        The number of layers.

    norm_last_layer : bool
        If True, then we freeze the norm of the weight of the last linear layer
        to 1.

    Attributes
    ----------
    mlp : nn.Sequential
        Vanilla multi-layer perceptron.

    last_layer : nn.Linear
        Reparametrized linear layer with weight normalization. That means
        that that it will have `weight_g` and `weight_v` as learnable
        parameters instead of a single `weight`.
    """

    def __init__(
        self,
        in_dim,
        out_dim,
        hidden_dim=2048,
        bottleneck_dim=256,
        n_layers=3,
        norm_last_layer=False,
    ):
        super().__init__()
        if n_layers == 1:
            self.mlp = nn.Linear(in_dim, bottleneck_dim)
        else:
            layers = [nn.Linear(in_dim, hidden_dim)]
            layers.append(nn.GELU())
            for _ in range(n_layers - 2):
                layers.append(nn.Linear(hidden_dim, hidden_dim))
                layers.append(nn.GELU())
            layers.append(nn.Linear(hidden_dim, bottleneck_dim))
            self.mlp = nn.Sequential(*layers)

        self.apply(self._init_weights)

        self.last_layer = nn.utils.weight_norm(
            nn.Linear(bottleneck_dim, out_dim, bias=False)
        )
        self.last_layer.weight_g.data.fill_(1)
        if norm_last_layer:
            self.last_layer.weight_g.requires_grad = False

    def _init_weights(self, m):
        """Initialize learnable parameters."""
        if isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, std=0.02)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        """Run forward pass.

        Parameters
        ----------
        x : torch.Tensor
            Of shape `(n_samples, in_dim)`.

        Returns
        -------
        torch.Tensor
            Of shape `(n_samples, out_dim)`.
        """
        x = self.mlp(x)  # (n_samples, bottleneck_dim)
        x = nn.functional.normalize(x, dim=-1, p=2)  # (n_samples, bottleneck_dim)
        x = self.last_layer(x)  # (n_samples, out_dim)

        return x

class MultiCropWrapper(nn.Module):
  """Convenience class for forward pass of multiple crops.

  Parameters
  ----------
  backbone : timm.models.vision_transformer.VisionTransformer
      Instantiated Vision Transformer. Note that we will take the `head`
      attribute and replace it with `nn.Identity`.

  new_head : Head
      New head that is going to be put on top of the `backbone`.
  """
  def __init__(self, backbone, new_head):
      super().__init__()
      backbone.head = nn.Identity()  # deactivate original head
      self.backbone = backbone
      self.new_head = new_head

  def forward(self, x):
      """Run the forward pass.

      The different crops are concatenated along the batch dimension
      and then a single forward pass is fun. The resulting tensor
      is then chunked back to per crop tensors.

      Parameters
      ----------
      x : list
          List of `torch.Tensor` each of shape `(n_samples, 3, size, size)`.

      Returns
      -------
      tuple
          Tuple of `torch.Tensor` each of shape `(n_samples, out_dim)` where
          `output_dim` is determined by `Head`.
      """
      n_crops = len(x)
      concatenated = torch.cat(x, dim=0)  # (n_samples * n_crops, 3, size, size)
      # print(concatenated.shape)
      cls_embedding = self.backbone(concatenated)  # (n_samples * n_crops, in_dim)
      # print(cls_embedding.shape)
      logits = self.new_head(cls_embedding)  # (n_samples * n_crops, out_dim)
      chunks = logits.chunk(n_crops)  # n_crops * (n_samples, out_dim)

      return chunks

class Loss(nn.Module):
    """The loss function.

    We subclass the `nn.Module` becuase we want to create a buffer for the
    logits center of the teacher.

    Parameters
    ----------
    out_dim : int
        The dimensionality of the final layer (we computed the softmax over).

    teacher_temp, student_temp : float
        Softmax temperature of the teacher resp. student.

    center_momentum : float
        Hyperparameter for the exponential moving average that determines
        the center logits. The higher the more the running average matters.
    """
    def __init__(
        self, out_dim, teacher_temp=0.04, student_temp=0.1, center_momentum=0.9
    ):
        super().__init__()
        self.student_temp = student_temp
        self.teacher_temp = teacher_temp
        self.center_momentum = center_momentum
        self.register_buffer("center", torch.zeros(1, out_dim))

    def forward(self, student_output, teacher_output):
        """Evaluate loss.

        Parameters
        ----------
        student_output, teacher_output : tuple
            Tuple of tensors of shape `(n_samples, out_dim)` representing
            logits. The length is equal to number of crops.
            Note that student processed all crops and that the two initial crops
            are the global ones.

        Returns
        -------
        loss : torch.Tensor
            Scalar representing the average loss.
        """
        student_temp = [s / self.student_temp for s in student_output]
        teacher_temp = [(t - self.center) / self.teacher_temp for t in teacher_output]

        student_sm = [F.log_softmax(s, dim=-1) for s in student_temp]
        teacher_sm = [F.softmax(t, dim=-1).detach() for t in teacher_temp]

        total_loss = 0
        n_loss_terms = 0

        for t_ix, t in enumerate(teacher_sm):
            for s_ix, s in enumerate(student_sm):
                if t_ix == s_ix:
                    continue

                loss = torch.sum(-t * s, dim=-1)  # (n_samples,)
                total_loss += loss.mean()  # scalar
                n_loss_terms += 1

        total_loss /= n_loss_terms
        self.update_center(teacher_output)

        return total_loss

    @torch.no_grad()
    def update_center(self, teacher_output):
        """Update center used for teacher output.

        Compute the exponential moving average.

        Parameters
        ----------
        teacher_output : tuple
            Tuple of tensors of shape `(n_samples, out_dim)` where each
            tensor represents a different crop.
        """
        batch_center = torch.cat(teacher_output).mean(
            dim=0, keepdim=True
        )  # (1, out_dim)
        self.center = self.center * self.center_momentum + batch_center * (
            1 - self.center_momentum
        )


def clip_gradients(model, clip=2.0):
    """Rescale norm of computed gradients.

    Parameters
    ----------
    model : nn.Module
        Module.

    clip : float
        Maximum norm.
    """
    for p in model.parameters():
        if p.grad is not None:
            param_norm = p.grad.data.norm(2)
            clip_coef = clip / (param_norm + 1e-6)
            if clip_coef < 1:
                p.grad.data.mul_(clip_coef)

def compute_knn(backbone, data_loader_train, data_loader_val):
    """Get CLS embeddings and use KNN classifier on them.

    We load all embeddings in memory and use sklearn. Should
    be doable.

    Parameters
    ----------
    backbone : timm.models.vision_transformer.VisionTransformer
        Vision transformer whose head is just an identity
        mapping.

    data_loader_train, data_loader_val : torch.utils.data.DataLoader
        Training and validation dataloader that does not apply any
        augmentations. Just casting to tensor and then normalizing.

    Returns
    -------
    val_accuracy : float
        Validation accuracy.
    """
    device = next(backbone.parameters()).device

    data_loaders = {
        "train": data_loader_train,
        "val": data_loader_val,
    }
    lists = {
        "X_train": [],
        "y_train": [],
        "X_val": [],
        "y_val": [],
    }

    for name, data_loader in data_loaders.items():
        for imgs, y in data_loader:
            imgs = imgs.to(device)
            lists[f"X_{name}"].append(backbone(imgs).detach().cpu().numpy())
            lists[f"y_{name}"].append(y.detach().cpu().numpy())

    arrays = {k: np.concatenate(l) for k, l in lists.items()}

    estimator = KNeighborsClassifier()
    estimator.fit(arrays["X_train"], arrays["y_train"])
    y_val_pred = estimator.predict(arrays["X_val"])

    acc = accuracy_score(arrays["y_val"], y_val_pred)

    return acc

def compute_embedding(backbone, data_loader):
    """Compute CLS embedding and prepare for TensorBoard.

    Parameters
    ----------
    backbone : timm.models.vision_transformer.VisionTransformer
        Vision transformer. The head should be an identity mapping.

    data_loader : torch.utils.data.DataLoader
        Validation dataloader that does not apply any augmentations. Just
        casting to tensor and then normalizing.

    Returns
    -------
    embs : torch.Tensor
        Embeddings of shape `(n_samples, out_dim)`.

    imgs : torch.Tensor
        Images of shape `(n_samples, 3, height, width)`.

    labels : list
        List of strings representing the classes.
    """
    device = next(backbone.parameters()).device

    embs_l = []
    imgs_l = []
    labels = []

    for img, y in data_loader:
        img = img.to(device)
        embs_l.append(backbone(img).detach().cpu())
        imgs_l.append(((img * 0.224) + 0.45).cpu())  # undo norm
        labels.extend([data_loader.dataset.classes[i] for i in y.tolist()])

    embs = torch.cat(embs_l, dim=0)
    imgs = torch.cat(imgs_l, dim=0)

    return embs, imgs, labels

# %%
batch_size = 64
device = "cuda"
logging_freq = 400
n_crops = 4
momentum_teacher = 0.995
n_epochs  = 40
dim = 1000
out_dim = 8192
clip_grad = 2.0
norm_last_layer = True
teacher_temp = 0.04
student_temp = 0.1
weight_decay = 0.0001

# %%
batch_size = 32
transform_aug = DataAugmentation(size=224, n_local_crops=n_crops - 2)
dataset_train_aug = ImageFolder(path_dataset_train, transform=transform_aug)
data_loader_train_aug = DataLoader(dataset_train_aug,batch_size=batch_size,shuffle=True,
    drop_last=True,num_workers=n_workers, pin_memory=True,)

# %% [markdown]
# ## STUDENT AND TEACHER WITH RESNET18 AS BACKBONE

# %%
student_cnn = torchvision.models.resnet18()
teacher_cnn = torchvision.models.resnet18()
student = MultiCropWrapper(student_cnn,Head(dim, out_dim, norm_last_layer=True, hidden_dim=512,bottleneck_dim=256,))
teacher = MultiCropWrapper(teacher_cnn, Head(dim, out_dim, norm_last_layer=True, hidden_dim=512,bottleneck_dim=256,))
student, teacher = student.to(device), teacher.to(device)

teacher.load_state_dict(student.state_dict())

for p in teacher.parameters():
        p.requires_grad = False
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
# Loss related
loss_inst = Loss(out_dim, teacher_temp=teacher_temp,student_temp=student_temp,).to(device)

lr = 0.0005 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=weight_decay)

# Training loop
n_batches = len(dataset_train_aug) //batch_size
best_acc = 0
n_steps = 0

# %%
save_best_path = '/content/gdrive/MyDrive/imagenette2-320/resnet_weights/best_model.pth'
best_loss = 1e3
n_epochs = 50

# %%
# save_best_path = '/content/gdrive/MyDrive/imagenette2-320/VIT_weights/best_model.pth'
dino_loss = []
KNN_accuracy = []
def train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 5):
  for e in range(n_epochs):
    student.train()
    for i, (images, _) in enumerate(data_loader_train_aug):

        images = [img.to(device) for img in images]

        teacher_output = teacher(images[:2])
        student_output = student(images)

        loss = loss_inst(student_output, teacher_output)
        dino_loss.append(loss.item())
        optimizer.zero_grad()
        loss.backward()
        clip_gradients(student, clip_grad)
        optimizer.step()
        if loss.item() < best_loss:
          torch.save(student.state_dict(),save_best_path)
          best_loss = loss.item()

        if i%100 == 0:
          print(f"  epoch : {e+start_epoch}  i : {i}  Loss : {loss.item()}")

        with torch.no_grad():
            for student_ps, teacher_ps in zip(student.parameters(), teacher.parameters()):
                teacher_ps.data.mul_(momentum_teacher)
                teacher_ps.data.add_(
                    (1 - momentum_teacher) * student_ps.detach().data
                )

    if e % validate_every == 0:
        save_path = f'/content/gdrive/MyDrive/imagenette2-320/resnet_weights/model_{e}.pth'
        torch.save(student.state_dict(),save_path)
        student.eval()
        current_acc = compute_knn(student.backbone,data_loader_train_plain,data_loader_val_plain,)
        KNN_accuracy.append(current_acc)
        print(f"epoch :{e+start_epoch} KNN Accuracy : {current_acc}")
        # student.train()

  return student

# %%
n_epochs = 50
start_epoch = 0
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst)
# Out:
#   epoch : 0  i : 0  Loss : 9.02420711517334
#   epoch : 0  i : 100  Loss : 8.976109504699707
# epoch :0 KNN Accuracy : 0.3543949044585987
#   epoch : 1  i : 0  Loss : 8.952603340148926
#   epoch : 1  i : 100  Loss : 8.882328987121582
#   epoch : 2  i : 0  Loss : 8.82746410369873
#   epoch : 2  i : 100  Loss : 8.526862144470215
#   epoch : 3  i : 0  Loss : 8.311239242553711
#   epoch : 3  i : 100  Loss : 8.201010704040527
#   epoch : 4  i : 0  Loss : 7.843644618988037
#   epoch : 4  i : 100  Loss : 7.473136901855469
#   epoch : 5  i : 0  Loss : 8.027811050415039
#   epoch : 5  i : 100  Loss : 7.8927321434021
# epoch :5 KNN Accuracy : 0.3819108280254777
#   epoch : 6  i : 0  Loss : 7.878645896911621
#   epoch : 6  i : 100  Loss : 7.714883327484131
#   epoch : 7  i : 0  Loss : 7.267729759216309
#   epoch : 7  i : 100  Loss : 7.498587608337402
#   epoch : 8  i : 0  Loss : 7.465859889984131
#   epoch : 8  i : 100  Loss : 7.473573684692383
#   epoch : 9  i : 0  Loss : 7.3529510498046875
#   epoch : 9  i : 100  Loss : 7.019537925720215
#   epoch : 10  i : 0  Loss : 7.422053813934326
#   epoch : 10  i : 100  Loss : 6.648412227630615
# epoch :10 KNN Accuracy : 0.4361783439490446
#   epoch : 11  i : 0  Loss : 6.631476402282715
#   epoch : 11  i : 100  Loss : 6.912788391113281
#   epoch : 12  i : 0  Loss : 6.926772117614746
#   epoch : 12  i : 100  Loss : 6.765689849853516
#   epoch : 13  i : 0  Loss : 6.637797832489014
#   epoch : 13  i : 100  Loss : 6.623109340667725
#   epoch : 14  i : 0  Loss : 6.511524200439453
#   epoch : 14  i : 100  Loss : 6.35230016708374
#   epoch : 15  i : 0  Loss : 6.383241176605225
#   epoch : 15  i : 100  Loss : 5.789445877075195
# epoch :15 KNN Accuracy : 0.5001273885350318
#   epoch : 16  i : 0  Loss : 6.018012523651123
#   epoch : 16  i : 100  Loss : 6.329690456390381
#   epoch : 17  i : 0  Loss : 6.032896041870117
#   epoch : 17  i : 100  Loss : 6.3644609451293945
#   epoch : 18  i : 0  Loss : 5.962806701660156
#   epoch : 18  i : 100  Loss : 5.908633232116699
#   epoch : 19  i : 0  Loss : 6.073901653289795
#   epoch : 19  i : 100  Loss : 6.408036708831787
#   epoch : 20  i : 0  Loss : 5.811354637145996
#   epoch : 20  i : 100  Loss : 6.088438034057617
# epoch :20 KNN Accuracy : 0.5648407643312102
#   epoch : 21  i : 0  Loss : 5.830388069152832
#   epoch : 21  i : 100  Loss : 5.503871917724609
#   epoch : 22  i : 0  Loss : 5.821620464324951
#   epoch : 22  i : 100  Loss : 6.101527214050293
#   epoch : 23  i : 0  Loss : 5.993344306945801
#   epoch : 23  i : 100  Loss : 5.516725063323975
#   epoch : 24  i : 0  Loss : 5.459771156311035
#   epoch : 24  i : 100  Loss : 5.163895606994629
#   epoch : 25  i : 0  Loss : 5.48811674118042
#   epoch : 25  i : 100  Loss : 4.997974395751953
# epoch :25 KNN Accuracy : 0.5936305732484076
#   epoch : 26  i : 0  Loss : 5.063028335571289
#   epoch : 26  i : 100  Loss : 4.997408390045166
#   epoch : 27  i : 0  Loss : 5.1887712478637695
#   epoch : 27  i : 100  Loss : 5.104615211486816
#   epoch : 28  i : 0  Loss : 5.270461559295654
#   epoch : 28  i : 100  Loss : 4.858489990234375
#   epoch : 29  i : 0  Loss : 4.765344619750977
#   epoch : 29  i : 100  Loss : 5.224620819091797
#   epoch : 30  i : 0  Loss : 5.1016998291015625
#   epoch : 30  i : 100  Loss : 5.043900489807129
# epoch :30 KNN Accuracy : 0.6313375796178344
#   epoch : 31  i : 0  Loss : 5.057116508483887
#   epoch : 31  i : 100  Loss : 4.833510875701904
#   epoch : 32  i : 0  Loss : 4.568212509155273
#   epoch : 32  i : 100  Loss : 4.7227606773376465
#   epoch : 33  i : 0  Loss : 4.817295074462891
#   epoch : 33  i : 100  Loss : 4.840146064758301
#   epoch : 34  i : 0  Loss : 4.857009410858154
#   epoch : 34  i : 100  Loss : 4.4792680740356445
#   epoch : 35  i : 0  Loss : 5.012468338012695
#   epoch : 35  i : 100  Loss : 4.63764762878418
# epoch :35 KNN Accuracy : 0.6519745222929937
#   epoch : 36  i : 0  Loss : 4.771506309509277
#   epoch : 36  i : 100  Loss : 4.217067718505859
#   epoch : 37  i : 0  Loss : 4.579057216644287
#   epoch : 37  i : 100  Loss : 4.413804531097412
#   epoch : 38  i : 0  Loss : 4.4433112144470215
#   epoch : 38  i : 100  Loss : 4.2623982429504395
#   epoch : 39  i : 0  Loss : 4.4613423347473145
#   epoch : 39  i : 100  Loss : 4.3830976486206055
#   epoch : 40  i : 0  Loss : 4.298308849334717
#   epoch : 40  i : 100  Loss : 4.413785457611084
# epoch :40 KNN Accuracy : 0.6687898089171974
#   epoch : 41  i : 0  Loss : 4.131194591522217
#   epoch : 41  i : 100  Loss : 4.329449653625488
#   epoch : 42  i : 0  Loss : 3.7589240074157715
#   epoch : 42  i : 100  Loss : 3.988131523132324
#   epoch : 43  i : 0  Loss : 3.9457011222839355
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-447ef95a2e13> in <cell line: 3>()
#       1 n_epochs = 50
#       2 start_epoch = 0
# ----> 3 student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst)
#
# <ipython-input-39-534d17e45aa4> in train_Dino(best_loss, n_epochs, start_epoch, student, teacher, optimizer, loss_inst)
#       5   for e in range(n_epochs):
#       6     student.train()
# ----> 7     for i, (images, _) in enumerate(data_loader_train_aug):
#       8
#       9         images = [img.to(device) for img in images]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1343             else:
#    1344                 del self._task_info[idx]
# -> 1345                 return self._process_data(data)
#    1346
#    1347     def _try_put_index(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1369         self._try_put_index()
#    1370         if isinstance(data, ExceptionWrapper):
# -> 1371             data.reraise()
#    1372         return data
#    1373
#
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py in reraise(self)
#     692             # instantiate since we don't know how to
#     693             raise RuntimeError(msg) from None
# --> 694         raise exception
#     695
#     696
#
# FileNotFoundError: Caught FileNotFoundError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 229, in __getitem__
#     sample = self.loader(path)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 268, in default_loader
#     return pil_loader(path)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 246, in pil_loader
#     with open(path, "rb") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/imagenette2-320/train/n03028079/n03028079_9099.JPEG'

# %%
n_epochs = 20
start_epoch = 42
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst)
# Out:
#   epoch : 42  i : 0  Loss : 3.9818437099456787
#   epoch : 42  i : 100  Loss : 4.130667686462402
# epoch :42 KNN Accuracy : 0.6878980891719745
#   epoch : 43  i : 0  Loss : 3.9896960258483887
#   epoch : 43  i : 100  Loss : 4.026087284088135
#   epoch : 44  i : 0  Loss : 4.018218994140625
#   epoch : 44  i : 100  Loss : 4.055819988250732
#   epoch : 45  i : 0  Loss : 4.135601043701172
#   epoch : 45  i : 100  Loss : 4.053676605224609
#   epoch : 46  i : 0  Loss : 3.822122097015381
#   epoch : 46  i : 100  Loss : 4.155665874481201
#   epoch : 47  i : 0  Loss : 3.6517083644866943
#   epoch : 47  i : 100  Loss : 3.9256253242492676
# epoch :47 KNN Accuracy : 0.6993630573248407
#   epoch : 48  i : 0  Loss : 4.020618438720703
#   epoch : 48  i : 100  Loss : 3.6503639221191406
#   epoch : 49  i : 0  Loss : 3.4848246574401855
#   epoch : 49  i : 100  Loss : 3.5844075679779053
#   epoch : 50  i : 0  Loss : 3.855245590209961
#   epoch : 50  i : 100  Loss : 3.5310707092285156
#   epoch : 51  i : 0  Loss : 3.7953052520751953
#   epoch : 51  i : 100  Loss : 3.652643918991089
#   epoch : 52  i : 0  Loss : 3.875131130218506
#   epoch : 52  i : 100  Loss : 3.3366951942443848
# epoch :52 KNN Accuracy : 0.6963057324840765
#   epoch : 53  i : 0  Loss : 3.732055425643921
#   epoch : 53  i : 100  Loss : 3.3745951652526855
#   epoch : 54  i : 0  Loss : 3.8547379970550537
#   epoch : 54  i : 100  Loss : 3.4543590545654297
#   epoch : 55  i : 0  Loss : 3.4694907665252686
#   epoch : 55  i : 100  Loss : 3.716825008392334
#   epoch : 56  i : 0  Loss : 3.2368383407592773
#   epoch : 56  i : 100  Loss : 3.5527405738830566
#   epoch : 57  i : 0  Loss : 3.4390134811401367
#   epoch : 57  i : 100  Loss : 3.7198195457458496
# epoch :57 KNN Accuracy : 0.7128662420382166
#   epoch : 58  i : 0  Loss : 3.228011131286621
#   epoch : 58  i : 100  Loss : 3.4536798000335693
#   epoch : 59  i : 0  Loss : 3.4053730964660645
#   epoch : 59  i : 100  Loss : 3.2750778198242188
#   epoch : 60  i : 0  Loss : 3.416238307952881
#   epoch : 60  i : 100  Loss : 3.510758876800537
#   epoch : 61  i : 0  Loss : 3.4942452907562256
#   epoch : 61  i : 100  Loss : 3.4217801094055176

# %%
lr = 0.0001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=1e-4)
n_epochs = 30
start_epoch = 72
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst)
# Out:
#   epoch : 72  i : 0  Loss : 3.1728665828704834
#   epoch : 72  i : 100  Loss : 3.463533878326416
# epoch :72 KNN Accuracy : 0.7230573248407643
#   epoch : 73  i : 0  Loss : 2.776732921600342
#   epoch : 73  i : 100  Loss : 3.240694046020508
#   epoch : 74  i : 0  Loss : 3.0137243270874023
#   epoch : 74  i : 100  Loss : 3.3743350505828857
#   epoch : 75  i : 0  Loss : 3.2060632705688477
#   epoch : 75  i : 100  Loss : 2.914559841156006
#   epoch : 76  i : 0  Loss : 3.091904401779175
#   epoch : 76  i : 100  Loss : 3.1865782737731934
#   epoch : 77  i : 0  Loss : 3.4295878410339355
#   epoch : 77  i : 100  Loss : 3.1751461029052734
# epoch :77 KNN Accuracy : 0.7319745222929936
#   epoch : 78  i : 0  Loss : 3.029054641723633
#   epoch : 78  i : 100  Loss : 3.1192684173583984
#   epoch : 79  i : 0  Loss : 3.183594226837158
#   epoch : 79  i : 100  Loss : 3.3319945335388184
#   epoch : 80  i : 0  Loss : 2.818366765975952
#   epoch : 80  i : 100  Loss : 2.9077746868133545
#   epoch : 81  i : 0  Loss : 3.204420566558838
#   epoch : 81  i : 100  Loss : 2.826294422149658
#   epoch : 82  i : 0  Loss : 3.257228374481201
#   epoch : 82  i : 100  Loss : 3.0450968742370605
# epoch :82 KNN Accuracy : 0.7398726114649682
#   epoch : 83  i : 0  Loss : 3.3640124797821045
#   epoch : 83  i : 100  Loss : 3.065946340560913
#   epoch : 84  i : 0  Loss : 3.073152542114258
#   epoch : 84  i : 100  Loss : 3.0593795776367188
#   epoch : 85  i : 0  Loss : 3.0394692420959473
#   epoch : 85  i : 100  Loss : 2.871995687484741
#   epoch : 86  i : 0  Loss : 2.9057421684265137
#   epoch : 86  i : 100  Loss : 2.9013888835906982
#   epoch : 87  i : 0  Loss : 2.7532267570495605
#   epoch : 87  i : 100  Loss : 3.02280855178833
# epoch :87 KNN Accuracy : 0.7286624203821656
#   epoch : 88  i : 0  Loss : 3.270430088043213
#   epoch : 88  i : 100  Loss : 3.0928568840026855
#   epoch : 89  i : 0  Loss : 3.130364179611206
#   epoch : 89  i : 100  Loss : 2.9554357528686523
#   epoch : 90  i : 0  Loss : 3.033734083175659
#   epoch : 90  i : 100  Loss : 2.8549089431762695
#   epoch : 91  i : 0  Loss : 2.7236974239349365
#   epoch : 91  i : 100  Loss : 2.91817569732666
#   epoch : 92  i : 0  Loss : 2.9092745780944824
#   epoch : 92  i : 100  Loss : 3.0094714164733887
# epoch :92 KNN Accuracy : 0.7357961783439491
#   epoch : 93  i : 0  Loss : 3.210991859436035
#   epoch : 93  i : 100  Loss : 3.1654269695281982
#   epoch : 94  i : 0  Loss : 2.9137401580810547
#   epoch : 94  i : 100  Loss : 2.7635536193847656
#   epoch : 95  i : 0  Loss : 3.0166232585906982
#   epoch : 95  i : 100  Loss : 3.1156349182128906
#   epoch : 96  i : 0  Loss : 2.9564499855041504
#   epoch : 96  i : 100  Loss : 2.9930739402770996
#   epoch : 97  i : 0  Loss : 2.8944411277770996
#   epoch : 97  i : 100  Loss : 2.8371238708496094
# epoch :97 KNN Accuracy : 0.7414012738853503
#   epoch : 98  i : 0  Loss : 2.906510353088379
#   epoch : 98  i : 100  Loss : 2.5904881954193115
#   epoch : 99  i : 0  Loss : 2.799428939819336
#   epoch : 99  i : 100  Loss : 2.994450092315674
#   epoch : 100  i : 0  Loss : 2.7556824684143066
#   epoch : 100  i : 100  Loss : 2.7249956130981445
#   epoch : 101  i : 0  Loss : 2.7241170406341553
#   epoch : 101  i : 100  Loss : 2.806504964828491

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.1)
n_epochs = 30
start_epoch = 102
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst)
# Out:
#   epoch : 102  i : 0  Loss : 2.9144911766052246
#   epoch : 102  i : 100  Loss : 2.9242312908172607
# epoch :102 KNN Accuracy : 0.7388535031847133
#   epoch : 103  i : 0  Loss : 2.8352274894714355
#   epoch : 103  i : 100  Loss : 3.088395595550537
#   epoch : 104  i : 0  Loss : 3.242990016937256
#   epoch : 104  i : 100  Loss : 2.7682299613952637
#   epoch : 105  i : 0  Loss : 2.7257182598114014
#   epoch : 105  i : 100  Loss : 2.7173056602478027
#   epoch : 106  i : 0  Loss : 2.6286368370056152
#   epoch : 106  i : 100  Loss : 2.799177646636963
#   epoch : 107  i : 0  Loss : 2.78991961479187
#   epoch : 107  i : 100  Loss : 2.737703323364258
# epoch :107 KNN Accuracy : 0.7541401273885351
#   epoch : 108  i : 0  Loss : 2.8545520305633545
#   epoch : 108  i : 100  Loss : 2.81748628616333
#   epoch : 109  i : 0  Loss : 2.494121551513672
#   epoch : 109  i : 100  Loss : 2.9271163940429688
#   epoch : 110  i : 0  Loss : 2.7229373455047607
#   epoch : 110  i : 100  Loss : 2.977524757385254
#   epoch : 111  i : 0  Loss : 2.682870388031006
#   epoch : 111  i : 100  Loss : 2.982555389404297
#   epoch : 112  i : 0  Loss : 2.8105201721191406
#   epoch : 112  i : 100  Loss : 2.601393938064575
# epoch :112 KNN Accuracy : 0.7536305732484077
#   epoch : 113  i : 0  Loss : 2.9235968589782715
#   epoch : 113  i : 100  Loss : 2.8198745250701904
#   epoch : 114  i : 0  Loss : 2.75594425201416
#   epoch : 114  i : 100  Loss : 2.7376649379730225
#   epoch : 115  i : 0  Loss : 2.6408746242523193
#   epoch : 115  i : 100  Loss : 2.803880214691162
#   epoch : 116  i : 0  Loss : 2.480234384536743
#   epoch : 116  i : 100  Loss : 2.764153242111206
#   epoch : 117  i : 0  Loss : 2.581164836883545
#   epoch : 117  i : 100  Loss : 2.6827220916748047
# epoch :117 KNN Accuracy : 0.7689171974522293
#   epoch : 118  i : 0  Loss : 2.931727170944214
#   epoch : 118  i : 100  Loss : 2.507863759994507
#   epoch : 119  i : 0  Loss : 2.636253833770752
#   epoch : 119  i : 100  Loss : 2.6546599864959717
#   epoch : 120  i : 0  Loss : 2.486664295196533
#   epoch : 120  i : 100  Loss : 2.6699776649475098
#   epoch : 121  i : 0  Loss : 2.479555606842041
#   epoch : 121  i : 100  Loss : 2.210486888885498
#   epoch : 122  i : 0  Loss : 2.715618133544922
#   epoch : 122  i : 100  Loss : 2.660496711730957
# epoch :122 KNN Accuracy : 0.7663694267515924
#   epoch : 123  i : 0  Loss : 2.725961685180664
#   epoch : 123  i : 100  Loss : 2.3700356483459473
#   epoch : 124  i : 0  Loss : 2.711500883102417
#   epoch : 124  i : 100  Loss : 2.6085901260375977
#   epoch : 125  i : 0  Loss : 2.470851421356201
#   epoch : 125  i : 100  Loss : 2.4466347694396973
#   epoch : 126  i : 0  Loss : 2.7524688243865967
#   epoch : 126  i : 100  Loss : 2.4509949684143066
#   epoch : 127  i : 0  Loss : 2.787276029586792
#   epoch : 127  i : 100  Loss : 2.467461585998535
# epoch :127 KNN Accuracy : 0.7729936305732484
#   epoch : 128  i : 0  Loss : 2.5339179039001465
#   epoch : 128  i : 100  Loss : 2.3443539142608643
#   epoch : 129  i : 0  Loss : 2.3574061393737793
#   epoch : 129  i : 100  Loss : 2.322018623352051
#   epoch : 130  i : 0  Loss : 2.3730125427246094
#   epoch : 130  i : 100  Loss : 2.581754446029663
#   epoch : 131  i : 0  Loss : 2.583939552307129
#   epoch : 131  i : 100  Loss : 2.3459460735321045

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.1)
n_epochs = 30
start_epoch = 132
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst)
# Out:
#   epoch : 132  i : 0  Loss : 2.29766845703125
#   epoch : 132  i : 100  Loss : 2.1402668952941895
# epoch :132 KNN Accuracy : 0.7747770700636942
#   epoch : 133  i : 0  Loss : 2.4085488319396973
#   epoch : 133  i : 100  Loss : 2.331089496612549
#   epoch : 134  i : 0  Loss : 2.3805415630340576
#   epoch : 134  i : 100  Loss : 2.671372890472412
#   epoch : 135  i : 0  Loss : 2.4093151092529297
#   epoch : 135  i : 100  Loss : 2.1754777431488037
#   epoch : 136  i : 0  Loss : 2.232269525527954
#   epoch : 136  i : 100  Loss : 2.4026126861572266
#   epoch : 137  i : 0  Loss : 2.3166816234588623
#   epoch : 137  i : 100  Loss : 2.2506725788116455
# epoch :137 KNN Accuracy : 0.781656050955414
#   epoch : 138  i : 0  Loss : 2.136922597885132
#   epoch : 138  i : 100  Loss : 2.4002652168273926
#   epoch : 139  i : 0  Loss : 2.1796789169311523
#   epoch : 139  i : 100  Loss : 2.3244190216064453
#   epoch : 140  i : 0  Loss : 2.2618346214294434
#   epoch : 140  i : 100  Loss : 2.2655889987945557
#   epoch : 141  i : 0  Loss : 2.368793249130249
#   epoch : 141  i : 100  Loss : 2.565311908721924
#   epoch : 142  i : 0  Loss : 1.9411300420761108
#   epoch : 142  i : 100  Loss : 2.3756701946258545
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch :142 KNN Accuracy : 0.7806369426751593
#   epoch : 143  i : 0  Loss : 2.0087318420410156
#   epoch : 143  i : 100  Loss : 2.3552968502044678
#   epoch : 144  i : 0  Loss : 2.1430976390838623
#   epoch : 144  i : 100  Loss : 2.419816017150879
#   epoch : 145  i : 0  Loss : 2.413015842437744
#   epoch : 145  i : 100  Loss : 2.2341041564941406
#   epoch : 146  i : 0  Loss : 2.066159963607788
#   epoch : 146  i : 100  Loss : 2.2251124382019043
#   epoch : 147  i : 0  Loss : 2.216953992843628
#   epoch : 147  i : 100  Loss : 2.4136812686920166
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     Exception ignored in: if w.is_alive():<function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionErrorself._shutdown_workers():
# can only test a child process
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch :147 KNN Accuracy : 0.7921019108280255
#   epoch : 148  i : 0  Loss : 2.2456014156341553
#   epoch : 148  i : 100  Loss : 2.2208328247070312
#   epoch : 149  i : 0  Loss : 2.263960838317871
#   epoch : 149  i : 100  Loss : 2.1827526092529297
#   epoch : 150  i : 0  Loss : 1.876591682434082
#   epoch : 150  i : 100  Loss : 2.3720602989196777
#   epoch : 151  i : 0  Loss : 2.2960333824157715
#   epoch : 151  i : 100  Loss : 2.3225386142730713
#   epoch : 152  i : 0  Loss : 2.177553176879883
#   epoch : 152  i : 100  Loss : 2.207897901535034
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch :152 KNN Accuracy : 0.793375796178344
#   epoch : 153  i : 0  Loss : 1.8615624904632568
#   epoch : 153  i : 100  Loss : 2.1489360332489014
#   epoch : 154  i : 0  Loss : 1.9984210729599
#   epoch : 154  i : 100  Loss : 1.9416263103485107
#   epoch : 155  i : 0  Loss : 2.5671677589416504
#   epoch : 155  i : 100  Loss : 2.025700092315674
#   epoch : 156  i : 0  Loss : 1.8957937955856323
#   epoch : 156  i : 100  Loss : 2.2548880577087402
#   epoch : 157  i : 0  Loss : 2.029087781906128
#   epoch : 157  i : 100  Loss : 2.549213171005249
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
# self._shutdown_workers()  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():AssertionError
# :   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionErrorException ignored in: : <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>can only test a child process
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# if w.is_alive():
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()    assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# :     can only test a child process
# if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>    assert self._parent_pid == os.getpid(), 'can only test a child process'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# AssertionError    : self._shutdown_workers()can only test a child process
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0><function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# self._shutdown_workers()
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# self._shutdown_workers()
# if w.is_alive():  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():    assert self._parent_pid == os.getpid(), 'can only test a child process'
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#     AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process':
# can only test a child processAssertionError:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>self._shutdown_workers()
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         self._shutdown_workers()if w.is_alive():
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
#
# AssertionError  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     : can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>can only test a child process
# Traceback (most recent call last):
#
# Exception ignored in:   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# self._shutdown_workers()Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         if w.is_alive():self._shutdown_workers()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():AssertionError
# :   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# epoch :157 KNN Accuracy : 0.7882802547770701
#   epoch : 158  i : 0  Loss : 2.089461326599121
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#   epoch : 158  i : 100  Loss : 2.0968079566955566
#   epoch : 159  i : 0  Loss : 1.997278094291687
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#   epoch : 159  i : 100  Loss : 2.4767284393310547
#   epoch : 160  i : 0  Loss : 2.3531360626220703
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#   epoch : 160  i : 100  Loss : 2.0295796394348145
#   epoch : 161  i : 0  Loss : 2.374478816986084
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Exception ignored in: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# self._shutdown_workers()Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         self._shutdown_workers()if w.is_alive():
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError    : assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
# Exception ignored in:   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Traceback (most recent call last):
# self._shutdown_workers()      File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     self._shutdown_workers()
# if w.is_alive():  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():AssertionError    assert self._parent_pid == os.getpid(), 'can only test a child process':
#
#
# can only test a child processAssertionError: can only test a child processException ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
# Exception ignored in: Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
# self._shutdown_workers()  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#     if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0><function _MultiProcessingDataLoaderIter.__del__ at 0x797218c46cb0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     self._shutdown_workers()    if w.is_alive():
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
# AssertionError
# :   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child process
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#   epoch : 161  i : 100  Loss : 2.0741348266601562

# %%
curr_path = '/content/gdrive/MyDrive/imagenette2-320/resnet_weights/best_model.pth'
student.load_state_dict(torch.load(curr_path))
# Out:
# <All keys matched successfully>

# %%
curr_path = '/content/gdrive/MyDrive/imagenette2-320/resnet_weights/best_model.pth'
student.load_state_dict(torch.load(curr_path))
student.eval()
current_acc = compute_knn(student.backbone,data_loader_train_plain,data_loader_val_plain,)
print("KNN Accuracy :",current_acc)
# Out:
# KNN Accuracy : 0.7903184713375796

# %% [markdown]
# ### VIT AS BACKBONE

# %%
vit_name, dim = "deit_small_distilled_patch16_224", 384
student_vit = timm.create_model(vit_name, pretrained=False)
teacher_vit = timm.create_model(vit_name, pretrained=False)
student_vit.head = nn.Identity()
student_vit.head_dist = nn.Identity()
teacher_vit.head = nn.Identity()
teacher_vit.head_dist = nn.Identity()

student = MultiCropWrapper(student_vit,Head(dim, out_dim, norm_last_layer=True, hidden_dim=512,bottleneck_dim=256,))
teacher = MultiCropWrapper(teacher_vit, Head(dim, out_dim, norm_last_layer=True, hidden_dim=512,bottleneck_dim=256,))
student, teacher = student.to(device), teacher.to(device)

teacher.load_state_dict(student.state_dict())

for p in teacher.parameters():
        p.requires_grad = False
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
data_loader_train_plain = DataLoader(dataset_train_plain,batch_size=64, shuffle = True,drop_last=False,num_workers=4,)
data_loader_val_plain = DataLoader(dataset_val_plain,batch_size=64,drop_last=False,num_workers=4,shuffle = True)

# %%
# Loss related
loss_inst = Loss(out_dim, teacher_temp=teacher_temp,student_temp=student_temp,).to(device)
batch_size = 128
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=weight_decay)

# Training loop
n_batches = len(dataset_train_aug) //batch_size
best_acc = 0

# %%
compute_knn(student.backbone,data_loader_train_plain,data_loader_val_plain,)
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0>
# Traceback (most recent call last):
# Exception ignored in:   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0>
# self._shutdown_workers()Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         self._shutdown_workers()if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
#
# AssertionError  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# : can only test a child process
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0><function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0><function _MultiProcessingDataLoaderIter.__del__ at 0x7ececd22b1c0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
# self._shutdown_workers()  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
# if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process':     assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionErrorcan only test a child process:
# can only test a child process
# 0.292484076433121

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.1)
save_best_path = '/content/gdrive/MyDrive/imagenette2-320/VIT_weights/best_model.pth'
n_epochs = 50
start_epoch = 0
best_loss = 1e3
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 10)
# Out:
#   epoch : 0  i : 0  Loss : 8.747684478759766
#   epoch : 0  i : 100  Loss : 8.750885009765625
#   epoch : 0  i : 200  Loss : 8.641149520874023
# epoch :0 KNN Accuracy : 0.2835668789808917
#   epoch : 1  i : 0  Loss : 8.653779029846191
#   epoch : 1  i : 100  Loss : 8.589271545410156
#   epoch : 1  i : 200  Loss : 8.376199722290039
#   epoch : 2  i : 0  Loss : 8.296825408935547
#   epoch : 2  i : 100  Loss : 8.493345260620117
#   epoch : 2  i : 200  Loss : 8.406209945678711
#   epoch : 3  i : 0  Loss : 8.287588119506836
#   epoch : 3  i : 100  Loss : 8.214757919311523
#   epoch : 3  i : 200  Loss : 7.724208354949951
#   epoch : 4  i : 0  Loss : 7.922868728637695
#   epoch : 4  i : 100  Loss : 8.142062187194824
#   epoch : 4  i : 200  Loss : 8.096233367919922
#   epoch : 5  i : 0  Loss : 7.5859503746032715
#   epoch : 5  i : 100  Loss : 7.683028697967529
#   epoch : 5  i : 200  Loss : 7.212411403656006
#   epoch : 6  i : 0  Loss : 7.3705058097839355
#   epoch : 6  i : 100  Loss : 7.771353721618652
#   epoch : 6  i : 200  Loss : 7.58625602722168
#   epoch : 7  i : 0  Loss : 7.569682598114014
#   epoch : 7  i : 100  Loss : 7.452073574066162
#   epoch : 7  i : 200  Loss : 7.298470497131348
#   epoch : 8  i : 0  Loss : 7.45955228805542
#   epoch : 8  i : 100  Loss : 7.665041923522949
#   epoch : 8  i : 200  Loss : 7.772550106048584
#   epoch : 9  i : 0  Loss : 7.683170318603516
#   epoch : 9  i : 100  Loss : 7.221131324768066
#   epoch : 9  i : 200  Loss : 7.723763942718506
#   epoch : 10  i : 0  Loss : 6.927071571350098
#   epoch : 10  i : 100  Loss : 7.406533241271973
#   epoch : 10  i : 200  Loss : 7.638067245483398
# epoch :10 KNN Accuracy : 0.375031847133758
#   epoch : 11  i : 0  Loss : 6.70924186706543
#   epoch : 11  i : 100  Loss : 7.490291595458984
#   epoch : 11  i : 200  Loss : 7.369074821472168
#   epoch : 12  i : 0  Loss : 7.308482646942139
#   epoch : 12  i : 100  Loss : 6.899519920349121
#   epoch : 12  i : 200  Loss : 7.137654781341553
#   epoch : 13  i : 0  Loss : 6.802124977111816
#   epoch : 13  i : 100  Loss : 7.255483150482178
#   epoch : 13  i : 200  Loss : 7.063863277435303
#   epoch : 14  i : 0  Loss : 6.872206687927246
#   epoch : 14  i : 100  Loss : 5.83738899230957
#   epoch : 14  i : 200  Loss : 6.357579708099365
#   epoch : 15  i : 0  Loss : 6.516487121582031
#   epoch : 15  i : 100  Loss : 6.7689738273620605
#   epoch : 15  i : 200  Loss : 6.386106014251709
#   epoch : 16  i : 0  Loss : 6.502009391784668
#   epoch : 16  i : 100  Loss : 7.426527976989746
#   epoch : 16  i : 200  Loss : 6.197598934173584
#   epoch : 17  i : 0  Loss : 7.273033142089844
#   epoch : 17  i : 100  Loss : 6.43174934387207
#   epoch : 17  i : 200  Loss : 6.5389862060546875
#   epoch : 18  i : 0  Loss : 6.32636833190918
#   epoch : 18  i : 100  Loss : 6.285592079162598
#   epoch : 18  i : 200  Loss : 5.962273597717285
#   epoch : 19  i : 0  Loss : 6.628343105316162
#   epoch : 19  i : 100  Loss : 6.227126121520996
#   epoch : 19  i : 200  Loss : 6.0846686363220215
#   epoch : 20  i : 0  Loss : 6.915358543395996
#   epoch : 20  i : 100  Loss : 5.986063003540039
#   epoch : 20  i : 200  Loss : 5.700494289398193
# epoch :20 KNN Accuracy : 0.44
#   epoch : 21  i : 0  Loss : 6.547945022583008
#   epoch : 21  i : 100  Loss : 6.038542747497559
#   epoch : 21  i : 200  Loss : 6.547436714172363
#   epoch : 22  i : 0  Loss : 5.8773698806762695
#   epoch : 22  i : 100  Loss : 6.292234420776367
#   epoch : 22  i : 200  Loss : 6.648262023925781
#   epoch : 23  i : 0  Loss : 6.081582069396973
#   epoch : 23  i : 100  Loss : 5.85798454284668
#   epoch : 23  i : 200  Loss : 6.512481689453125
#   epoch : 24  i : 0  Loss : 6.332851409912109
#   epoch : 24  i : 100  Loss : 6.2449188232421875
#   epoch : 24  i : 200  Loss : 5.935895919799805
#   epoch : 25  i : 0  Loss : 6.174014091491699
#   epoch : 25  i : 100  Loss : 6.17704963684082
#   epoch : 25  i : 200  Loss : 6.201042175292969
#   epoch : 26  i : 0  Loss : 5.780665397644043
#   epoch : 26  i : 100  Loss : 6.298742294311523
#   epoch : 26  i : 200  Loss : 6.3393354415893555
#   epoch : 27  i : 0  Loss : 6.143502235412598
#   epoch : 27  i : 100  Loss : 5.72860860824585
#   epoch : 27  i : 200  Loss : 5.683255195617676
#   epoch : 28  i : 0  Loss : 6.290003776550293
#   epoch : 28  i : 100  Loss : 6.223130226135254
#   epoch : 28  i : 200  Loss : 5.098888397216797
#   epoch : 29  i : 0  Loss : 5.3793559074401855
#   epoch : 29  i : 100  Loss : 6.038017272949219
#   epoch : 29  i : 200  Loss : 5.831151008605957
#   epoch : 30  i : 0  Loss : 5.425585746765137
#   epoch : 30  i : 100  Loss : 6.094814300537109
#   epoch : 30  i : 200  Loss : 5.37362003326416
# epoch :30 KNN Accuracy : 0.4942675159235669
#   epoch : 31  i : 0  Loss : 6.742361068725586
#   epoch : 31  i : 100  Loss : 5.763387680053711
#   epoch : 31  i : 200  Loss : 5.729217052459717
#   epoch : 32  i : 0  Loss : 6.046455383300781
#   epoch : 32  i : 100  Loss : 5.8582048416137695
#   epoch : 32  i : 200  Loss : 5.855975151062012
#   epoch : 33  i : 0  Loss : 5.160014629364014
#   epoch : 33  i : 100  Loss : 5.9252238273620605
#   epoch : 33  i : 200  Loss : 5.198008060455322
#   epoch : 34  i : 0  Loss : 5.015729904174805
#   epoch : 34  i : 100  Loss : 5.393438339233398
#   epoch : 34  i : 200  Loss : 6.44069766998291
#   epoch : 35  i : 0  Loss : 5.591726303100586
#   epoch : 35  i : 100  Loss : 5.4787116050720215
#   epoch : 35  i : 200  Loss : 5.70244026184082
#   epoch : 36  i : 0  Loss : 5.49135684967041
#   epoch : 36  i : 100  Loss : 5.501954555511475
#   epoch : 36  i : 200  Loss : 5.112900733947754
#   epoch : 37  i : 0  Loss : 5.484275817871094
#   epoch : 37  i : 100  Loss : 5.144780158996582
#   epoch : 37  i : 200  Loss : 5.544075012207031
#   epoch : 38  i : 0  Loss : 5.898163795471191
#   epoch : 38  i : 100  Loss : 5.485445976257324
#   epoch : 38  i : 200  Loss : 5.327897548675537
#   epoch : 39  i : 0  Loss : 5.059489727020264
#   epoch : 39  i : 100  Loss : 5.20884895324707
#   epoch : 39  i : 200  Loss : 5.322182655334473
#   epoch : 40  i : 0  Loss : 5.479318141937256
#   epoch : 40  i : 100  Loss : 5.098986625671387
#   epoch : 40  i : 200  Loss : 5.178681373596191
# epoch :40 KNN Accuracy : 0.5347770700636942
#   epoch : 41  i : 0  Loss : 5.123973846435547
#   epoch : 41  i : 100  Loss : 5.080843448638916
#   epoch : 41  i : 200  Loss : 5.305064678192139
#   epoch : 42  i : 0  Loss : 5.379804611206055
#   epoch : 42  i : 100  Loss : 5.808679103851318
#   epoch : 42  i : 200  Loss : 5.093378067016602
#   epoch : 43  i : 0  Loss : 5.218581676483154
#   epoch : 43  i : 100  Loss : 4.458690643310547
#   epoch : 43  i : 200  Loss : 4.721099853515625
#   epoch : 44  i : 0  Loss : 4.704411506652832
#   epoch : 44  i : 100  Loss : 5.537275314331055
#   epoch : 44  i : 200  Loss : 5.0675506591796875
#   epoch : 45  i : 0  Loss : 4.747929573059082
#   epoch : 45  i : 100  Loss : 5.676836967468262
#   epoch : 45  i : 200  Loss : 5.47652006149292
#   epoch : 46  i : 0  Loss : 5.228665351867676
#   epoch : 46  i : 100  Loss : 5.05660343170166
#   epoch : 46  i : 200  Loss : 4.586833953857422
#   epoch : 47  i : 0  Loss : 4.946506500244141
#   epoch : 47  i : 100  Loss : 5.128069877624512
#   epoch : 47  i : 200  Loss : 4.658560276031494
#   epoch : 48  i : 0  Loss : 4.655463218688965
#   epoch : 48  i : 100  Loss : 5.3509368896484375
#   epoch : 48  i : 200  Loss : 4.854066848754883
#   epoch : 49  i : 0  Loss : 4.2903971672058105
#   epoch : 49  i : 100  Loss : 4.712468147277832
#   epoch : 49  i : 200  Loss : 4.296627044677734

# %%
batch_size = 32
transform_aug = DataAugmentation(size=224, n_local_crops=n_crops - 2)
dataset_train_aug = ImageFolder(path_dataset_train, transform=transform_aug)
data_loader_train_aug = DataLoader(dataset_train_aug,batch_size=batch_size,shuffle=True,
    drop_last=True,num_workers=4, pin_memory=True,)

# %%
save_best_path = '/content/gdrive/MyDrive/imagenette2-320/VIT_weights/best_model.pth'
student.load_state_dict(torch.load(save_best_path))
# Out:
# <All keys matched successfully>

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.1)
n_epochs = 50
start_epoch = 50
best_loss = 5
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 10)
# Out:
#   epoch : 50  i : 0  Loss : 12.271464347839355
#   epoch : 50  i : 100  Loss : 8.887006759643555
# epoch :50 KNN Accuracy : 0.4435668789808917
#   epoch : 51  i : 0  Loss : 8.531305313110352
#   epoch : 51  i : 100  Loss : 8.247798919677734
#   epoch : 52  i : 0  Loss : 8.640562057495117
#   epoch : 52  i : 100  Loss : 7.804385185241699
#   epoch : 53  i : 0  Loss : 7.2993621826171875
#   epoch : 53  i : 100  Loss : 6.740617275238037
#   epoch : 54  i : 0  Loss : 6.533051490783691
#   epoch : 54  i : 100  Loss : 5.355316162109375
#   epoch : 55  i : 0  Loss : 5.454911708831787
#   epoch : 55  i : 100  Loss : 5.337714672088623
#   epoch : 56  i : 0  Loss : 4.813057899475098
#   epoch : 56  i : 100  Loss : 4.965258598327637
#   epoch : 57  i : 0  Loss : 4.933638572692871
#   epoch : 57  i : 100  Loss : 4.813665390014648
#   epoch : 58  i : 0  Loss : 5.190382480621338
#   epoch : 58  i : 100  Loss : 4.824418067932129
#   epoch : 59  i : 0  Loss : 4.764100551605225
#   epoch : 59  i : 100  Loss : 4.9516472816467285
#   epoch : 60  i : 0  Loss : 4.177381992340088
#   epoch : 60  i : 100  Loss : 4.807047367095947
# epoch :60 KNN Accuracy : 0.572484076433121
#   epoch : 61  i : 0  Loss : 3.848644971847534
#   epoch : 61  i : 100  Loss : 4.634261131286621
#   epoch : 62  i : 0  Loss : 4.689495086669922
#   epoch : 62  i : 100  Loss : 4.151761054992676
#   epoch : 63  i : 0  Loss : 4.540768623352051
#   epoch : 63  i : 100  Loss : 4.619770050048828
#   epoch : 64  i : 0  Loss : 4.069409370422363
#   epoch : 64  i : 100  Loss : 4.359501838684082
#   epoch : 65  i : 0  Loss : 4.3592143058776855
#   epoch : 65  i : 100  Loss : 4.208281993865967
#   epoch : 66  i : 0  Loss : 4.551363945007324
#   epoch : 66  i : 100  Loss : 4.636728763580322
#   epoch : 67  i : 0  Loss : 3.9683523178100586
#   epoch : 67  i : 100  Loss : 4.413024425506592
#   epoch : 68  i : 0  Loss : 4.846451759338379
#   epoch : 68  i : 100  Loss : 4.243776321411133
#   epoch : 69  i : 0  Loss : 4.077906131744385
#   epoch : 69  i : 100  Loss : 3.991960287094116
#   epoch : 70  i : 0  Loss : 4.04724645614624
#   epoch : 70  i : 100  Loss : 3.940121650695801
# epoch :70 KNN Accuracy : 0.5839490445859873
#   epoch : 71  i : 0  Loss : 4.193060398101807
#   epoch : 71  i : 100  Loss : 4.1078338623046875
#   epoch : 72  i : 0  Loss : 3.8952064514160156
#   epoch : 72  i : 100  Loss : 4.0043439865112305
#   epoch : 73  i : 0  Loss : 4.190460205078125
#   epoch : 73  i : 100  Loss : 3.952836513519287
#   epoch : 74  i : 0  Loss : 3.971160650253296
#   epoch : 74  i : 100  Loss : 3.831127166748047
#   epoch : 75  i : 0  Loss : 4.138592720031738
#   epoch : 75  i : 100  Loss : 4.064017295837402
#   epoch : 76  i : 0  Loss : 3.702467918395996
#   epoch : 76  i : 100  Loss : 3.9165475368499756
#   epoch : 77  i : 0  Loss : 3.9093470573425293
#   epoch : 77  i : 100  Loss : 4.20932674407959
#   epoch : 78  i : 0  Loss : 4.011227607727051
#   epoch : 78  i : 100  Loss : 3.8990845680236816
#   epoch : 79  i : 0  Loss : 3.920294761657715
#   epoch : 79  i : 100  Loss : 4.005599021911621
#   epoch : 80  i : 0  Loss : 4.05657958984375
#   epoch : 80  i : 100  Loss : 3.639023780822754
# epoch :80 KNN Accuracy : 0.606624203821656
#   epoch : 81  i : 0  Loss : 3.5759358406066895
#   epoch : 81  i : 100  Loss : 3.978588819503784
#   epoch : 82  i : 0  Loss : 4.2029218673706055
#   epoch : 82  i : 100  Loss : 4.029191493988037
#   epoch : 83  i : 0  Loss : 3.7819583415985107
#   epoch : 83  i : 100  Loss : 3.9485883712768555
#   epoch : 84  i : 0  Loss : 3.7623870372772217
#   epoch : 84  i : 100  Loss : 3.9230105876922607
#   epoch : 85  i : 0  Loss : 3.967947483062744
#   epoch : 85  i : 100  Loss : 3.661888599395752
#   epoch : 86  i : 0  Loss : 4.117185115814209
#   epoch : 86  i : 100  Loss : 4.286996841430664
#   epoch : 87  i : 0  Loss : 3.821359157562256
#   epoch : 87  i : 100  Loss : 3.98732328414917
#   epoch : 88  i : 0  Loss : 3.74267578125
#   epoch : 88  i : 100  Loss : 3.664503574371338
#   epoch : 89  i : 0  Loss : 3.604146957397461
#   epoch : 89  i : 100  Loss : 3.9904251098632812
#   epoch : 90  i : 0  Loss : 3.3853044509887695
#   epoch : 90  i : 100  Loss : 3.643190383911133
# epoch :90 KNN Accuracy : 0.6292993630573248
#   epoch : 91  i : 0  Loss : 3.650468349456787
#   epoch : 91  i : 100  Loss : 3.946918487548828
#   epoch : 92  i : 0  Loss : 3.5025992393493652
#   epoch : 92  i : 100  Loss : 3.767077922821045
#   epoch : 93  i : 0  Loss : 3.4422521591186523
#   epoch : 93  i : 100  Loss : 3.582179069519043
#   epoch : 94  i : 0  Loss : 3.622343063354492
#   epoch : 94  i : 100  Loss : 4.074641227722168
#   epoch : 95  i : 0  Loss : 3.678171157836914
#   epoch : 95  i : 100  Loss : 3.3787927627563477
#   epoch : 96  i : 0  Loss : 3.5547759532928467
#   epoch : 96  i : 100  Loss : 3.4149889945983887
#   epoch : 97  i : 0  Loss : 3.8547472953796387
#   epoch : 97  i : 100  Loss : 3.7622344493865967
#   epoch : 98  i : 0  Loss : 3.449526309967041
#   epoch : 98  i : 100  Loss : 3.527512311935425
#   epoch : 99  i : 0  Loss : 3.5679521560668945
#   epoch : 99  i : 100  Loss : 3.4975485801696777

# %%
save_best_path = '/content/gdrive/MyDrive/imagenette2-320/VIT_weights/latest_model.pth'
torch.save(student.state_dict(),save_best_path)

# %%
student.load_state_dict()

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.1)
n_epochs = 50
start_epoch = 100
best_loss = 5
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 10)
# Out:
#   epoch : 100  i : 0  Loss : 12.947257995605469
# epoch :100 KNN Accuracy : 0.34878980891719746
#   epoch : 101  i : 0  Loss : 8.884957313537598
#   epoch : 102  i : 0  Loss : 8.831358909606934
#   epoch : 103  i : 0  Loss : 8.723714828491211
#   epoch : 104  i : 0  Loss : 8.526971817016602
#   epoch : 105  i : 0  Loss : 8.32490062713623
#   epoch : 106  i : 0  Loss : 8.04737377166748
#   epoch : 107  i : 0  Loss : 8.157147407531738
#   epoch : 108  i : 0  Loss : 7.973672389984131
#   epoch : 109  i : 0  Loss : 7.221358299255371
#   epoch : 110  i : 0  Loss : 7.382135391235352
# epoch :110 KNN Accuracy : 0.5559235668789809
#   epoch : 111  i : 0  Loss : 7.059484481811523
#   epoch : 112  i : 0  Loss : 6.916423320770264
#   epoch : 113  i : 0  Loss : 6.730546474456787
#   epoch : 114  i : 0  Loss : 6.23309326171875
#   epoch : 115  i : 0  Loss : 6.289758682250977
#   epoch : 116  i : 0  Loss : 6.085557460784912
#   epoch : 117  i : 0  Loss : 5.436591148376465
#   epoch : 118  i : 0  Loss : 5.2024431228637695
#   epoch : 119  i : 0  Loss : 5.369980812072754
#   epoch : 120  i : 0  Loss : 4.789735794067383
# epoch :120 KNN Accuracy : 0.5969426751592357
#   epoch : 121  i : 0  Loss : 4.8921356201171875
#   epoch : 122  i : 0  Loss : 4.656785011291504
#   epoch : 123  i : 0  Loss : 4.968975067138672
#   epoch : 124  i : 0  Loss : 4.477654457092285
#   epoch : 125  i : 0  Loss : 4.572350025177002
#   epoch : 126  i : 0  Loss : 4.260125160217285
#   epoch : 127  i : 0  Loss : 4.281487464904785
#   epoch : 128  i : 0  Loss : 4.247518539428711
#   epoch : 129  i : 0  Loss : 3.9470772743225098
#   epoch : 130  i : 0  Loss : 4.079244136810303
# epoch :130 KNN Accuracy : 0.6326114649681529
#   epoch : 131  i : 0  Loss : 4.020140647888184
#   epoch : 132  i : 0  Loss : 4.3238677978515625
#   epoch : 133  i : 0  Loss : 3.5997185707092285
#   epoch : 134  i : 0  Loss : 3.8641390800476074
#   epoch : 135  i : 0  Loss : 3.838301658630371
#   epoch : 136  i : 0  Loss : 3.870168447494507
#   epoch : 137  i : 0  Loss : 4.040695667266846
#   epoch : 138  i : 0  Loss : 3.7114615440368652
#   epoch : 139  i : 0  Loss : 3.548166036605835
#   epoch : 140  i : 0  Loss : 3.5761399269104004
# epoch :140 KNN Accuracy : 0.6445859872611465
#   epoch : 141  i : 0  Loss : 3.673448324203491
#   epoch : 142  i : 0  Loss : 3.5994153022766113
#   epoch : 143  i : 0  Loss : 3.5401878356933594
#   epoch : 144  i : 0  Loss : 3.5843989849090576
#   epoch : 145  i : 0  Loss : 3.5903429985046387
#   epoch : 146  i : 0  Loss : 3.374856948852539
#   epoch : 147  i : 0  Loss : 3.276718854904175
#   epoch : 148  i : 0  Loss : 3.3672759532928467
#   epoch : 149  i : 0  Loss : 3.48837947845459

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.01)
n_epochs = 50
start_epoch = 150
best_loss = 3.4
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 10)
# Out:
#   epoch : 150  i : 0  Loss : 3.5474050045013428
# epoch :150 KNN Accuracy : 0.660891719745223
#   epoch : 151  i : 0  Loss : 3.4862780570983887
#   epoch : 152  i : 0  Loss : 3.3241653442382812
#   epoch : 153  i : 0  Loss : 3.400827169418335
#   epoch : 154  i : 0  Loss : 3.2651419639587402
#   epoch : 155  i : 0  Loss : 3.365139961242676
#   epoch : 156  i : 0  Loss : 3.2948503494262695
#   epoch : 157  i : 0  Loss : 3.3898301124572754
#   epoch : 158  i : 0  Loss : 3.340912342071533
#   epoch : 159  i : 0  Loss : 3.5738320350646973
#   epoch : 160  i : 0  Loss : 3.201122999191284
# epoch :160 KNN Accuracy : 0.6759235668789809
#   epoch : 161  i : 0  Loss : 3.5490455627441406
#   epoch : 162  i : 0  Loss : 3.3544507026672363
#   epoch : 163  i : 0  Loss : 3.134982109069824
#   epoch : 164  i : 0  Loss : 3.085092306137085
#   epoch : 165  i : 0  Loss : 3.251201629638672
#   epoch : 166  i : 0  Loss : 3.2641971111297607
#   epoch : 167  i : 0  Loss : 3.3597631454467773
#   epoch : 168  i : 0  Loss : 2.8766307830810547
#   epoch : 169  i : 0  Loss : 3.057391881942749
#   epoch : 170  i : 0  Loss : 2.9818363189697266
# epoch :170 KNN Accuracy : 0.6820382165605096
#   epoch : 171  i : 0  Loss : 3.207152843475342
#   epoch : 172  i : 0  Loss : 3.2570111751556396
#   epoch : 173  i : 0  Loss : 3.074558734893799
#   epoch : 174  i : 0  Loss : 3.1367156505584717
#   epoch : 175  i : 0  Loss : 3.1580286026000977
#   epoch : 176  i : 0  Loss : 3.11933970451355
#   epoch : 177  i : 0  Loss : 2.906972885131836
#   epoch : 178  i : 0  Loss : 3.080441474914551
#   epoch : 179  i : 0  Loss : 2.784404754638672
#   epoch : 180  i : 0  Loss : 3.0978050231933594
# epoch :180 KNN Accuracy : 0.6838216560509555
#   epoch : 181  i : 0  Loss : 3.0903987884521484
#   epoch : 182  i : 0  Loss : 2.990365982055664
#   epoch : 183  i : 0  Loss : 3.0175857543945312
#   epoch : 184  i : 0  Loss : 2.941556692123413
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-b8353a1a14bd> in <cell line: 6>()
#       4 start_epoch = 150
#       5 best_loss = 3.4
# ----> 6 student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 10)
#
# <ipython-input-14-87b2bb4ffd5b> in train_Dino(best_loss, n_epochs, start_epoch, student, teacher, optimizer, loss_inst, validate_every)
#       5   for e in range(n_epochs):
#       6     student.train()
# ----> 7     for i, (images, _) in enumerate(data_loader_train_aug):
#       8
#       9         images = [img.to(device) for img in images]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1343             else:
#    1344                 del self._task_info[idx]
# -> 1345                 return self._process_data(data)
#    1346
#    1347     def _try_put_index(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1369         self._try_put_index()
#    1370         if isinstance(data, ExceptionWrapper):
# -> 1371             data.reraise()
#    1372         return data
#    1373
#
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py in reraise(self)
#     692             # instantiate since we don't know how to
#     693             raise RuntimeError(msg) from None
# --> 694         raise exception
#     695
#     696
#
# FileNotFoundError: Caught FileNotFoundError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 229, in __getitem__
#     sample = self.loader(path)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 268, in default_loader
#     return pil_loader(path)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py", line 246, in pil_loader
#     with open(path, "rb") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/imagenette2-320/train/n03000684/n03000684_27164.JPEG'

# %%
lr = 0.001 * batch_size / 256
optimizer = torch.optim.AdamW(student.parameters(),lr=lr,weight_decay=0.01)
n_epochs = 50
start_epoch = 180
best_loss = 3
student = train_Dino(best_loss,n_epochs,start_epoch,student,teacher,optimizer,loss_inst,validate_every = 10)
# Out:
#   epoch : 180  i : 0  Loss : 2.813631057739258
# epoch :180 KNN Accuracy : 0.6963057324840765
#   epoch : 181  i : 0  Loss : 2.880256175994873
#   epoch : 182  i : 0  Loss : 2.753526210784912
#   epoch : 183  i : 0  Loss : 2.6740455627441406
#   epoch : 184  i : 0  Loss : 2.647549867630005
#   epoch : 185  i : 0  Loss : 2.806070327758789
#   epoch : 186  i : 0  Loss : 2.674097776412964
#   epoch : 187  i : 0  Loss : 2.588306427001953
#   epoch : 188  i : 0  Loss : 2.969336986541748
#   epoch : 189  i : 0  Loss : 2.6850335597991943
#   epoch : 190  i : 0  Loss : 2.6343657970428467
# epoch :190 KNN Accuracy : 0.6991082802547771
#   epoch : 191  i : 0  Loss : 2.8266971111297607
#   epoch : 192  i : 0  Loss : 2.51401948928833
#   epoch : 193  i : 0  Loss : 2.8059165477752686
#   epoch : 194  i : 0  Loss : 2.688098669052124
#   epoch : 195  i : 0  Loss : 2.662720203399658
#   epoch : 196  i : 0  Loss : 2.736356735229492
#   epoch : 197  i : 0  Loss : 2.709721565246582
#   epoch : 198  i : 0  Loss : 2.713698387145996
#   epoch : 199  i : 0  Loss : 2.6750869750976562
#   epoch : 200  i : 0  Loss : 2.771254301071167
# epoch :200 KNN Accuracy : 0.7067515923566879
#   epoch : 201  i : 0  Loss : 2.561798334121704
#   epoch : 202  i : 0  Loss : 2.6252145767211914
#   epoch : 203  i : 0  Loss : 2.6356592178344727
#   epoch : 204  i : 0  Loss : 2.6406655311584473
#   epoch : 205  i : 0  Loss : 2.73175311088562
#   epoch : 206  i : 0  Loss : 2.422947406768799
#   epoch : 207  i : 0  Loss : 2.6288301944732666
#   epoch : 208  i : 0  Loss : 2.620731830596924
#   epoch : 209  i : 0  Loss : 2.665414333343506
#   epoch : 210  i : 0  Loss : 2.4800519943237305
# epoch :210 KNN Accuracy : 0.6973248407643312
#   epoch : 211  i : 0  Loss : 2.442530393600464
#   epoch : 212  i : 0  Loss : 2.6704001426696777
#   epoch : 213  i : 0  Loss : 2.575003147125244
#   epoch : 214  i : 0  Loss : 2.576296329498291
#   epoch : 215  i : 0  Loss : 2.564352512359619
#   epoch : 216  i : 0  Loss : 2.5157532691955566
#   epoch : 217  i : 0  Loss : 2.462550640106201
#   epoch : 218  i : 0  Loss : 2.301701307296753
#   epoch : 219  i : 0  Loss : 2.5531864166259766
#   epoch : 220  i : 0  Loss : 2.3869075775146484
# epoch :220 KNN Accuracy : 0.7070063694267515
#   epoch : 221  i : 0  Loss : 2.312187671661377
#   epoch : 222  i : 0  Loss : 2.412994623184204
#   epoch : 223  i : 0  Loss : 2.474475383758545
#   epoch : 224  i : 0  Loss : 2.2318320274353027
#   epoch : 225  i : 0  Loss : 2.5672988891601562
#   epoch : 226  i : 0  Loss : 2.443657398223877
#   epoch : 227  i : 0  Loss : 2.355119228363037
#   epoch : 228  i : 0  Loss : 2.5086236000061035
#   epoch : 229  i : 0  Loss : 2.29530930519104

# %% [markdown]
# # KNN ACCURACY = 70.7 %

# %% [markdown]
# ## TRANSFER LEARNING/FINETUNING USING DINO SSL MODEL

# %%
class dino_resnet(nn.Module):

    def __init__(self,num_classes,student,freeze):

        super(dino_resnet, self).__init__()
        self.num_classes = num_classes
        self.encoder = student.backbone

        if freeze:
          for p in self.encoder.parameters():
            p.requires_grad = False
        else:
          for p in self.encoder.parameters():
            p.requires_grad = True

        self.activation = nn.ReLU()
        self.classifier = nn.Linear(1000,num_classes)

    def forward(self, x):

        x = self.encoder(x)
        x =  self.activation(x)
        x = self.classifier(x)

        return x

# %%
class dino_vit(nn.Module):
  def __init__(self,num_classes,student,freeze):
    super(dino_vit, self).__init__()
    self.num_classes = num_classes
    self.encoder = student.backbone

    if freeze:
      for p in self.encoder.parameters():
        p.requires_grad = False
    else:
      for p in self.encoder.parameters():
        p.requires_grad = True

    self.activation = nn.ReLU()
    self.classifier = nn.Linear(384,num_classes)

  def forward(self, x):

      x = self.encoder(x)
      x =  self.activation(x)
      x = self.classifier(x)

      return x

# %% [markdown]
# ## RESNET DINO SSL

# %%
device = torch.device("cuda" if torch.cuda.is_available else "cpu")
dino_model = dino_resnet(num_classes=10,student = student,freeze = True)
# model = resnet(num_classes = 10)
dino_model = dino_model.to(device)
criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(dino_model.parameters(),lr = 0.001)

# %%
optimizer_supervised = torch.optim.SGD(dino_model.parameters(), lr= 0.0001,momentum  = 0.9)
a_,b_,c_,d_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer_supervised,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.343250036239624, Correct Predictions(batch) : 17/128
# idx : 5 , Current Loss(batch) : 2.3718113899230957, Correct Predictions(batch) : 10/128
# idx : 10 , Current Loss(batch) : 2.373744010925293, Correct Predictions(batch) : 10/128
# Epoch: 0, Loss (per batch) : 2.3722, Accuracy: 0.1051
# Test Accuracy: 0.1083
# Average Test Loss : 2.3389
# idx : 0 , Current Loss(batch) : 2.3546769618988037, Correct Predictions(batch) : 17/128
# idx : 5 , Current Loss(batch) : 2.2986247539520264, Correct Predictions(batch) : 20/128
# idx : 10 , Current Loss(batch) : 2.353295087814331, Correct Predictions(batch) : 13/128
# Epoch: 1, Loss (per batch) : 2.3187, Accuracy: 0.1183
# Test Accuracy: 0.1274
# Average Test Loss : 2.2828
# idx : 0 , Current Loss(batch) : 2.2513833045959473, Correct Predictions(batch) : 23/128
# idx : 5 , Current Loss(batch) : 2.270355463027954, Correct Predictions(batch) : 23/128
# idx : 10 , Current Loss(batch) : 2.2247743606567383, Correct Predictions(batch) : 21/128
# Epoch: 2, Loss (per batch) : 2.2560, Accuracy: 0.1616
# Test Accuracy: 0.1822
# Average Test Loss : 2.2225
# idx : 0 , Current Loss(batch) : 2.257181167602539, Correct Predictions(batch) : 22/128
# idx : 5 , Current Loss(batch) : 2.196798801422119, Correct Predictions(batch) : 26/128
# idx : 10 , Current Loss(batch) : 2.1891977787017822, Correct Predictions(batch) : 27/128
# Epoch: 3, Loss (per batch) : 2.1949, Accuracy: 0.2250
# Test Accuracy: 0.2331
# Average Test Loss : 2.1626
# idx : 0 , Current Loss(batch) : 2.144874095916748, Correct Predictions(batch) : 31/128
# idx : 5 , Current Loss(batch) : 2.1445837020874023, Correct Predictions(batch) : 38/128
# idx : 10 , Current Loss(batch) : 2.131960153579712, Correct Predictions(batch) : 43/128
# Epoch: 4, Loss (per batch) : 2.1385, Accuracy: 0.2921
# Test Accuracy: 0.3032
# Average Test Loss : 2.1170
# idx : 0 , Current Loss(batch) : 2.106851816177368, Correct Predictions(batch) : 37/128
# idx : 5 , Current Loss(batch) : 2.0945940017700195, Correct Predictions(batch) : 49/128
# idx : 10 , Current Loss(batch) : 2.0591821670532227, Correct Predictions(batch) : 53/128
# Epoch: 5, Loss (per batch) : 2.0881, Accuracy: 0.3539
# Test Accuracy: 0.3745
# Average Test Loss : 2.0789
# idx : 0 , Current Loss(batch) : 2.0536768436431885, Correct Predictions(batch) : 48/128
# idx : 5 , Current Loss(batch) : 2.031186103820801, Correct Predictions(batch) : 54/128
# idx : 10 , Current Loss(batch) : 2.039875030517578, Correct Predictions(batch) : 49/128
# Epoch: 6, Loss (per batch) : 2.0387, Accuracy: 0.4231
# Test Accuracy: 0.4459
# Average Test Loss : 2.0179
# idx : 0 , Current Loss(batch) : 2.019794464111328, Correct Predictions(batch) : 63/128
# idx : 5 , Current Loss(batch) : 1.9799628257751465, Correct Predictions(batch) : 67/128
# idx : 10 , Current Loss(batch) : 1.9970786571502686, Correct Predictions(batch) : 60/128
# Epoch: 7, Loss (per batch) : 1.9902, Accuracy: 0.4765
# Test Accuracy: 0.4955
# Average Test Loss : 1.9875
# idx : 0 , Current Loss(batch) : 1.9440873861312866, Correct Predictions(batch) : 68/128
# idx : 5 , Current Loss(batch) : 1.9177290201187134, Correct Predictions(batch) : 68/128
# idx : 10 , Current Loss(batch) : 1.9071030616760254, Correct Predictions(batch) : 72/128
# Epoch: 8, Loss (per batch) : 1.9490, Accuracy: 0.5061
# Test Accuracy: 0.5338
# Average Test Loss : 1.9580
# idx : 0 , Current Loss(batch) : 1.932917833328247, Correct Predictions(batch) : 63/128
# idx : 5 , Current Loss(batch) : 1.9300802946090698, Correct Predictions(batch) : 71/128
# idx : 10 , Current Loss(batch) : 1.900326132774353, Correct Predictions(batch) : 66/128
# Epoch: 9, Loss (per batch) : 1.9040, Accuracy: 0.5415
# Test Accuracy: 0.5605
# Average Test Loss : 1.8976
# idx : 0 , Current Loss(batch) : 1.8810654878616333, Correct Predictions(batch) : 71/128
# idx : 5 , Current Loss(batch) : 1.8698047399520874, Correct Predictions(batch) : 73/128
# idx : 10 , Current Loss(batch) : 1.857400894165039, Correct Predictions(batch) : 73/128
# Epoch: 10, Loss (per batch) : 1.8663, Accuracy: 0.5658
# Test Accuracy: 0.5720
# Average Test Loss : 1.8604
# idx : 0 , Current Loss(batch) : 1.8499096632003784, Correct Predictions(batch) : 78/128
# idx : 5 , Current Loss(batch) : 1.8487828969955444, Correct Predictions(batch) : 73/128
# idx : 10 , Current Loss(batch) : 1.7958117723464966, Correct Predictions(batch) : 80/128
# Epoch: 11, Loss (per batch) : 1.8252, Accuracy: 0.5843
# Test Accuracy: 0.5936
# Average Test Loss : 1.8168
# idx : 0 , Current Loss(batch) : 1.7646530866622925, Correct Predictions(batch) : 78/128
# idx : 5 , Current Loss(batch) : 1.7530491352081299, Correct Predictions(batch) : 80/128
# idx : 10 , Current Loss(batch) : 1.8149852752685547, Correct Predictions(batch) : 75/128
# Epoch: 12, Loss (per batch) : 1.7883, Accuracy: 0.6096
# Test Accuracy: 0.6051
# Average Test Loss : 1.8030
# idx : 0 , Current Loss(batch) : 1.749336838722229, Correct Predictions(batch) : 82/128
# idx : 5 , Current Loss(batch) : 1.715341329574585, Correct Predictions(batch) : 88/128
# idx : 10 , Current Loss(batch) : 1.7505507469177246, Correct Predictions(batch) : 75/128
# Epoch: 13, Loss (per batch) : 1.7534, Accuracy: 0.6212
# Test Accuracy: 0.6217
# Average Test Loss : 1.7850
# idx : 0 , Current Loss(batch) : 1.7123069763183594, Correct Predictions(batch) : 85/128
# idx : 5 , Current Loss(batch) : 1.742120623588562, Correct Predictions(batch) : 86/128
# idx : 10 , Current Loss(batch) : 1.6766606569290161, Correct Predictions(batch) : 86/128
# Epoch: 14, Loss (per batch) : 1.7176, Accuracy: 0.6408
# Test Accuracy: 0.6318
# Average Test Loss : 1.7428
# idx : 0 , Current Loss(batch) : 1.7800312042236328, Correct Predictions(batch) : 72/128
# idx : 5 , Current Loss(batch) : 1.6364636421203613, Correct Predictions(batch) : 91/128
# idx : 10 , Current Loss(batch) : 1.6775569915771484, Correct Predictions(batch) : 80/128
# Epoch: 15, Loss (per batch) : 1.6867, Accuracy: 0.6440
# Test Accuracy: 0.6331
# Average Test Loss : 1.7005
# idx : 0 , Current Loss(batch) : 1.6578203439712524, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.6817152500152588, Correct Predictions(batch) : 75/128
# idx : 10 , Current Loss(batch) : 1.6954518556594849, Correct Predictions(batch) : 78/128
# Epoch: 16, Loss (per batch) : 1.6570, Accuracy: 0.6572
# Test Accuracy: 0.6433
# Average Test Loss : 1.6908
# idx : 0 , Current Loss(batch) : 1.6467968225479126, Correct Predictions(batch) : 80/128
# idx : 5 , Current Loss(batch) : 1.6467517614364624, Correct Predictions(batch) : 85/128
# idx : 10 , Current Loss(batch) : 1.607640027999878, Correct Predictions(batch) : 91/128
# Epoch: 17, Loss (per batch) : 1.6261, Accuracy: 0.6719
# Test Accuracy: 0.6484
# Average Test Loss : 1.6703
# idx : 0 , Current Loss(batch) : 1.592768907546997, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.5955711603164673, Correct Predictions(batch) : 89/128
# idx : 10 , Current Loss(batch) : 1.6042593717575073, Correct Predictions(batch) : 83/128
# Epoch: 18, Loss (per batch) : 1.5982, Accuracy: 0.6725
# Test Accuracy: 0.6573
# Average Test Loss : 1.6131
# idx : 0 , Current Loss(batch) : 1.5668394565582275, Correct Predictions(batch) : 85/128
# idx : 5 , Current Loss(batch) : 1.5941461324691772, Correct Predictions(batch) : 81/128
# idx : 10 , Current Loss(batch) : 1.5927979946136475, Correct Predictions(batch) : 86/128
# Epoch: 19, Loss (per batch) : 1.5706, Accuracy: 0.6767
# Test Accuracy: 0.6662
# Average Test Loss : 1.6118
# idx : 0 , Current Loss(batch) : 1.5380243062973022, Correct Predictions(batch) : 96/128
# idx : 5 , Current Loss(batch) : 1.4939658641815186, Correct Predictions(batch) : 91/128
# idx : 10 , Current Loss(batch) : 1.5525836944580078, Correct Predictions(batch) : 89/128
# Epoch: 20, Loss (per batch) : 1.5466, Accuracy: 0.6852
# Test Accuracy: 0.6713
# Average Test Loss : 1.5867
# idx : 0 , Current Loss(batch) : 1.4849789142608643, Correct Predictions(batch) : 94/128
# idx : 5 , Current Loss(batch) : 1.5406543016433716, Correct Predictions(batch) : 90/128
# idx : 10 , Current Loss(batch) : 1.5090311765670776, Correct Predictions(batch) : 89/128
# Epoch: 21, Loss (per batch) : 1.5192, Accuracy: 0.6931
# Test Accuracy: 0.6777
# Average Test Loss : 1.5480
# idx : 0 , Current Loss(batch) : 1.5549066066741943, Correct Predictions(batch) : 76/128
# idx : 5 , Current Loss(batch) : 1.494961142539978, Correct Predictions(batch) : 89/128
# idx : 10 , Current Loss(batch) : 1.5600554943084717, Correct Predictions(batch) : 85/128
# Epoch: 22, Loss (per batch) : 1.4996, Accuracy: 0.6968
# Test Accuracy: 0.6815
# Average Test Loss : 1.5043
# idx : 0 , Current Loss(batch) : 1.5262268781661987, Correct Predictions(batch) : 90/128
# idx : 5 , Current Loss(batch) : 1.4339706897735596, Correct Predictions(batch) : 91/128
# idx : 10 , Current Loss(batch) : 1.4517827033996582, Correct Predictions(batch) : 88/128
# Epoch: 23, Loss (per batch) : 1.4763, Accuracy: 0.6978
# Test Accuracy: 0.6841
# Average Test Loss : 1.5041
# idx : 0 , Current Loss(batch) : 1.4939619302749634, Correct Predictions(batch) : 87/128
# idx : 5 , Current Loss(batch) : 1.3838785886764526, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.4653054475784302, Correct Predictions(batch) : 88/128
# Epoch: 24, Loss (per batch) : 1.4535, Accuracy: 0.6999
# Test Accuracy: 0.6866
# Average Test Loss : 1.4921
# idx : 0 , Current Loss(batch) : 1.4262598752975464, Correct Predictions(batch) : 98/128
# idx : 5 , Current Loss(batch) : 1.4351993799209595, Correct Predictions(batch) : 91/128
# idx : 10 , Current Loss(batch) : 1.3499062061309814, Correct Predictions(batch) : 96/128
# Epoch: 25, Loss (per batch) : 1.4335, Accuracy: 0.7063
# Test Accuracy: 0.6892
# Average Test Loss : 1.4590
# idx : 0 , Current Loss(batch) : 1.5167479515075684, Correct Predictions(batch) : 87/128
# idx : 5 , Current Loss(batch) : 1.3329153060913086, Correct Predictions(batch) : 99/128
# idx : 10 , Current Loss(batch) : 1.3978925943374634, Correct Predictions(batch) : 89/128
# Epoch: 26, Loss (per batch) : 1.4110, Accuracy: 0.7021
# Test Accuracy: 0.6879
# Average Test Loss : 1.4704
# idx : 0 , Current Loss(batch) : 1.3768386840820312, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 1.3951958417892456, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.3783401250839233, Correct Predictions(batch) : 92/128
# Epoch: 27, Loss (per batch) : 1.3931, Accuracy: 0.7147
# Test Accuracy: 0.6943
# Average Test Loss : 1.4324
# idx : 0 , Current Loss(batch) : 1.3368180990219116, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.4076440334320068, Correct Predictions(batch) : 86/128
# idx : 10 , Current Loss(batch) : 1.4058964252471924, Correct Predictions(batch) : 87/128
# Epoch: 28, Loss (per batch) : 1.3735, Accuracy: 0.7132
# Test Accuracy: 0.7032
# Average Test Loss : 1.4408
# idx : 0 , Current Loss(batch) : 1.4271740913391113, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.381667971611023, Correct Predictions(batch) : 88/128
# idx : 10 , Current Loss(batch) : 1.3988897800445557, Correct Predictions(batch) : 94/128
# Epoch: 29, Loss (per batch) : 1.3592, Accuracy: 0.7147
# Test Accuracy: 0.7032
# Average Test Loss : 1.3781
# idx : 0 , Current Loss(batch) : 1.4413155317306519, Correct Predictions(batch) : 87/128
# idx : 5 , Current Loss(batch) : 1.3752251863479614, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.3470710515975952, Correct Predictions(batch) : 92/128
# Epoch: 30, Loss (per batch) : 1.3399, Accuracy: 0.7200
# Test Accuracy: 0.7083
# Average Test Loss : 1.3843
# idx : 0 , Current Loss(batch) : 1.309251308441162, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 1.3788706064224243, Correct Predictions(batch) : 86/128
# idx : 10 , Current Loss(batch) : 1.3411155939102173, Correct Predictions(batch) : 88/128
# Epoch: 31, Loss (per batch) : 1.3244, Accuracy: 0.7179
# Test Accuracy: 0.7070
# Average Test Loss : 1.3610
# idx : 0 , Current Loss(batch) : 1.2267416715621948, Correct Predictions(batch) : 98/128
# idx : 5 , Current Loss(batch) : 1.2578579187393188, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 1.4049663543701172, Correct Predictions(batch) : 84/128
# Epoch: 32, Loss (per batch) : 1.3082, Accuracy: 0.7258
# Test Accuracy: 0.7121
# Average Test Loss : 1.3251
# idx : 0 , Current Loss(batch) : 1.355839490890503, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.2245475053787231, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.280246376991272, Correct Predictions(batch) : 94/128
# Epoch: 33, Loss (per batch) : 1.2945, Accuracy: 0.7258
# Test Accuracy: 0.7108
# Average Test Loss : 1.3359
# idx : 0 , Current Loss(batch) : 1.2410646677017212, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 1.1720619201660156, Correct Predictions(batch) : 104/128
# idx : 10 , Current Loss(batch) : 1.2227226495742798, Correct Predictions(batch) : 97/128
# Epoch: 34, Loss (per batch) : 1.2767, Accuracy: 0.7290
# Test Accuracy: 0.7146
# Average Test Loss : 1.3249
# idx : 0 , Current Loss(batch) : 1.2168550491333008, Correct Predictions(batch) : 99/128
# idx : 5 , Current Loss(batch) : 1.3213948011398315, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 1.2215276956558228, Correct Predictions(batch) : 97/128
# Epoch: 35, Loss (per batch) : 1.2668, Accuracy: 0.7306
# Test Accuracy: 0.7134
# Average Test Loss : 1.3185
# idx : 0 , Current Loss(batch) : 1.171715497970581, Correct Predictions(batch) : 100/128
# idx : 5 , Current Loss(batch) : 1.2619845867156982, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 1.222712516784668, Correct Predictions(batch) : 99/128
# Epoch: 36, Loss (per batch) : 1.2500, Accuracy: 0.7353
# Test Accuracy: 0.7185
# Average Test Loss : 1.2921
# idx : 0 , Current Loss(batch) : 1.266115427017212, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.2957042455673218, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.2345565557479858, Correct Predictions(batch) : 95/128
# Epoch: 37, Loss (per batch) : 1.2362, Accuracy: 0.7343
# Test Accuracy: 0.7172
# Average Test Loss : 1.2716
# idx : 0 , Current Loss(batch) : 1.2252992391586304, Correct Predictions(batch) : 96/128
# idx : 5 , Current Loss(batch) : 1.2508151531219482, Correct Predictions(batch) : 96/128
# idx : 10 , Current Loss(batch) : 1.1304765939712524, Correct Predictions(batch) : 100/128
# Epoch: 38, Loss (per batch) : 1.2249, Accuracy: 0.7390
# Test Accuracy: 0.7197
# Average Test Loss : 1.2674
# idx : 0 , Current Loss(batch) : 1.1571167707443237, Correct Predictions(batch) : 99/128
# idx : 5 , Current Loss(batch) : 1.1856756210327148, Correct Predictions(batch) : 99/128
# idx : 10 , Current Loss(batch) : 1.236196756362915, Correct Predictions(batch) : 92/128
# Epoch: 39, Loss (per batch) : 1.2148, Accuracy: 0.7364
# Test Accuracy: 0.7197
# Average Test Loss : 1.2486
# idx : 0 , Current Loss(batch) : 1.2272099256515503, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 1.1515758037567139, Correct Predictions(batch) : 98/128
# idx : 10 , Current Loss(batch) : 1.1979995965957642, Correct Predictions(batch) : 91/128
# Epoch: 40, Loss (per batch) : 1.2025, Accuracy: 0.7353
# Test Accuracy: 0.7223
# Average Test Loss : 1.2200
# idx : 0 , Current Loss(batch) : 1.1958576440811157, Correct Predictions(batch) : 96/128
# idx : 5 , Current Loss(batch) : 1.1620526313781738, Correct Predictions(batch) : 101/128
# idx : 10 , Current Loss(batch) : 1.2518125772476196, Correct Predictions(batch) : 86/128
# Epoch: 41, Loss (per batch) : 1.1912, Accuracy: 0.7353
# Test Accuracy: 0.7236
# Average Test Loss : 1.2503
# idx : 0 , Current Loss(batch) : 1.2129600048065186, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 1.126815915107727, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 1.1440895795822144, Correct Predictions(batch) : 101/128
# Epoch: 42, Loss (per batch) : 1.1785, Accuracy: 0.7359
# Test Accuracy: 0.7248
# Average Test Loss : 1.2552
# idx : 0 , Current Loss(batch) : 1.1122550964355469, Correct Predictions(batch) : 94/128
# idx : 5 , Current Loss(batch) : 1.1841791868209839, Correct Predictions(batch) : 91/128
# idx : 10 , Current Loss(batch) : 1.2327967882156372, Correct Predictions(batch) : 92/128
# Epoch: 43, Loss (per batch) : 1.1726, Accuracy: 0.7433
# Test Accuracy: 0.7287
# Average Test Loss : 1.2427
# idx : 0 , Current Loss(batch) : 1.1398181915283203, Correct Predictions(batch) : 97/128
# idx : 5 , Current Loss(batch) : 1.1332868337631226, Correct Predictions(batch) : 99/128
# idx : 10 , Current Loss(batch) : 1.1714973449707031, Correct Predictions(batch) : 86/128
# Epoch: 44, Loss (per batch) : 1.1591, Accuracy: 0.7427
# Test Accuracy: 0.7287
# Average Test Loss : 1.2336
# idx : 0 , Current Loss(batch) : 1.1781566143035889, Correct Predictions(batch) : 92/128
# idx : 5 , Current Loss(batch) : 1.2042713165283203, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 1.1264424324035645, Correct Predictions(batch) : 91/128
# Epoch: 45, Loss (per batch) : 1.1517, Accuracy: 0.7412
# Test Accuracy: 0.7299
# Average Test Loss : 1.2041
# idx : 0 , Current Loss(batch) : 1.1538726091384888, Correct Predictions(batch) : 92/128
# idx : 5 , Current Loss(batch) : 1.1214371919631958, Correct Predictions(batch) : 93/128
# idx : 10 , Current Loss(batch) : 1.1395347118377686, Correct Predictions(batch) : 94/128
# Epoch: 46, Loss (per batch) : 1.1400, Accuracy: 0.7422
# Test Accuracy: 0.7312
# Average Test Loss : 1.1754
# idx : 0 , Current Loss(batch) : 1.2799406051635742, Correct Predictions(batch) : 85/128
# idx : 5 , Current Loss(batch) : 1.2333945035934448, Correct Predictions(batch) : 86/128
# idx : 10 , Current Loss(batch) : 1.0570145845413208, Correct Predictions(batch) : 104/128
# Epoch: 47, Loss (per batch) : 1.1312, Accuracy: 0.7464
# Test Accuracy: 0.7274
# Average Test Loss : 1.1499
# idx : 0 , Current Loss(batch) : 1.0752073526382446, Correct Predictions(batch) : 102/128
# idx : 5 , Current Loss(batch) : 1.0278323888778687, Correct Predictions(batch) : 106/128
# idx : 10 , Current Loss(batch) : 1.1516863107681274, Correct Predictions(batch) : 96/128
# Epoch: 48, Loss (per batch) : 1.1209, Accuracy: 0.7480
# Test Accuracy: 0.7312
# Average Test Loss : 1.1929
# idx : 0 , Current Loss(batch) : 1.0473424196243286, Correct Predictions(batch) : 101/128
# idx : 5 , Current Loss(batch) : 1.0917692184448242, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.063826560974121, Correct Predictions(batch) : 100/128
# Epoch: 49, Loss (per batch) : 1.1140, Accuracy: 0.7459
# Test Accuracy: 0.7325
# Average Test Loss : 1.1647

# %%
optimizer_supervised = torch.optim.SGD(dino_model.parameters(), lr= 0.0001,momentum  = 0.9)
a_,b_,c_,d_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer_supervised,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 1.2266178131103516, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.131690263748169, Correct Predictions(batch) : 101/128
# idx : 10 , Current Loss(batch) : 1.065451979637146, Correct Predictions(batch) : 98/128
# Epoch: 0, Loss (per batch) : 1.1060, Accuracy: 0.7501
# Test Accuracy: 0.7299
# Average Test Loss : 1.1807
# idx : 0 , Current Loss(batch) : 1.0703883171081543, Correct Predictions(batch) : 97/128
# idx : 5 , Current Loss(batch) : 1.111220121383667, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.0724796056747437, Correct Predictions(batch) : 99/128
# Epoch: 1, Loss (per batch) : 1.0971, Accuracy: 0.7549
# Test Accuracy: 0.7350
# Average Test Loss : 1.1620
# idx : 0 , Current Loss(batch) : 1.1764750480651855, Correct Predictions(batch) : 90/128
# idx : 5 , Current Loss(batch) : 1.0622411966323853, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 1.034711480140686, Correct Predictions(batch) : 101/128
# Epoch: 2, Loss (per batch) : 1.0921, Accuracy: 0.7517
# Test Accuracy: 0.7338
# Average Test Loss : 1.1787
# idx : 0 , Current Loss(batch) : 1.0822818279266357, Correct Predictions(batch) : 97/128
# idx : 5 , Current Loss(batch) : 1.0013327598571777, Correct Predictions(batch) : 105/128
# idx : 10 , Current Loss(batch) : 1.0624322891235352, Correct Predictions(batch) : 98/128
# Epoch: 3, Loss (per batch) : 1.0833, Accuracy: 0.7528
# Test Accuracy: 0.7350
# Average Test Loss : 1.1474
# idx : 0 , Current Loss(batch) : 1.028031349182129, Correct Predictions(batch) : 102/128
# idx : 5 , Current Loss(batch) : 1.1201814413070679, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.158844232559204, Correct Predictions(batch) : 88/128
# Epoch: 4, Loss (per batch) : 1.0720, Accuracy: 0.7570
# Test Accuracy: 0.7338
# Average Test Loss : 1.1638
# idx : 0 , Current Loss(batch) : 1.0838208198547363, Correct Predictions(batch) : 94/128
# idx : 5 , Current Loss(batch) : 1.0599910020828247, Correct Predictions(batch) : 101/128
# idx : 10 , Current Loss(batch) : 1.0281282663345337, Correct Predictions(batch) : 101/128
# Epoch: 5, Loss (per batch) : 1.0722, Accuracy: 0.7602
# Test Accuracy: 0.7363
# Average Test Loss : 1.0793
# idx : 0 , Current Loss(batch) : 1.1348026990890503, Correct Predictions(batch) : 94/128
# idx : 5 , Current Loss(batch) : 1.0344034433364868, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 1.034625768661499, Correct Predictions(batch) : 99/128
# Epoch: 6, Loss (per batch) : 1.0643, Accuracy: 0.7575
# Test Accuracy: 0.7389
# Average Test Loss : 1.1018
# idx : 0 , Current Loss(batch) : 0.9450500011444092, Correct Predictions(batch) : 106/128
# idx : 5 , Current Loss(batch) : 1.0254796743392944, Correct Predictions(batch) : 98/128
# idx : 10 , Current Loss(batch) : 1.1106207370758057, Correct Predictions(batch) : 90/128
# Epoch: 7, Loss (per batch) : 1.0529, Accuracy: 0.7581
# Test Accuracy: 0.7376
# Average Test Loss : 1.1099
# idx : 0 , Current Loss(batch) : 0.9260645508766174, Correct Predictions(batch) : 99/128
# idx : 5 , Current Loss(batch) : 1.0015759468078613, Correct Predictions(batch) : 102/128
# idx : 10 , Current Loss(batch) : 1.0351197719573975, Correct Predictions(batch) : 100/128
# Epoch: 8, Loss (per batch) : 1.0525, Accuracy: 0.7554
# Test Accuracy: 0.7401
# Average Test Loss : 1.1685
# idx : 0 , Current Loss(batch) : 1.1201045513153076, Correct Predictions(batch) : 96/128
# idx : 5 , Current Loss(batch) : 1.0328539609909058, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 0.9720210433006287, Correct Predictions(batch) : 106/128
# Epoch: 9, Loss (per batch) : 1.0423, Accuracy: 0.7602
# Test Accuracy: 0.7389
# Average Test Loss : 1.0904
# idx : 0 , Current Loss(batch) : 0.8995972871780396, Correct Predictions(batch) : 103/128
# idx : 5 , Current Loss(batch) : 1.0834053754806519, Correct Predictions(batch) : 93/128
# idx : 10 , Current Loss(batch) : 1.0351557731628418, Correct Predictions(batch) : 100/128
# Epoch: 10, Loss (per batch) : 1.0353, Accuracy: 0.7575
# Test Accuracy: 0.7401
# Average Test Loss : 1.1008
# idx : 0 , Current Loss(batch) : 1.1102633476257324, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 0.9428521394729614, Correct Predictions(batch) : 102/128
# idx : 10 , Current Loss(batch) : 1.0365785360336304, Correct Predictions(batch) : 98/128
# Epoch: 11, Loss (per batch) : 1.0271, Accuracy: 0.7660
# Test Accuracy: 0.7401
# Average Test Loss : 1.0860
# idx : 0 , Current Loss(batch) : 1.0410529375076294, Correct Predictions(batch) : 92/128
# idx : 5 , Current Loss(batch) : 1.0617313385009766, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 0.9353569746017456, Correct Predictions(batch) : 105/128
# Epoch: 12, Loss (per batch) : 1.0216, Accuracy: 0.7618
# Test Accuracy: 0.7414
# Average Test Loss : 1.1063
# idx : 0 , Current Loss(batch) : 0.9785451889038086, Correct Predictions(batch) : 100/128
# idx : 5 , Current Loss(batch) : 0.9791980981826782, Correct Predictions(batch) : 106/128
# idx : 10 , Current Loss(batch) : 1.0136669874191284, Correct Predictions(batch) : 94/128
# Epoch: 13, Loss (per batch) : 1.0177, Accuracy: 0.7655
# Test Accuracy: 0.7414
# Average Test Loss : 1.0471
# idx : 0 , Current Loss(batch) : 0.9511880874633789, Correct Predictions(batch) : 103/128
# idx : 5 , Current Loss(batch) : 0.9630268812179565, Correct Predictions(batch) : 103/128
# idx : 10 , Current Loss(batch) : 1.0643384456634521, Correct Predictions(batch) : 97/128
# Epoch: 14, Loss (per batch) : 1.0133, Accuracy: 0.7665
# Test Accuracy: 0.7401
# Average Test Loss : 1.0811
# idx : 0 , Current Loss(batch) : 0.9649426937103271, Correct Predictions(batch) : 96/128
# idx : 5 , Current Loss(batch) : 0.9694978594779968, Correct Predictions(batch) : 98/128
# idx : 10 , Current Loss(batch) : 1.0454739332199097, Correct Predictions(batch) : 96/128
# Epoch: 15, Loss (per batch) : 1.0049, Accuracy: 0.7681
# Test Accuracy: 0.7427
# Average Test Loss : 1.0943
# idx : 0 , Current Loss(batch) : 1.015777349472046, Correct Predictions(batch) : 96/128
# idx : 5 , Current Loss(batch) : 0.9104465246200562, Correct Predictions(batch) : 104/128
# idx : 10 , Current Loss(batch) : 0.9399012923240662, Correct Predictions(batch) : 101/128
# Epoch: 16, Loss (per batch) : 0.9978, Accuracy: 0.7686
# Test Accuracy: 0.7439
# Average Test Loss : 1.0488
# idx : 0 , Current Loss(batch) : 0.9548211693763733, Correct Predictions(batch) : 99/128
# idx : 5 , Current Loss(batch) : 0.9921970367431641, Correct Predictions(batch) : 101/128
# idx : 10 , Current Loss(batch) : 0.9180468320846558, Correct Predictions(batch) : 101/128
# Epoch: 17, Loss (per batch) : 0.9893, Accuracy: 0.7776
# Test Accuracy: 0.7439
# Average Test Loss : 1.0519
# idx : 0 , Current Loss(batch) : 1.0198423862457275, Correct Predictions(batch) : 92/128
# idx : 5 , Current Loss(batch) : 0.9658836126327515, Correct Predictions(batch) : 98/128
# idx : 10 , Current Loss(batch) : 0.8804627060890198, Correct Predictions(batch) : 104/128
# Epoch: 18, Loss (per batch) : 0.9879, Accuracy: 0.7660
# Test Accuracy: 0.7439
# Average Test Loss : 1.0236
# idx : 0 , Current Loss(batch) : 0.9896034002304077, Correct Predictions(batch) : 103/128
# idx : 5 , Current Loss(batch) : 1.0206449031829834, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 0.9988256096839905, Correct Predictions(batch) : 97/128
# Epoch: 19, Loss (per batch) : 0.9859, Accuracy: 0.7713
# Test Accuracy: 0.7439
# Average Test Loss : 1.0176
# idx : 0 , Current Loss(batch) : 0.9374973773956299, Correct Predictions(batch) : 98/128
# idx : 5 , Current Loss(batch) : 0.9936296939849854, Correct Predictions(batch) : 93/128
# idx : 10 , Current Loss(batch) : 1.0545790195465088, Correct Predictions(batch) : 96/128
# Epoch: 20, Loss (per batch) : 0.9761, Accuracy: 0.7750
# Test Accuracy: 0.7439
# Average Test Loss : 1.0220
# idx : 0 , Current Loss(batch) : 0.9441573619842529, Correct Predictions(batch) : 105/128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-7c324d8e422d> in <cell line: 2>()
#       1 optimizer_supervised = torch.optim.SGD(dino_model.parameters(), lr= 0.0001,momentum  = 0.9)
# ----> 2 a_,b_,c_,d_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer_supervised,criterion,50)
#
# <ipython-input-17-a79158196d01> in train(train_loader, val_loader, model, optimizer, criterion, num_epochs)
#      42             # label = torch.tensor(label)
#      43             bsz = label.shape[0]
# ---> 44             optimizer.zero_grad()
#      45             img = img.to(device)
#      46             label = label.to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/_compile.py in inner(*args, **kwargs)
#      18     if fn is not None:
#      19
# ---> 20         @functools.wraps(fn)
#      21         def inner(*args, **kwargs):
#      22             import torch._dynamo
#
# KeyboardInterrupt:

# %%
optimizer_supervised = torch.optim.Adam(dino_model.parameters(), lr= 0.001)
a_,b_,c_,d_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer_supervised,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.2249107360839844, Correct Predictions(batch) : 12/128
# idx : 5 , Current Loss(batch) : 0.12002411484718323, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.07858672738075256, Correct Predictions(batch) : 127/128
# Epoch: 0, Loss (per batch) : 0.3747, Accuracy: 0.9033
# Test Accuracy: 0.6599
# Average Test Loss : 1.4702
# idx : 0 , Current Loss(batch) : 0.023073842748999596, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.03469126671552658, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.09047216922044754, Correct Predictions(batch) : 125/128
# Epoch: 1, Loss (per batch) : 0.0935, Accuracy: 0.9709
# Test Accuracy: 0.5121
# Average Test Loss : 3.7539
# idx : 0 , Current Loss(batch) : 0.11606542766094208, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.026564331725239754, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.07669920474290848, Correct Predictions(batch) : 125/128
# Epoch: 2, Loss (per batch) : 0.0728, Accuracy: 0.9773
# Test Accuracy: 0.6178
# Average Test Loss : 2.8990
# idx : 0 , Current Loss(batch) : 0.03841593116521835, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.023984666913747787, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.009163089096546173, Correct Predictions(batch) : 128/128
# Epoch: 3, Loss (per batch) : 0.0621, Accuracy: 0.9794
# Test Accuracy: 0.5427
# Average Test Loss : 3.0103
# idx : 0 , Current Loss(batch) : 0.02309616655111313, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.00442980881780386, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.06797171384096146, Correct Predictions(batch) : 126/128
# Epoch: 4, Loss (per batch) : 0.0479, Accuracy: 0.9852
# Test Accuracy: 0.6726
# Average Test Loss : 1.6938
# idx : 0 , Current Loss(batch) : 0.05753104388713837, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.07884835451841354, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.03124845027923584, Correct Predictions(batch) : 126/128
# Epoch: 5, Loss (per batch) : 0.0640, Accuracy: 0.9773
# Test Accuracy: 0.6089
# Average Test Loss : 2.8155
# idx : 0 , Current Loss(batch) : 0.0025102838408201933, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.05682343989610672, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.007212503347545862, Correct Predictions(batch) : 128/128
# Epoch: 6, Loss (per batch) : 0.0412, Accuracy: 0.9868
# Test Accuracy: 0.6038
# Average Test Loss : 2.4445
# idx : 0 , Current Loss(batch) : 0.029924707487225533, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.03636140003800392, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.008452588692307472, Correct Predictions(batch) : 128/128
# Epoch: 7, Loss (per batch) : 0.0446, Accuracy: 0.9842
# Test Accuracy: 0.6484
# Average Test Loss : 2.3420
# idx : 0 , Current Loss(batch) : 0.012190636247396469, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.03227190300822258, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.01596563309431076, Correct Predictions(batch) : 127/128
# Epoch: 8, Loss (per batch) : 0.0337, Accuracy: 0.9884
# Test Accuracy: 0.6548
# Average Test Loss : 1.9988
# idx : 0 , Current Loss(batch) : 0.048556745052337646, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.05556013435125351, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.07489122450351715, Correct Predictions(batch) : 125/128
# Epoch: 9, Loss (per batch) : 0.0365, Accuracy: 0.9889
# Test Accuracy: 0.6599
# Average Test Loss : 2.0416
# idx : 0 , Current Loss(batch) : 0.012920612469315529, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.03031371906399727, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.05116954445838928, Correct Predictions(batch) : 125/128
# Epoch: 10, Loss (per batch) : 0.0445, Accuracy: 0.9842
# Test Accuracy: 0.6955
# Average Test Loss : 1.6260
# idx : 0 , Current Loss(batch) : 0.005593590438365936, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00283305742777884, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0035603237338364124, Correct Predictions(batch) : 128/128
# Epoch: 11, Loss (per batch) : 0.0262, Accuracy: 0.9931
# Test Accuracy: 0.6662
# Average Test Loss : 1.7549
# idx : 0 , Current Loss(batch) : 0.011018838733434677, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.0071274531073868275, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00656139338389039, Correct Predictions(batch) : 128/128
# Epoch: 12, Loss (per batch) : 0.0419, Accuracy: 0.9842
# Test Accuracy: 0.7325
# Average Test Loss : 1.4504
# idx : 0 , Current Loss(batch) : 0.014821033924818039, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.023177769035100937, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.09122269600629807, Correct Predictions(batch) : 124/128
# Epoch: 13, Loss (per batch) : 0.0339, Accuracy: 0.9884
# Test Accuracy: 0.6624
# Average Test Loss : 2.2448
# idx : 0 , Current Loss(batch) : 0.012178863398730755, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.017297670245170593, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.005336573347449303, Correct Predictions(batch) : 128/128
# Epoch: 14, Loss (per batch) : 0.0299, Accuracy: 0.9910
# Test Accuracy: 0.6306
# Average Test Loss : 2.4852
# idx : 0 , Current Loss(batch) : 0.008254755288362503, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00765462638810277, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.02772175706923008, Correct Predictions(batch) : 127/128
# Epoch: 15, Loss (per batch) : 0.0180, Accuracy: 0.9921
# Test Accuracy: 0.7580
# Average Test Loss : 1.5073
# idx : 0 , Current Loss(batch) : 0.0005673004779964685, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.051122959703207016, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.02745654433965683, Correct Predictions(batch) : 126/128
# Epoch: 16, Loss (per batch) : 0.0191, Accuracy: 0.9947
# Test Accuracy: 0.7070
# Average Test Loss : 1.5469
# idx : 0 , Current Loss(batch) : 0.000514072016812861, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.02492447942495346, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.03156665712594986, Correct Predictions(batch) : 127/128
# Epoch: 17, Loss (per batch) : 0.0127, Accuracy: 0.9958
# Test Accuracy: 0.6522
# Average Test Loss : 2.2105
# idx : 0 , Current Loss(batch) : 0.02881300449371338, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.017442340031266212, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.0026962310075759888, Correct Predictions(batch) : 128/128
# Epoch: 18, Loss (per batch) : 0.0164, Accuracy: 0.9926
# Test Accuracy: 0.6369
# Average Test Loss : 2.0797
# idx : 0 , Current Loss(batch) : 0.01617010310292244, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.032432056963443756, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.005290013272315264, Correct Predictions(batch) : 128/128
# Epoch: 19, Loss (per batch) : 0.0274, Accuracy: 0.9921
# Test Accuracy: 0.6484
# Average Test Loss : 2.4030
# idx : 0 , Current Loss(batch) : 0.00607312424108386, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0019898337777704, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.01445715967565775, Correct Predictions(batch) : 128/128
# Epoch: 20, Loss (per batch) : 0.0211, Accuracy: 0.9942
# Test Accuracy: 0.6204
# Average Test Loss : 2.8072
# idx : 0 , Current Loss(batch) : 0.009672913700342178, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.015797626227140427, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.056024499237537384, Correct Predictions(batch) : 127/128
# Epoch: 21, Loss (per batch) : 0.0277, Accuracy: 0.9926
# Test Accuracy: 0.5758
# Average Test Loss : 4.0630
# idx : 0 , Current Loss(batch) : 0.016795827075839043, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.07181909680366516, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.0037020391318947077, Correct Predictions(batch) : 128/128
# Epoch: 22, Loss (per batch) : 0.0369, Accuracy: 0.9900
# Test Accuracy: 0.6803
# Average Test Loss : 1.6447
# idx : 0 , Current Loss(batch) : 0.03666970133781433, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.09191491454839706, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.01793467067182064, Correct Predictions(batch) : 127/128
# Epoch: 23, Loss (per batch) : 0.0369, Accuracy: 0.9910
# Test Accuracy: 0.6637
# Average Test Loss : 2.2422
# idx : 0 , Current Loss(batch) : 0.004014595877379179, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.012180562131106853, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.05433015897870064, Correct Predictions(batch) : 124/128
# Epoch: 24, Loss (per batch) : 0.0403, Accuracy: 0.9884
# Test Accuracy: 0.6599
# Average Test Loss : 2.0050
# idx : 0 , Current Loss(batch) : 0.03781021386384964, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.056522637605667114, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.007953479886054993, Correct Predictions(batch) : 128/128
# Epoch: 25, Loss (per batch) : 0.0385, Accuracy: 0.9873
# Test Accuracy: 0.6701
# Average Test Loss : 1.9208
# idx : 0 , Current Loss(batch) : 0.009642260149121284, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.013365977443754673, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.05420275777578354, Correct Predictions(batch) : 123/128
# Epoch: 26, Loss (per batch) : 0.0401, Accuracy: 0.9836
# Test Accuracy: 0.6357
# Average Test Loss : 2.1139
# idx : 0 , Current Loss(batch) : 0.003882782533764839, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.058998145163059235, Correct Predictions(batch) : 124/128
# idx : 10 , Current Loss(batch) : 0.019187303259968758, Correct Predictions(batch) : 127/128
# Epoch: 27, Loss (per batch) : 0.0286, Accuracy: 0.9910
# Test Accuracy: 0.6803
# Average Test Loss : 1.9322
# idx : 0 , Current Loss(batch) : 0.06615384668111801, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.005594212561845779, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.03595295548439026, Correct Predictions(batch) : 126/128
# Epoch: 28, Loss (per batch) : 0.0188, Accuracy: 0.9926
# Test Accuracy: 0.7338
# Average Test Loss : 1.3934
# idx : 0 , Current Loss(batch) : 0.0012706003617495298, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0042175911366939545, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0842447429895401, Correct Predictions(batch) : 123/128
# Epoch: 29, Loss (per batch) : 0.0150, Accuracy: 0.9947
# Test Accuracy: 0.6293
# Average Test Loss : 2.3644
# idx : 0 , Current Loss(batch) : 0.12412098050117493, Correct Predictions(batch) : 124/128
# idx : 5 , Current Loss(batch) : 0.013628648594021797, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.020920339971780777, Correct Predictions(batch) : 127/128
# Epoch: 30, Loss (per batch) : 0.0649, Accuracy: 0.9831
# Test Accuracy: 0.6497
# Average Test Loss : 2.0238
# idx : 0 , Current Loss(batch) : 0.007465145085006952, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.03091784194111824, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.03763226419687271, Correct Predictions(batch) : 126/128
# Epoch: 31, Loss (per batch) : 0.0366, Accuracy: 0.9910
# Test Accuracy: 0.6752
# Average Test Loss : 2.1419
# idx : 0 , Current Loss(batch) : 0.007201494183391333, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.01544877514243126, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.001592338434420526, Correct Predictions(batch) : 128/128
# Epoch: 32, Loss (per batch) : 0.0327, Accuracy: 0.9921
# Test Accuracy: 0.7070
# Average Test Loss : 1.5180
# idx : 0 , Current Loss(batch) : 0.011836802586913109, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.02518644742667675, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.019574999809265137, Correct Predictions(batch) : 127/128
# Epoch: 33, Loss (per batch) : 0.0133, Accuracy: 0.9947
# Test Accuracy: 0.7338
# Average Test Loss : 1.2453
# idx : 0 , Current Loss(batch) : 0.0031979370396584272, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.004625418223440647, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0033274726010859013, Correct Predictions(batch) : 128/128
# Epoch: 34, Loss (per batch) : 0.0105, Accuracy: 0.9952
# Test Accuracy: 0.7325
# Average Test Loss : 1.4751
# idx : 0 , Current Loss(batch) : 0.04140928015112877, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.007677978370338678, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005642280448228121, Correct Predictions(batch) : 128/128
# Epoch: 35, Loss (per batch) : 0.0105, Accuracy: 0.9974
# Test Accuracy: 0.7108
# Average Test Loss : 1.7040
# idx : 0 , Current Loss(batch) : 0.010552260093390942, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.0003127017698716372, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.014551416970789433, Correct Predictions(batch) : 127/128
# Epoch: 36, Loss (per batch) : 0.0028, Accuracy: 0.9989
# Test Accuracy: 0.7580
# Average Test Loss : 1.2838
# idx : 0 , Current Loss(batch) : 0.0007594855269417167, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.004526135511696339, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0012106499634683132, Correct Predictions(batch) : 128/128
# Epoch: 37, Loss (per batch) : 0.0015, Accuracy: 1.0000
# Test Accuracy: 0.7873
# Average Test Loss : 1.1581
# idx : 0 , Current Loss(batch) : 0.000601552426815033, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0013028837274760008, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005835620104335248, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0005, Accuracy: 1.0000
# Test Accuracy: 0.7936
# Average Test Loss : 1.0682
# idx : 0 , Current Loss(batch) : 0.00018676227773539722, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00014858387294225395, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00015927894855849445, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0006, Accuracy: 1.0000
# Test Accuracy: 0.7936
# Average Test Loss : 1.1470
# idx : 0 , Current Loss(batch) : 0.0002027200534939766, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00017221331654582173, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0032458947971463203, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0004, Accuracy: 1.0000
# Test Accuracy: 0.7911
# Average Test Loss : 1.1504
# idx : 0 , Current Loss(batch) : 5.970972779323347e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.877491927705705e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00011590895883273333, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0002, Accuracy: 1.0000
# Test Accuracy: 0.7911
# Average Test Loss : 1.0146
# idx : 0 , Current Loss(batch) : 0.00023957891971804202, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.407027881825343e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.000154122753883712, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0002, Accuracy: 1.0000
# Test Accuracy: 0.8013
# Average Test Loss : 1.0875
# idx : 0 , Current Loss(batch) : 0.00010324006143491715, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 7.86523160059005e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.8872017689282075e-05, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8064
# Average Test Loss : 1.2924
# idx : 0 , Current Loss(batch) : 4.2039355321321636e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.806614379049279e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.542083479464054e-05, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8038
# Average Test Loss : 1.1494
# idx : 0 , Current Loss(batch) : 7.44267090340145e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.0586874092696235e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.943455471424386e-05, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8025
# Average Test Loss : 1.1812
# idx : 0 , Current Loss(batch) : 9.773627971298993e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.1697250455617905e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 6.327225128188729e-05, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.7975
# Average Test Loss : 1.1573
# idx : 0 , Current Loss(batch) : 8.415548654738814e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.5468505555181764e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00010106462286785245, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8025
# Average Test Loss : 1.0686
# idx : 0 , Current Loss(batch) : 6.591268902411684e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.524095518514514e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.697718420880847e-05, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8064
# Average Test Loss : 1.0688
# idx : 0 , Current Loss(batch) : 5.400134978117421e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.145440496155061e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.4508244425524026e-05, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8051
# Average Test Loss : 1.0383

# %%
optimizer_supervised = torch.optim.Adam(dino_model.parameters(), lr= 0.0001)
a_,b_,c_,d_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer_supervised,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 8.131758659146726e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.8776881410740316e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.2073081961716525e-05, Correct Predictions(batch) : 128/128
# Epoch: 0, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8064
# Average Test Loss : 1.2446
# idx : 0 , Current Loss(batch) : 0.00013744711759500206, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.138654276175657e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 9.37211461859988e-06, Correct Predictions(batch) : 128/128
# Epoch: 1, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8064
# Average Test Loss : 1.2684
# idx : 0 , Current Loss(batch) : 9.15104101295583e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.3917608561750967e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.7406917322659865e-05, Correct Predictions(batch) : 128/128
# Epoch: 2, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8013
# Average Test Loss : 1.2004
# idx : 0 , Current Loss(batch) : 5.347244496078929e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.700246088556014e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.0977268983842805e-06, Correct Predictions(batch) : 128/128
# Epoch: 3, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8076
# Average Test Loss : 1.1499
# idx : 0 , Current Loss(batch) : 4.815758529730374e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.6532868560025236e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.486745976668317e-06, Correct Predictions(batch) : 128/128
# Epoch: 4, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8115
# Average Test Loss : 1.1832
# idx : 0 , Current Loss(batch) : 5.18621209266712e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.3131540299582412e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.4128006569080753e-06, Correct Predictions(batch) : 128/128
# Epoch: 5, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.3385
# idx : 0 , Current Loss(batch) : 2.231416374343098e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.753282948717242e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.9277827050245833e-06, Correct Predictions(batch) : 128/128
# Epoch: 6, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.2005
# idx : 0 , Current Loss(batch) : 1.0887096095757443e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 9.257272495233337e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 8.869492376106791e-06, Correct Predictions(batch) : 128/128
# Epoch: 7, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8115
# Average Test Loss : 1.2504
# idx : 0 , Current Loss(batch) : 8.922041274672665e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.2572542118505226e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.352620979057974e-06, Correct Predictions(batch) : 128/128
# Epoch: 8, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8115
# Average Test Loss : 1.3358
# idx : 0 , Current Loss(batch) : 2.49864660872845e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.856827093950415e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.764857178292004e-07, Correct Predictions(batch) : 128/128
# Epoch: 9, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.3079
# idx : 0 , Current Loss(batch) : 9.648454124544514e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.1028688479418634e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.0602141123381443e-06, Correct Predictions(batch) : 128/128
# Epoch: 10, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.2297
# idx : 0 , Current Loss(batch) : 6.686630513286218e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.4248918205339578e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 6.454030199165572e-07, Correct Predictions(batch) : 128/128
# Epoch: 11, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.1502
# idx : 0 , Current Loss(batch) : 5.209382379689487e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 6.742727691744221e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.526200143573078e-07, Correct Predictions(batch) : 128/128
# Epoch: 12, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.0630
# idx : 0 , Current Loss(batch) : 5.972982307866914e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 9.406298886460718e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.582094845773099e-07, Correct Predictions(batch) : 128/128
# Epoch: 13, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 1.2609
# idx : 0 , Current Loss(batch) : 2.0489073904172983e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.054729234008846e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.9231006262998562e-06, Correct Predictions(batch) : 128/128
# Epoch: 14, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.1499
# idx : 0 , Current Loss(batch) : 3.306185192286648e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.016985265778203e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.594894906200352e-07, Correct Predictions(batch) : 128/128
# Epoch: 15, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.1060
# idx : 0 , Current Loss(batch) : 1.411860694133793e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 9.015146815727348e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.855661248053366e-07, Correct Predictions(batch) : 128/128
# Epoch: 16, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 1.1200
# idx : 0 , Current Loss(batch) : 6.509863510473224e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.0495771221030736e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.151353015733548e-07, Correct Predictions(batch) : 128/128
# Epoch: 17, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 1.1075
# idx : 0 , Current Loss(batch) : 2.952286877189181e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.861487923335517e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.507583639679069e-07, Correct Predictions(batch) : 128/128
# Epoch: 18, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.3522
# idx : 0 , Current Loss(batch) : 2.2537970778557792e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.0356130815125653e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.8649724842798605e-07, Correct Predictions(batch) : 128/128
# Epoch: 19, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 1.2790
# idx : 0 , Current Loss(batch) : 4.6286444899124035e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.661219226269168e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 6.528529752358736e-07, Correct Predictions(batch) : 128/128
# Epoch: 20, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 1.3928
# idx : 0 , Current Loss(batch) : 3.259615937167837e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.339929660091002e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 8.521541872141825e-07, Correct Predictions(batch) : 128/128
# Epoch: 21, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.2750
# idx : 0 , Current Loss(batch) : 5.271261898087687e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.036105908904574e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.4738272347567545e-07, Correct Predictions(batch) : 128/128
# Epoch: 22, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 1.1224
# idx : 0 , Current Loss(batch) : 9.070996043192281e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.867310051144159e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.2258541321207304e-07, Correct Predictions(batch) : 128/128
# Epoch: 23, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2446
# idx : 0 , Current Loss(batch) : 9.313222193441106e-08, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.8312157951404515e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.1529682524269447e-06, Correct Predictions(batch) : 128/128
# Epoch: 24, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.1850
# idx : 0 , Current Loss(batch) : 2.188543248848873e-06, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.4400591769335733e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.8870942969660973e-07, Correct Predictions(batch) : 128/128
# Epoch: 25, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.3556
# idx : 0 , Current Loss(batch) : 4.4051398617739324e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.7194553808840283e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.0360860137079726e-07, Correct Predictions(batch) : 128/128
# Epoch: 26, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8127
# Average Test Loss : 1.3465
# idx : 0 , Current Loss(batch) : 1.7508847349745338e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 6.426086542887788e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.4028082634686143e-07, Correct Predictions(batch) : 128/128
# Epoch: 27, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.2050
# idx : 0 , Current Loss(batch) : 3.464511735273845e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.847557353419688e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.771846195377293e-07, Correct Predictions(batch) : 128/128
# Epoch: 28, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.0896
# idx : 0 , Current Loss(batch) : 2.5611331011532457e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.179292266646371e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.7974500110540248e-07, Correct Predictions(batch) : 128/128
# Epoch: 29, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x791f638770a0>
# Exception ignored in: Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x791f638770a0>  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1461, in _shutdown_workers
#     if w.is_alive():
# if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'    assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Test Accuracy: 0.8178
# Average Test Loss : 1.1106
# idx : 0 , Current Loss(batch) : 2.77533558801224e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.009370588979436e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.731035687655094e-07, Correct Predictions(batch) : 128/128
# Epoch: 30, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.1987
# idx : 0 , Current Loss(batch) : 2.5425049443583703e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.9743994528198527e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.7601976765035943e-07, Correct Predictions(batch) : 128/128
# Epoch: 31, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2262
# idx : 0 , Current Loss(batch) : 4.358577996299573e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.3690424793821876e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 6.435322461584292e-07, Correct Predictions(batch) : 128/128
# Epoch: 32, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.3110
# idx : 0 , Current Loss(batch) : 1.294536389195855e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.2665962856317492e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.7043171851582883e-07, Correct Predictions(batch) : 128/128
# Epoch: 33, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.0934
# idx : 0 , Current Loss(batch) : 1.8160773151976173e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.825186922767898e-06, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.0337672051718982e-07, Correct Predictions(batch) : 128/128
# Epoch: 34, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.4107
# idx : 0 , Current Loss(batch) : 2.095473234930978e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 7.655381750737433e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.8964061016267806e-07, Correct Predictions(batch) : 128/128
# Epoch: 35, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.1477
# idx : 0 , Current Loss(batch) : 1.396981161860822e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.1920916875851617e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.1641523656180652e-07, Correct Predictions(batch) : 128/128
# Epoch: 36, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.2973
# idx : 0 , Current Loss(batch) : 1.9557749908472033e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.940692453052179e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.8964032594558375e-07, Correct Predictions(batch) : 128/128
# Epoch: 37, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.2366
# idx : 0 , Current Loss(batch) : 1.760198244937783e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.278240114923392e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.285222026581323e-07, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2666
# idx : 0 , Current Loss(batch) : 5.8673300884493074e-08, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 2.8964049647584034e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.2479712552249111e-07, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.2194
# idx : 0 , Current Loss(batch) : 4.572781051592756e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.49480034806038e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.5797521630011033e-07, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.4238
# idx : 0 , Current Loss(batch) : 2.793962323721644e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.639126594454865e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.908055757368857e-07, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2708
# idx : 0 , Current Loss(batch) : 1.2479695499223453e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 6.779965815439937e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.1175863789958385e-07, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8127
# Average Test Loss : 1.3264
# idx : 0 , Current Loss(batch) : 1.0617065271389947e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 7.078048724906694e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.4342344911710825e-07, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 1.2961
# idx : 0 , Current Loss(batch) : 7.729975237680264e-08, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.20140498438559e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 7.450577044210149e-08, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.1842
# idx : 0 , Current Loss(batch) : 1.778820575282225e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.005827670041981e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.4214341465267353e-07, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2884
# idx : 0 , Current Loss(batch) : 3.352760558072987e-08, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.6472749204440333e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.3399424498602457e-07, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.1821
# idx : 0 , Current Loss(batch) : 1.3038486201821797e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 1.220031862203541e-07, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.5052526098079397e-07, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2228
# idx : 0 , Current Loss(batch) : 1.2945369576300436e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.563479905073109e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.434232217434328e-07, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 1.2475
# idx : 0 , Current Loss(batch) : 1.229345087949696e-07, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 6.426122212133123e-08, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 1.1641520814009709e-07, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0000, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 1.2718

# %%
a_,b_,c_,d_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.309063673019409, Correct Predictions(batch) : 15/128
# idx : 5 , Current Loss(batch) : 1.6374412775039673, Correct Predictions(batch) : 79/128
# idx : 10 , Current Loss(batch) : 1.0436230897903442, Correct Predictions(batch) : 94/128
# Epoch: 0, Loss (per batch) : 1.5277, Accuracy: 0.5747
# Test Accuracy: 0.6102
# Average Test Loss : 1.2284
# idx : 0 , Current Loss(batch) : 0.7566370964050293, Correct Predictions(batch) : 97/128
# idx : 5 , Current Loss(batch) : 0.6162517666816711, Correct Predictions(batch) : 102/128
# idx : 10 , Current Loss(batch) : 0.4694118797779083, Correct Predictions(batch) : 107/128
# Epoch: 1, Loss (per batch) : 0.5575, Accuracy: 0.8146
# Test Accuracy: 0.5439
# Average Test Loss : 1.7321
# idx : 0 , Current Loss(batch) : 0.40690839290618896, Correct Predictions(batch) : 107/128
# idx : 5 , Current Loss(batch) : 0.29295873641967773, Correct Predictions(batch) : 118/128
# idx : 10 , Current Loss(batch) : 0.2980726361274719, Correct Predictions(batch) : 117/128
# Epoch: 2, Loss (per batch) : 0.3224, Accuracy: 0.8959
# Test Accuracy: 0.6395
# Average Test Loss : 1.4518
# idx : 0 , Current Loss(batch) : 0.20632612705230713, Correct Predictions(batch) : 119/128
# idx : 5 , Current Loss(batch) : 0.21864137053489685, Correct Predictions(batch) : 121/128
# idx : 10 , Current Loss(batch) : 0.2860313951969147, Correct Predictions(batch) : 114/128
# Epoch: 3, Loss (per batch) : 0.2211, Accuracy: 0.9255
# Test Accuracy: 0.6459
# Average Test Loss : 1.5515
# idx : 0 , Current Loss(batch) : 0.0713978037238121, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.20270875096321106, Correct Predictions(batch) : 120/128
# idx : 10 , Current Loss(batch) : 0.16927272081375122, Correct Predictions(batch) : 120/128
# Epoch: 4, Loss (per batch) : 0.1533, Accuracy: 0.9498
# Test Accuracy: 0.6713
# Average Test Loss : 1.3861
# idx : 0 , Current Loss(batch) : 0.07264780253171921, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.04264628514647484, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.06599557399749756, Correct Predictions(batch) : 125/128
# Epoch: 5, Loss (per batch) : 0.1072, Accuracy: 0.9651
# Test Accuracy: 0.7350
# Average Test Loss : 1.1823
# idx : 0 , Current Loss(batch) : 0.04892712086439133, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.17332823574543, Correct Predictions(batch) : 121/128
# idx : 10 , Current Loss(batch) : 0.038334790617227554, Correct Predictions(batch) : 127/128
# Epoch: 6, Loss (per batch) : 0.0777, Accuracy: 0.9768
# Test Accuracy: 0.7057
# Average Test Loss : 1.2576
# idx : 0 , Current Loss(batch) : 0.03172856569290161, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.13683874905109406, Correct Predictions(batch) : 126/128
# idx : 10 , Current Loss(batch) : 0.007416474632918835, Correct Predictions(batch) : 128/128
# Epoch: 7, Loss (per batch) : 0.0460, Accuracy: 0.9873
# Test Accuracy: 0.7134
# Average Test Loss : 1.3808
# idx : 0 , Current Loss(batch) : 0.017564646899700165, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.03623713552951813, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.026887277141213417, Correct Predictions(batch) : 127/128
# Epoch: 8, Loss (per batch) : 0.0376, Accuracy: 0.9878
# Test Accuracy: 0.7057
# Average Test Loss : 1.1817
# idx : 0 , Current Loss(batch) : 0.02807578817009926, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.039534792304039, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.026700148358941078, Correct Predictions(batch) : 127/128
# Epoch: 9, Loss (per batch) : 0.0385, Accuracy: 0.9878
# Test Accuracy: 0.7096
# Average Test Loss : 1.5148
# idx : 0 , Current Loss(batch) : 0.017810365185141563, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.025637006387114525, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.020304515957832336, Correct Predictions(batch) : 127/128
# Epoch: 10, Loss (per batch) : 0.0466, Accuracy: 0.9857
# Test Accuracy: 0.7096
# Average Test Loss : 1.3618
# idx : 0 , Current Loss(batch) : 0.019009752199053764, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.005947597324848175, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.04271122068166733, Correct Predictions(batch) : 125/128
# Epoch: 11, Loss (per batch) : 0.0466, Accuracy: 0.9884
# Test Accuracy: 0.6306
# Average Test Loss : 1.7007
# idx : 0 , Current Loss(batch) : 0.042833082377910614, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.1036500558257103, Correct Predictions(batch) : 123/128
# idx : 10 , Current Loss(batch) : 0.045044977217912674, Correct Predictions(batch) : 127/128
# Epoch: 12, Loss (per batch) : 0.0648, Accuracy: 0.9762
# Test Accuracy: 0.7389
# Average Test Loss : 1.1872
# idx : 0 , Current Loss(batch) : 0.023719727993011475, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.06270231306552887, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.05838550627231598, Correct Predictions(batch) : 126/128
# Epoch: 13, Loss (per batch) : 0.0795, Accuracy: 0.9762
# Test Accuracy: 0.5732
# Average Test Loss : 2.2984
# idx : 0 , Current Loss(batch) : 0.02690875716507435, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.051294200122356415, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.08763478696346283, Correct Predictions(batch) : 123/128
# Epoch: 14, Loss (per batch) : 0.0862, Accuracy: 0.9757
# Test Accuracy: 0.6688
# Average Test Loss : 1.6054
# idx : 0 , Current Loss(batch) : 0.03262440487742424, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.09876390546560287, Correct Predictions(batch) : 122/128
# idx : 10 , Current Loss(batch) : 0.1744217574596405, Correct Predictions(batch) : 122/128
# Epoch: 15, Loss (per batch) : 0.0756, Accuracy: 0.9794
# Test Accuracy: 0.6000
# Average Test Loss : 2.5432
# idx : 0 , Current Loss(batch) : 0.043805018067359924, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.2685815989971161, Correct Predictions(batch) : 120/128
# idx : 10 , Current Loss(batch) : 0.1139373779296875, Correct Predictions(batch) : 123/128
# Epoch: 16, Loss (per batch) : 0.0858, Accuracy: 0.9746
# Test Accuracy: 0.7185
# Average Test Loss : 1.6006
# idx : 0 , Current Loss(batch) : 0.036756888031959534, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.04548144340515137, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.10616246610879898, Correct Predictions(batch) : 126/128
# Epoch: 17, Loss (per batch) : 0.0768, Accuracy: 0.9778
# Test Accuracy: 0.5376
# Average Test Loss : 2.4092
# idx : 0 , Current Loss(batch) : 0.06049889698624611, Correct Predictions(batch) : 125/128
# idx : 5 , Current Loss(batch) : 0.02070462517440319, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.044129904359579086, Correct Predictions(batch) : 127/128
# Epoch: 18, Loss (per batch) : 0.0616, Accuracy: 0.9799
# Test Accuracy: 0.7146
# Average Test Loss : 1.2554
# idx : 0 , Current Loss(batch) : 0.04742726683616638, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.033294305205345154, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.059122055768966675, Correct Predictions(batch) : 125/128
# Epoch: 19, Loss (per batch) : 0.0357, Accuracy: 0.9878
# Test Accuracy: 0.7248
# Average Test Loss : 1.3414
# idx : 0 , Current Loss(batch) : 0.006214939057826996, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.07954790443181992, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.016269592568278313, Correct Predictions(batch) : 127/128
# Epoch: 20, Loss (per batch) : 0.0409, Accuracy: 0.9894
# Test Accuracy: 0.7414
# Average Test Loss : 1.5102
# idx : 0 , Current Loss(batch) : 0.052989836782217026, Correct Predictions(batch) : 126/128
# idx : 5 , Current Loss(batch) : 0.014945251867175102, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.003206410212442279, Correct Predictions(batch) : 128/128
# Epoch: 21, Loss (per batch) : 0.0255, Accuracy: 0.9905
# Test Accuracy: 0.7401
# Average Test Loss : 1.0626
# idx : 0 , Current Loss(batch) : 0.016697606071829796, Correct Predictions(batch) : 127/128
# idx : 5 , Current Loss(batch) : 0.05228534713387489, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.12710396945476532, Correct Predictions(batch) : 124/128
# Epoch: 22, Loss (per batch) : 0.0318, Accuracy: 0.9931
# Test Accuracy: 0.6930
# Average Test Loss : 1.4801
# idx : 0 , Current Loss(batch) : 0.005546352826058865, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.029285963624715805, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.015068095177412033, Correct Predictions(batch) : 127/128
# Epoch: 23, Loss (per batch) : 0.0234, Accuracy: 0.9926
# Test Accuracy: 0.7210
# Average Test Loss : 1.3560
# idx : 0 , Current Loss(batch) : 0.0023139871191233397, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003438197076320648, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.019758982583880424, Correct Predictions(batch) : 127/128
# Epoch: 24, Loss (per batch) : 0.0119, Accuracy: 0.9958
# Test Accuracy: 0.7134
# Average Test Loss : 1.4098
# idx : 0 , Current Loss(batch) : 0.0022143758833408356, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0019019863102585077, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.002216296037659049, Correct Predictions(batch) : 128/128
# Epoch: 25, Loss (per batch) : 0.0096, Accuracy: 0.9984
# Test Accuracy: 0.7707
# Average Test Loss : 1.2226
# idx : 0 , Current Loss(batch) : 0.008124691434204578, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.005749768111854792, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001315150992013514, Correct Predictions(batch) : 128/128
# Epoch: 26, Loss (per batch) : 0.0048, Accuracy: 0.9995
# Test Accuracy: 0.8000
# Average Test Loss : 0.9034
# idx : 0 , Current Loss(batch) : 0.0014595913235098124, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.001335144741460681, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.01628388650715351, Correct Predictions(batch) : 127/128
# Epoch: 27, Loss (per batch) : 0.0033, Accuracy: 0.9989
# Test Accuracy: 0.8038
# Average Test Loss : 0.8941
# idx : 0 , Current Loss(batch) : 0.0019100150093436241, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0011101668933406472, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0016402096953243017, Correct Predictions(batch) : 128/128
# Epoch: 28, Loss (per batch) : 0.0015, Accuracy: 1.0000
# Test Accuracy: 0.7962
# Average Test Loss : 0.9275
# idx : 0 , Current Loss(batch) : 0.00024260008649434894, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0004013373691122979, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0003723848203662783, Correct Predictions(batch) : 128/128
# Epoch: 29, Loss (per batch) : 0.0005, Accuracy: 1.0000
# Test Accuracy: 0.8025
# Average Test Loss : 0.9165
# idx : 0 , Current Loss(batch) : 0.000348715198924765, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0005980833666399121, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00016516770119778812, Correct Predictions(batch) : 128/128
# Epoch: 30, Loss (per batch) : 0.0005, Accuracy: 1.0000
# Test Accuracy: 0.8102
# Average Test Loss : 0.8438
# idx : 0 , Current Loss(batch) : 0.0002954818191938102, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0003670100122690201, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.002098826225847006, Correct Predictions(batch) : 128/128
# Epoch: 31, Loss (per batch) : 0.0003, Accuracy: 1.0000
# Test Accuracy: 0.8102
# Average Test Loss : 0.8779
# idx : 0 , Current Loss(batch) : 0.00010497529001440853, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 9.646960097597912e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00011936366354348138, Correct Predictions(batch) : 128/128
# Epoch: 32, Loss (per batch) : 0.0002, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.8486
# idx : 0 , Current Loss(batch) : 0.00019761419389396906, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00018298627401236445, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00038394820876419544, Correct Predictions(batch) : 128/128
# Epoch: 33, Loss (per batch) : 0.0002, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.7977
# idx : 0 , Current Loss(batch) : 7.480733620468527e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00010005982767324895, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00020978999964427203, Correct Predictions(batch) : 128/128
# Epoch: 34, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.9551
# idx : 0 , Current Loss(batch) : 5.4375865147449076e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0003703420516103506, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00025270297192037106, Correct Predictions(batch) : 128/128
# Epoch: 35, Loss (per batch) : 0.0003, Accuracy: 1.0000
# Test Accuracy: 0.8191
# Average Test Loss : 0.7887
# idx : 0 , Current Loss(batch) : 5.265419167699292e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.908509335014969e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 6.293504702625796e-05, Correct Predictions(batch) : 128/128
# Epoch: 36, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8191
# Average Test Loss : 0.8747
# idx : 0 , Current Loss(batch) : 0.0001275808026548475, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.7506229748250917e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00018330937018617988, Correct Predictions(batch) : 128/128
# Epoch: 37, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.8476
# idx : 0 , Current Loss(batch) : 0.0001260945136891678, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00012737854558508843, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 7.45249490137212e-05, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.8748
# idx : 0 , Current Loss(batch) : 4.843315764446743e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00010679009574232623, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.859446926275268e-05, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.9501
# idx : 0 , Current Loss(batch) : 0.00010387032671133056, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.150558015680872e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 6.433555972762406e-05, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8191
# Average Test Loss : 0.8354
# idx : 0 , Current Loss(batch) : 4.233916843077168e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.026800135965459e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 7.4773131927941e-05, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8217
# Average Test Loss : 0.8377
# idx : 0 , Current Loss(batch) : 7.886828825576231e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.636770947603509e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.515948239713907e-05, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8204
# Average Test Loss : 0.8405
# idx : 0 , Current Loss(batch) : 0.00011834927136078477, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 5.922068521613255e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.968360397266224e-05, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8229
# Average Test Loss : 0.8195
# idx : 0 , Current Loss(batch) : 4.942734449286945e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 8.714674913790077e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.037729715695605e-05, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8191
# Average Test Loss : 0.9503
# idx : 0 , Current Loss(batch) : 2.8905797080369666e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 6.235446926439181e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 5.9764723118860275e-05, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8191
# Average Test Loss : 0.8405
# idx : 0 , Current Loss(batch) : 5.2068528020754457e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 9.070078522199765e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 3.368445686646737e-05, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.8829
# idx : 0 , Current Loss(batch) : 4.591955803334713e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.8466146836290136e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 2.2151885787025094e-05, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8217
# Average Test Loss : 0.8498
# idx : 0 , Current Loss(batch) : 7.733265374554321e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 4.731664739665575e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.708669439423829e-05, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8217
# Average Test Loss : 0.9870
# idx : 0 , Current Loss(batch) : 4.085389446117915e-05, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 3.224949978175573e-05, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 4.402643389767036e-05, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0001, Accuracy: 1.0000
# Test Accuracy: 0.8217
# Average Test Loss : 0.9802

# %%
device = torch.device("cuda" if torch.cuda.is_available else "cpu")
dino_model = dino_resnet(num_classes=10,student = student,freeze = True)
# model = resnet(num_classes = 10)
dino_model = dino_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(dino_model.parameters(),lr = 0.001)

# %%
a1_,b1_,c1_,d1_ = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.5271718502044678, Correct Predictions(batch) : 2/128
# idx : 5 , Current Loss(batch) : 0.855148196220398, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 0.2452448010444641, Correct Predictions(batch) : 128/128
# Epoch: 0, Loss (per batch) : 0.8205, Accuracy: 0.8685
# Test Accuracy: 0.8115
# Average Test Loss : 0.6565
# idx : 0 , Current Loss(batch) : 0.0667416974902153, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.040391165763139725, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.022342432290315628, Correct Predictions(batch) : 128/128
# Epoch: 1, Loss (per batch) : 0.0376, Accuracy: 1.0000
# Test Accuracy: 0.8115
# Average Test Loss : 0.6522
# idx : 0 , Current Loss(batch) : 0.024831531569361687, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.013432176783680916, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.010921841487288475, Correct Predictions(batch) : 128/128
# Epoch: 2, Loss (per batch) : 0.0135, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6138
# idx : 0 , Current Loss(batch) : 0.008339240215718746, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.008302287198603153, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00826274324208498, Correct Predictions(batch) : 128/128
# Epoch: 3, Loss (per batch) : 0.0100, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.5947
# idx : 0 , Current Loss(batch) : 0.007091414649039507, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.009768822230398655, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.007181616500020027, Correct Predictions(batch) : 128/128
# Epoch: 4, Loss (per batch) : 0.0080, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6248
# idx : 0 , Current Loss(batch) : 0.007631146349012852, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.007331877946853638, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.00558189582079649, Correct Predictions(batch) : 128/128
# Epoch: 5, Loss (per batch) : 0.0071, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6184
# idx : 0 , Current Loss(batch) : 0.005410133395344019, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.004028359893709421, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0063023860566318035, Correct Predictions(batch) : 128/128
# Epoch: 6, Loss (per batch) : 0.0059, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 0.5616
# idx : 0 , Current Loss(batch) : 0.004173068795353174, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.006271338555961847, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.005336276721209288, Correct Predictions(batch) : 128/128
# Epoch: 7, Loss (per batch) : 0.0051, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6047
# idx : 0 , Current Loss(batch) : 0.003877201583236456, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00524526322260499, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004627903923392296, Correct Predictions(batch) : 128/128
# Epoch: 8, Loss (per batch) : 0.0055, Accuracy: 1.0000
# Test Accuracy: 0.8127
# Average Test Loss : 0.6332
# idx : 0 , Current Loss(batch) : 0.0049690674059093, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003494562581181526, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.005368815269321203, Correct Predictions(batch) : 128/128
# Epoch: 9, Loss (per batch) : 0.0046, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6524
# idx : 0 , Current Loss(batch) : 0.004991712048649788, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003412497928366065, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004020066931843758, Correct Predictions(batch) : 128/128
# Epoch: 10, Loss (per batch) : 0.0045, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6519
# idx : 0 , Current Loss(batch) : 0.005037732422351837, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003530951216816902, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0038077994249761105, Correct Predictions(batch) : 128/128
# Epoch: 11, Loss (per batch) : 0.0041, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 0.5721
# idx : 0 , Current Loss(batch) : 0.00295154913328588, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0050923507660627365, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.002544563263654709, Correct Predictions(batch) : 128/128
# Epoch: 12, Loss (per batch) : 0.0039, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 0.6311
# idx : 0 , Current Loss(batch) : 0.00346594350412488, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0028204035479575396, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.003357043256983161, Correct Predictions(batch) : 128/128
# Epoch: 13, Loss (per batch) : 0.0034, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.6827
# idx : 0 , Current Loss(batch) : 0.0029611345380544662, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00322561408393085, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.003141687950119376, Correct Predictions(batch) : 128/128
# Epoch: 14, Loss (per batch) : 0.0031, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.5733
# idx : 0 , Current Loss(batch) : 0.0027064078021794558, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.003098584245890379, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.004381874576210976, Correct Predictions(batch) : 128/128
# Epoch: 15, Loss (per batch) : 0.0028, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6664
# idx : 0 , Current Loss(batch) : 0.002687095431610942, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0028673929627984762, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.002656023483723402, Correct Predictions(batch) : 128/128
# Epoch: 16, Loss (per batch) : 0.0026, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6237
# idx : 0 , Current Loss(batch) : 0.002217754954472184, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0024940206203609705, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0033954994287341833, Correct Predictions(batch) : 128/128
# Epoch: 17, Loss (per batch) : 0.0025, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.7592
# idx : 0 , Current Loss(batch) : 0.0020964182913303375, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0019195445347577333, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.002757762325927615, Correct Predictions(batch) : 128/128
# Epoch: 18, Loss (per batch) : 0.0024, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6846
# idx : 0 , Current Loss(batch) : 0.001936415326781571, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0044530415907502174, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0024452628567814827, Correct Predictions(batch) : 128/128
# Epoch: 19, Loss (per batch) : 0.0026, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.6873
# idx : 0 , Current Loss(batch) : 0.003379120258614421, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0019801573362201452, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.001890990068204701, Correct Predictions(batch) : 128/128
# Epoch: 20, Loss (per batch) : 0.0022, Accuracy: 1.0000
# Test Accuracy: 0.8191
# Average Test Loss : 0.6141
# idx : 0 , Current Loss(batch) : 0.0018842107383534312, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.001737609738484025, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0016548173734918237, Correct Predictions(batch) : 128/128
# Epoch: 21, Loss (per batch) : 0.0019, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.5663
# idx : 0 , Current Loss(batch) : 0.0013313814997673035, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0018028364283964038, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0017011004965752363, Correct Predictions(batch) : 128/128
# Epoch: 22, Loss (per batch) : 0.0018, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6768
# idx : 0 , Current Loss(batch) : 0.0019297143444418907, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0017895869677886367, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0014430541777983308, Correct Predictions(batch) : 128/128
# Epoch: 23, Loss (per batch) : 0.0018, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.6373
# idx : 0 , Current Loss(batch) : 0.001963975839316845, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0012282314710319042, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0022004868369549513, Correct Predictions(batch) : 128/128
# Epoch: 24, Loss (per batch) : 0.0017, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.7027
# idx : 0 , Current Loss(batch) : 0.00247346144169569, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0015940709272399545, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0023764155339449644, Correct Predictions(batch) : 128/128
# Epoch: 25, Loss (per batch) : 0.0017, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6878
# idx : 0 , Current Loss(batch) : 0.001466628280468285, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.001921380404382944, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0013328330824151635, Correct Predictions(batch) : 128/128
# Epoch: 26, Loss (per batch) : 0.0016, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 0.6789
# idx : 0 , Current Loss(batch) : 0.001086098956875503, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0016624784329906106, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0018260820070281625, Correct Predictions(batch) : 128/128
# Epoch: 27, Loss (per batch) : 0.0016, Accuracy: 1.0000
# Test Accuracy: 0.8204
# Average Test Loss : 0.6173
# idx : 0 , Current Loss(batch) : 0.0013138492358848453, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0009632584406062961, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0014580573188140988, Correct Predictions(batch) : 128/128
# Epoch: 28, Loss (per batch) : 0.0016, Accuracy: 1.0000
# Test Accuracy: 0.8229
# Average Test Loss : 0.6228
# idx : 0 , Current Loss(batch) : 0.001166659640148282, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.001127161318436265, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0019535168539732695, Correct Predictions(batch) : 128/128
# Epoch: 29, Loss (per batch) : 0.0015, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.7149
# idx : 0 , Current Loss(batch) : 0.0011690391693264246, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0008714565192349255, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0011458086082711816, Correct Predictions(batch) : 128/128
# Epoch: 30, Loss (per batch) : 0.0012, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6935
# idx : 0 , Current Loss(batch) : 0.0011565989116206765, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.000945526931900531, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0013282804284244776, Correct Predictions(batch) : 128/128
# Epoch: 31, Loss (per batch) : 0.0013, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.7028
# idx : 0 , Current Loss(batch) : 0.000978156691417098, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0010921657085418701, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0006817873800173402, Correct Predictions(batch) : 128/128
# Epoch: 32, Loss (per batch) : 0.0012, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.7317
# idx : 0 , Current Loss(batch) : 0.0008572406368330121, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0016523355152457952, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.000867322669364512, Correct Predictions(batch) : 128/128
# Epoch: 33, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6406
# idx : 0 , Current Loss(batch) : 0.0010085211833938956, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007807326037436724, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0019043025095015764, Correct Predictions(batch) : 128/128
# Epoch: 34, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.6696
# idx : 0 , Current Loss(batch) : 0.0014429549919441342, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0018205365631729364, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0006740912795066833, Correct Predictions(batch) : 128/128
# Epoch: 35, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6207
# idx : 0 , Current Loss(batch) : 0.0007961838855408132, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007124369731172919, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0014234725385904312, Correct Predictions(batch) : 128/128
# Epoch: 36, Loss (per batch) : 0.0011, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6263
# idx : 0 , Current Loss(batch) : 0.0009401931893080473, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0008047819137573242, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0009562263148836792, Correct Predictions(batch) : 128/128
# Epoch: 37, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.6837
# idx : 0 , Current Loss(batch) : 0.000740236893761903, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.000917367753572762, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0006560971960425377, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0010, Accuracy: 1.0000
# Test Accuracy: 0.8127
# Average Test Loss : 0.6753
# idx : 0 , Current Loss(batch) : 0.0006007838528603315, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006234677857719362, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0009542796760797501, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0010, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.7275
# idx : 0 , Current Loss(batch) : 0.0006535809370689094, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0011058143572881818, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0012247819686308503, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.7038
# idx : 0 , Current Loss(batch) : 0.0011901844991371036, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007409713580273092, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005948375910520554, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0009, Accuracy: 1.0000
# Test Accuracy: 0.8166
# Average Test Loss : 0.7149
# idx : 0 , Current Loss(batch) : 0.0006946393987163901, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0007621700060553849, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0010333580430597067, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.7592
# idx : 0 , Current Loss(batch) : 0.0006380482809618115, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.000954346964135766, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0011031077010557055, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.8178
# Average Test Loss : 0.6738
# idx : 0 , Current Loss(batch) : 0.0007826281362213194, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0010304991155862808, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.000768175523262471, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.8127
# Average Test Loss : 0.6768
# idx : 0 , Current Loss(batch) : 0.0004572151810862124, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006656881305389106, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0013147784629836679, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.7546
# idx : 0 , Current Loss(batch) : 0.0007447171374224126, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0006621615611948073, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0010826516663655639, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.8127
# Average Test Loss : 0.7778
# idx : 0 , Current Loss(batch) : 0.00030497723491862416, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0005016819923184812, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0005115335225127637, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 0.6385
# idx : 0 , Current Loss(batch) : 0.0006641845684498549, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0004903977969661355, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0007456311141140759, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0008, Accuracy: 1.0000
# Test Accuracy: 0.8153
# Average Test Loss : 0.6705
# idx : 0 , Current Loss(batch) : 0.00046241647214628756, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.000594157783780247, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0006057380815036595, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0007, Accuracy: 1.0000
# Test Accuracy: 0.8140
# Average Test Loss : 0.6340

# %% [markdown]
# # VIT DINO SSL MODEL

# %% [markdown]
# ## **FINETUNING**

# %%
device = torch.device("cuda" if torch.cuda.is_available else "cpu")
dino_model = dino_vit(num_classes=10,student = student,freeze = False)
# model = resnet(num_classes = 10)
dino_model = dino_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(dino_model.parameters(),lr = 0.001)

# %%
a1_v,b1_v,c1_v,d1_v = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.243157386779785, Correct Predictions(batch) : 34/128
# idx : 5 , Current Loss(batch) : 2.145616292953491, Correct Predictions(batch) : 36/128
# idx : 10 , Current Loss(batch) : 1.9251033067703247, Correct Predictions(batch) : 74/128
# Epoch: 0, Loss (per batch) : 2.0451, Accuracy: 0.4036
# Test Accuracy: 0.5503
# Average Test Loss : 1.9198
# idx : 0 , Current Loss(batch) : 1.7066307067871094, Correct Predictions(batch) : 104/128
# idx : 5 , Current Loss(batch) : 1.5666342973709106, Correct Predictions(batch) : 111/128
# idx : 10 , Current Loss(batch) : 1.5042965412139893, Correct Predictions(batch) : 109/128
# Epoch: 1, Loss (per batch) : 1.5433, Accuracy: 0.8468
# Test Accuracy: 0.6471
# Average Test Loss : 1.6029
# idx : 0 , Current Loss(batch) : 1.3037490844726562, Correct Predictions(batch) : 119/128
# idx : 5 , Current Loss(batch) : 1.1758002042770386, Correct Predictions(batch) : 127/128
# idx : 10 , Current Loss(batch) : 1.0561203956604004, Correct Predictions(batch) : 126/128
# Epoch: 2, Loss (per batch) : 1.1288, Accuracy: 0.9799
# Test Accuracy: 0.7032
# Average Test Loss : 1.3801
# idx : 0 , Current Loss(batch) : 0.9109712839126587, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.848689079284668, Correct Predictions(batch) : 125/128
# idx : 10 , Current Loss(batch) : 0.7261536121368408, Correct Predictions(batch) : 127/128
# Epoch: 3, Loss (per batch) : 0.7916, Accuracy: 0.9963
# Test Accuracy: 0.7096
# Average Test Loss : 1.2159
# idx : 0 , Current Loss(batch) : 0.6464620232582092, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.5640291571617126, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.5049129724502563, Correct Predictions(batch) : 128/128
# Epoch: 4, Loss (per batch) : 0.5384, Accuracy: 0.9989
# Test Accuracy: 0.7172
# Average Test Loss : 1.0498
# idx : 0 , Current Loss(batch) : 0.4315354526042938, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.3720366060733795, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.34352803230285645, Correct Predictions(batch) : 128/128
# Epoch: 5, Loss (per batch) : 0.3645, Accuracy: 1.0000
# Test Accuracy: 0.7185
# Average Test Loss : 1.0447
# idx : 0 , Current Loss(batch) : 0.2932772934436798, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.27509576082229614, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.22900080680847168, Correct Predictions(batch) : 128/128
# Epoch: 6, Loss (per batch) : 0.2528, Accuracy: 1.0000
# Test Accuracy: 0.7172
# Average Test Loss : 1.0191
# idx : 0 , Current Loss(batch) : 0.2110079675912857, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.18875160813331604, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.16070401668548584, Correct Predictions(batch) : 128/128
# Epoch: 7, Loss (per batch) : 0.1826, Accuracy: 1.0000
# Test Accuracy: 0.7159
# Average Test Loss : 0.9377
# idx : 0 , Current Loss(batch) : 0.15475553274154663, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.15045993030071259, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.12862513959407806, Correct Predictions(batch) : 128/128
# Epoch: 8, Loss (per batch) : 0.1372, Accuracy: 1.0000
# Test Accuracy: 0.7172
# Average Test Loss : 0.9901
# idx : 0 , Current Loss(batch) : 0.11571672558784485, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.11708486825227737, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.09841810911893845, Correct Predictions(batch) : 128/128
# Epoch: 9, Loss (per batch) : 0.1073, Accuracy: 1.0000
# Test Accuracy: 0.7172
# Average Test Loss : 0.9384
# idx : 0 , Current Loss(batch) : 0.08881644904613495, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.09055270254611969, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.08254936337471008, Correct Predictions(batch) : 128/128
# Epoch: 10, Loss (per batch) : 0.0868, Accuracy: 1.0000
# Test Accuracy: 0.7146
# Average Test Loss : 0.9715
# idx : 0 , Current Loss(batch) : 0.07918843626976013, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.07704748213291168, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.06565019488334656, Correct Predictions(batch) : 128/128
# Epoch: 11, Loss (per batch) : 0.0721, Accuracy: 1.0000
# Test Accuracy: 0.7146
# Average Test Loss : 0.9588
# idx : 0 , Current Loss(batch) : 0.06398411840200424, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.06482727080583572, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.05978073552250862, Correct Predictions(batch) : 128/128
# Epoch: 12, Loss (per batch) : 0.0612, Accuracy: 1.0000
# Test Accuracy: 0.7121
# Average Test Loss : 0.9829
# idx : 0 , Current Loss(batch) : 0.057860471308231354, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.056277982890605927, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.05097482353448868, Correct Predictions(batch) : 128/128
# Epoch: 13, Loss (per batch) : 0.0528, Accuracy: 1.0000
# Test Accuracy: 0.7108
# Average Test Loss : 0.9546
# idx : 0 , Current Loss(batch) : 0.04943528398871422, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.04833933338522911, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.04339488223195076, Correct Predictions(batch) : 128/128
# Epoch: 14, Loss (per batch) : 0.0463, Accuracy: 1.0000
# Test Accuracy: 0.7121
# Average Test Loss : 1.0751
# idx : 0 , Current Loss(batch) : 0.04313100501894951, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.04131719097495079, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.039425358176231384, Correct Predictions(batch) : 128/128
# Epoch: 15, Loss (per batch) : 0.0411, Accuracy: 1.0000
# Test Accuracy: 0.7134
# Average Test Loss : 1.0444
# idx : 0 , Current Loss(batch) : 0.03937062621116638, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.039374057203531265, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.037351805716753006, Correct Predictions(batch) : 128/128
# Epoch: 16, Loss (per batch) : 0.0368, Accuracy: 1.0000
# Test Accuracy: 0.7121
# Average Test Loss : 0.9910
# idx : 0 , Current Loss(batch) : 0.03504189848899841, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.03321806713938713, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.03289121389389038, Correct Predictions(batch) : 128/128
# Epoch: 17, Loss (per batch) : 0.0332, Accuracy: 1.0000
# Test Accuracy: 0.7172
# Average Test Loss : 1.0574
# idx : 0 , Current Loss(batch) : 0.03141241893172264, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.030793949961662292, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.030002979561686516, Correct Predictions(batch) : 128/128
# Epoch: 18, Loss (per batch) : 0.0302, Accuracy: 1.0000
# Test Accuracy: 0.7185
# Average Test Loss : 0.9906
# idx : 0 , Current Loss(batch) : 0.028925150632858276, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.027247676625847816, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.026635553687810898, Correct Predictions(batch) : 128/128
# Epoch: 19, Loss (per batch) : 0.0277, Accuracy: 1.0000
# Test Accuracy: 0.7210
# Average Test Loss : 1.0417
# idx : 0 , Current Loss(batch) : 0.02642817422747612, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.02600129507482052, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.025191405788064003, Correct Predictions(batch) : 128/128
# Epoch: 20, Loss (per batch) : 0.0255, Accuracy: 1.0000
# Test Accuracy: 0.7210
# Average Test Loss : 0.9914
# idx : 0 , Current Loss(batch) : 0.024782150983810425, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.024220827966928482, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.023278020322322845, Correct Predictions(batch) : 128/128
# Epoch: 21, Loss (per batch) : 0.0236, Accuracy: 1.0000
# Test Accuracy: 0.7236
# Average Test Loss : 1.0302
# idx : 0 , Current Loss(batch) : 0.021464793011546135, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.021855724975466728, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.021830817684531212, Correct Predictions(batch) : 128/128
# Epoch: 22, Loss (per batch) : 0.0219, Accuracy: 1.0000
# Test Accuracy: 0.7197
# Average Test Loss : 1.0986
# idx : 0 , Current Loss(batch) : 0.02170570380985737, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.021094910800457, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0211547389626503, Correct Predictions(batch) : 128/128
# Epoch: 23, Loss (per batch) : 0.0204, Accuracy: 1.0000
# Test Accuracy: 0.7236
# Average Test Loss : 1.1353
# idx : 0 , Current Loss(batch) : 0.01968853734433651, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.019260497763752937, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.01867501437664032, Correct Predictions(batch) : 128/128
# Epoch: 24, Loss (per batch) : 0.0191, Accuracy: 1.0000
# Test Accuracy: 0.7236
# Average Test Loss : 1.1693
# idx : 0 , Current Loss(batch) : 0.01800927333533764, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.018335655331611633, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.017095506191253662, Correct Predictions(batch) : 128/128
# Epoch: 25, Loss (per batch) : 0.0179, Accuracy: 1.0000
# Test Accuracy: 0.7210
# Average Test Loss : 1.1768
# idx : 0 , Current Loss(batch) : 0.01692521944642067, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.017199283465743065, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.016675900667905807, Correct Predictions(batch) : 128/128
# Epoch: 26, Loss (per batch) : 0.0168, Accuracy: 1.0000
# Test Accuracy: 0.7236
# Average Test Loss : 0.9891
# idx : 0 , Current Loss(batch) : 0.016093073412775993, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.015929654240608215, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.015312670730054379, Correct Predictions(batch) : 128/128
# Epoch: 27, Loss (per batch) : 0.0159, Accuracy: 1.0000
# Test Accuracy: 0.7223
# Average Test Loss : 1.0742
# idx : 0 , Current Loss(batch) : 0.015213608741760254, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.0153048075735569, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.014476138167083263, Correct Predictions(batch) : 128/128
# Epoch: 28, Loss (per batch) : 0.0150, Accuracy: 1.0000
# Test Accuracy: 0.7223
# Average Test Loss : 1.0981
# idx : 0 , Current Loss(batch) : 0.014497539028525352, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.014516145922243595, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0139688765630126, Correct Predictions(batch) : 128/128
# Epoch: 29, Loss (per batch) : 0.0142, Accuracy: 1.0000
# Test Accuracy: 0.7248
# Average Test Loss : 1.0705
# idx : 0 , Current Loss(batch) : 0.013749492354691029, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.013624447397887707, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.013344470411539078, Correct Predictions(batch) : 128/128
# Epoch: 30, Loss (per batch) : 0.0135, Accuracy: 1.0000
# Test Accuracy: 0.7261
# Average Test Loss : 1.1069
# idx : 0 , Current Loss(batch) : 0.01286767516285181, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.012957829982042313, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.012474571354687214, Correct Predictions(batch) : 128/128
# Epoch: 31, Loss (per batch) : 0.0128, Accuracy: 1.0000
# Test Accuracy: 0.7248
# Average Test Loss : 1.1111
# idx : 0 , Current Loss(batch) : 0.012507240287959576, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.012291931547224522, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.012164109386503696, Correct Predictions(batch) : 128/128
# Epoch: 32, Loss (per batch) : 0.0122, Accuracy: 1.0000
# Test Accuracy: 0.7261
# Average Test Loss : 1.2167
# idx : 0 , Current Loss(batch) : 0.01180193480104208, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.011766092851758003, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.011463936418294907, Correct Predictions(batch) : 128/128
# Epoch: 33, Loss (per batch) : 0.0116, Accuracy: 1.0000
# Test Accuracy: 0.7261
# Average Test Loss : 1.0743
# idx : 0 , Current Loss(batch) : 0.011511885561048985, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.011043707840144634, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.011149543337523937, Correct Predictions(batch) : 128/128
# Epoch: 34, Loss (per batch) : 0.0111, Accuracy: 1.0000
# Test Accuracy: 0.7248
# Average Test Loss : 1.0553
# idx : 0 , Current Loss(batch) : 0.010648274794220924, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.010503407567739487, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.01083698496222496, Correct Predictions(batch) : 128/128
# Epoch: 35, Loss (per batch) : 0.0106, Accuracy: 1.0000
# Test Accuracy: 0.7274
# Average Test Loss : 1.0795
# idx : 0 , Current Loss(batch) : 0.010425647720694542, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.010539446026086807, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.010234981775283813, Correct Predictions(batch) : 128/128
# Epoch: 36, Loss (per batch) : 0.0102, Accuracy: 1.0000
# Test Accuracy: 0.7274
# Average Test Loss : 1.2294
# idx : 0 , Current Loss(batch) : 0.0100967176258564, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.010114030912518501, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.009658022783696651, Correct Predictions(batch) : 128/128
# Epoch: 37, Loss (per batch) : 0.0098, Accuracy: 1.0000
# Test Accuracy: 0.7287
# Average Test Loss : 1.0272
# idx : 0 , Current Loss(batch) : 0.009251896291971207, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.009487275965511799, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.009262033738195896, Correct Predictions(batch) : 128/128
# Epoch: 38, Loss (per batch) : 0.0094, Accuracy: 1.0000
# Test Accuracy: 0.7274
# Average Test Loss : 1.1107
# idx : 0 , Current Loss(batch) : 0.009053929708898067, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.008988667279481888, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.009016369469463825, Correct Predictions(batch) : 128/128
# Epoch: 39, Loss (per batch) : 0.0090, Accuracy: 1.0000
# Test Accuracy: 0.7287
# Average Test Loss : 1.1005
# idx : 0 , Current Loss(batch) : 0.009058697149157524, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.008727672509849072, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.008343101479113102, Correct Predictions(batch) : 128/128
# Epoch: 40, Loss (per batch) : 0.0087, Accuracy: 1.0000
# Test Accuracy: 0.7274
# Average Test Loss : 1.1360
# idx : 0 , Current Loss(batch) : 0.008340779691934586, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.008391276001930237, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.008290492929518223, Correct Predictions(batch) : 128/128
# Epoch: 41, Loss (per batch) : 0.0083, Accuracy: 1.0000
# Test Accuracy: 0.7261
# Average Test Loss : 1.2036
# idx : 0 , Current Loss(batch) : 0.008067624643445015, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.008024842478334904, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.008132989518344402, Correct Predictions(batch) : 128/128
# Epoch: 42, Loss (per batch) : 0.0080, Accuracy: 1.0000
# Test Accuracy: 0.7248
# Average Test Loss : 1.0765
# idx : 0 , Current Loss(batch) : 0.007905852049589157, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.007774301338940859, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0075626675970852375, Correct Predictions(batch) : 128/128
# Epoch: 43, Loss (per batch) : 0.0077, Accuracy: 1.0000
# Test Accuracy: 0.7261
# Average Test Loss : 1.1009
# idx : 0 , Current Loss(batch) : 0.0077394722029566765, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.007399096619337797, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.007333942223340273, Correct Predictions(batch) : 128/128
# Epoch: 44, Loss (per batch) : 0.0075, Accuracy: 1.0000
# Test Accuracy: 0.7223
# Average Test Loss : 1.1236
# idx : 0 , Current Loss(batch) : 0.0071705058217048645, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.007321195211261511, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.006827095523476601, Correct Predictions(batch) : 128/128
# Epoch: 45, Loss (per batch) : 0.0072, Accuracy: 1.0000
# Test Accuracy: 0.7236
# Average Test Loss : 1.1997
# idx : 0 , Current Loss(batch) : 0.006951924879103899, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.007005631923675537, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.006914295256137848, Correct Predictions(batch) : 128/128
# Epoch: 46, Loss (per batch) : 0.0070, Accuracy: 1.0000
# Test Accuracy: 0.7236
# Average Test Loss : 1.2167
# idx : 0 , Current Loss(batch) : 0.006730678956955671, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.006739072967320681, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.006637245882302523, Correct Predictions(batch) : 128/128
# Epoch: 47, Loss (per batch) : 0.0067, Accuracy: 1.0000
# Test Accuracy: 0.7223
# Average Test Loss : 1.1501
# idx : 0 , Current Loss(batch) : 0.006597088649868965, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.006536148022860289, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.006368073634803295, Correct Predictions(batch) : 128/128
# Epoch: 48, Loss (per batch) : 0.0065, Accuracy: 1.0000
# Test Accuracy: 0.7223
# Average Test Loss : 1.0688
# idx : 0 , Current Loss(batch) : 0.0063604991883039474, Correct Predictions(batch) : 128/128
# idx : 5 , Current Loss(batch) : 0.00633460795506835, Correct Predictions(batch) : 128/128
# idx : 10 , Current Loss(batch) : 0.0063101849518716335, Correct Predictions(batch) : 128/128
# Epoch: 49, Loss (per batch) : 0.0063, Accuracy: 1.0000
# Test Accuracy: 0.7223
# Average Test Loss : 1.2271

# %% [markdown]
# ## **VALIDATION ACCURACY : 72.87 %**

# %% [markdown]
# ## **PRETRAINING**

# %%
dino_model = dino_vit(num_classes=10,student = student,freeze = True)
# model = resnet(num_classes = 10)
dino_model = dino_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(dino_model.parameters(),lr = 0.0001)

# %%
a1_v,b1_v,c1_v,d1_v = train(data_loader_train_supervised,data_loader_test_supervised,dino_model,optimizer,criterion,50)
# Out:
# idx : 0 , Current Loss(batch) : 2.3060736656188965, Correct Predictions(batch) : 14/128
# idx : 5 , Current Loss(batch) : 2.299527168273926, Correct Predictions(batch) : 12/128
# idx : 10 , Current Loss(batch) : 2.3207600116729736, Correct Predictions(batch) : 7/128
# Epoch: 0, Loss (per batch) : 2.3015, Accuracy: 0.1057
# Test Accuracy: 0.1108
# Average Test Loss : 2.2741
# idx : 0 , Current Loss(batch) : 2.2829644680023193, Correct Predictions(batch) : 16/128
# idx : 5 , Current Loss(batch) : 2.289402961730957, Correct Predictions(batch) : 12/128
# idx : 10 , Current Loss(batch) : 2.264461040496826, Correct Predictions(batch) : 17/128
# Epoch: 1, Loss (per batch) : 2.2654, Accuracy: 0.1337
# Test Accuracy: 0.1325
# Average Test Loss : 2.2643
# idx : 0 , Current Loss(batch) : 2.2682061195373535, Correct Predictions(batch) : 17/128
# idx : 5 , Current Loss(batch) : 2.2222723960876465, Correct Predictions(batch) : 24/128
# idx : 10 , Current Loss(batch) : 2.2379138469696045, Correct Predictions(batch) : 20/128
# Epoch: 2, Loss (per batch) : 2.2309, Accuracy: 0.1717
# Test Accuracy: 0.1783
# Average Test Loss : 2.2349
# idx : 0 , Current Loss(batch) : 2.2048206329345703, Correct Predictions(batch) : 24/128
# idx : 5 , Current Loss(batch) : 2.2256927490234375, Correct Predictions(batch) : 26/128
# idx : 10 , Current Loss(batch) : 2.2095155715942383, Correct Predictions(batch) : 26/128
# Epoch: 3, Loss (per batch) : 2.1993, Accuracy: 0.2124
# Test Accuracy: 0.2166
# Average Test Loss : 2.2066
# idx : 0 , Current Loss(batch) : 2.161323070526123, Correct Predictions(batch) : 36/128
# idx : 5 , Current Loss(batch) : 2.1708712577819824, Correct Predictions(batch) : 32/128
# idx : 10 , Current Loss(batch) : 2.1968300342559814, Correct Predictions(batch) : 30/128
# Epoch: 4, Loss (per batch) : 2.1682, Accuracy: 0.2620
# Test Accuracy: 0.2561
# Average Test Loss : 2.1712
# idx : 0 , Current Loss(batch) : 2.1433188915252686, Correct Predictions(batch) : 37/128
# idx : 5 , Current Loss(batch) : 2.1563010215759277, Correct Predictions(batch) : 38/128
# idx : 10 , Current Loss(batch) : 2.1104142665863037, Correct Predictions(batch) : 52/128
# Epoch: 5, Loss (per batch) : 2.1374, Accuracy: 0.3180
# Test Accuracy: 0.3134
# Average Test Loss : 2.1306
# idx : 0 , Current Loss(batch) : 2.1223435401916504, Correct Predictions(batch) : 42/128
# idx : 5 , Current Loss(batch) : 2.0956366062164307, Correct Predictions(batch) : 48/128
# idx : 10 , Current Loss(batch) : 2.1045236587524414, Correct Predictions(batch) : 48/128
# Epoch: 6, Loss (per batch) : 2.1087, Accuracy: 0.3693
# Test Accuracy: 0.3554
# Average Test Loss : 2.1265
# idx : 0 , Current Loss(batch) : 2.0827600955963135, Correct Predictions(batch) : 59/128
# idx : 5 , Current Loss(batch) : 2.0860650539398193, Correct Predictions(batch) : 51/128
# idx : 10 , Current Loss(batch) : 2.073428153991699, Correct Predictions(batch) : 50/128
# Epoch: 7, Loss (per batch) : 2.0789, Accuracy: 0.4089
# Test Accuracy: 0.4038
# Average Test Loss : 2.0838
# idx : 0 , Current Loss(batch) : 2.0520753860473633, Correct Predictions(batch) : 57/128
# idx : 5 , Current Loss(batch) : 2.057042360305786, Correct Predictions(batch) : 59/128
# idx : 10 , Current Loss(batch) : 2.086210250854492, Correct Predictions(batch) : 58/128
# Epoch: 8, Loss (per batch) : 2.0517, Accuracy: 0.4575
# Test Accuracy: 0.4446
# Average Test Loss : 2.0666
# idx : 0 , Current Loss(batch) : 2.070704221725464, Correct Predictions(batch) : 54/128
# idx : 5 , Current Loss(batch) : 2.023007869720459, Correct Predictions(batch) : 66/128
# idx : 10 , Current Loss(batch) : 2.014559507369995, Correct Predictions(batch) : 69/128
# Epoch: 9, Loss (per batch) : 2.0230, Accuracy: 0.4976
# Test Accuracy: 0.4726
# Average Test Loss : 2.0341
# idx : 0 , Current Loss(batch) : 2.023743152618408, Correct Predictions(batch) : 61/128
# idx : 5 , Current Loss(batch) : 2.010526418685913, Correct Predictions(batch) : 63/128
# idx : 10 , Current Loss(batch) : 1.9826302528381348, Correct Predictions(batch) : 72/128
# Epoch: 10, Loss (per batch) : 1.9968, Accuracy: 0.5267
# Test Accuracy: 0.4968
# Average Test Loss : 2.0132
# idx : 0 , Current Loss(batch) : 2.017134428024292, Correct Predictions(batch) : 59/128
# idx : 5 , Current Loss(batch) : 1.9313870668411255, Correct Predictions(batch) : 81/128
# idx : 10 , Current Loss(batch) : 1.9858218431472778, Correct Predictions(batch) : 73/128
# Epoch: 11, Loss (per batch) : 1.9701, Accuracy: 0.5515
# Test Accuracy: 0.5134
# Average Test Loss : 1.9958
# idx : 0 , Current Loss(batch) : 1.9553335905075073, Correct Predictions(batch) : 68/128
# idx : 5 , Current Loss(batch) : 1.9629075527191162, Correct Predictions(batch) : 71/128
# idx : 10 , Current Loss(batch) : 1.9369771480560303, Correct Predictions(batch) : 72/128
# Epoch: 12, Loss (per batch) : 1.9449, Accuracy: 0.5711
# Test Accuracy: 0.5389
# Average Test Loss : 1.9742
# idx : 0 , Current Loss(batch) : 1.933558464050293, Correct Predictions(batch) : 75/128
# idx : 5 , Current Loss(batch) : 1.8728746175765991, Correct Predictions(batch) : 82/128
# idx : 10 , Current Loss(batch) : 1.9025218486785889, Correct Predictions(batch) : 84/128
# Epoch: 13, Loss (per batch) : 1.9188, Accuracy: 0.5880
# Test Accuracy: 0.5516
# Average Test Loss : 1.9505
# idx : 0 , Current Loss(batch) : 1.8853733539581299, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.8935152292251587, Correct Predictions(batch) : 84/128
# idx : 10 , Current Loss(batch) : 1.9069048166275024, Correct Predictions(batch) : 70/128
# Epoch: 14, Loss (per batch) : 1.8940, Accuracy: 0.6038
# Test Accuracy: 0.5656
# Average Test Loss : 1.9133
# idx : 0 , Current Loss(batch) : 1.893402338027954, Correct Predictions(batch) : 80/128
# idx : 5 , Current Loss(batch) : 1.855664610862732, Correct Predictions(batch) : 85/128
# idx : 10 , Current Loss(batch) : 1.8677138090133667, Correct Predictions(batch) : 79/128
# Epoch: 15, Loss (per batch) : 1.8696, Accuracy: 0.6244
# Test Accuracy: 0.5796
# Average Test Loss : 1.8915
# idx : 0 , Current Loss(batch) : 1.8328849077224731, Correct Predictions(batch) : 85/128
# idx : 5 , Current Loss(batch) : 1.8612569570541382, Correct Predictions(batch) : 77/128
# idx : 10 , Current Loss(batch) : 1.8149160146713257, Correct Predictions(batch) : 84/128
# Epoch: 16, Loss (per batch) : 1.8459, Accuracy: 0.6313
# Test Accuracy: 0.5898
# Average Test Loss : 1.8925
# idx : 0 , Current Loss(batch) : 1.8325749635696411, Correct Predictions(batch) : 84/128
# idx : 5 , Current Loss(batch) : 1.7913144826889038, Correct Predictions(batch) : 85/128
# idx : 10 , Current Loss(batch) : 1.841741919517517, Correct Predictions(batch) : 77/128
# Epoch: 17, Loss (per batch) : 1.8226, Accuracy: 0.6413
# Test Accuracy: 0.6051
# Average Test Loss : 1.8740
# idx : 0 , Current Loss(batch) : 1.781579852104187, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.7295448780059814, Correct Predictions(batch) : 89/128
# idx : 10 , Current Loss(batch) : 1.8255529403686523, Correct Predictions(batch) : 76/128
# Epoch: 18, Loss (per batch) : 1.8005, Accuracy: 0.6476
# Test Accuracy: 0.6076
# Average Test Loss : 1.8421
# idx : 0 , Current Loss(batch) : 1.741096019744873, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.8200459480285645, Correct Predictions(batch) : 72/128
# idx : 10 , Current Loss(batch) : 1.8089358806610107, Correct Predictions(batch) : 78/128
# Epoch: 19, Loss (per batch) : 1.7777, Accuracy: 0.6529
# Test Accuracy: 0.6102
# Average Test Loss : 1.8264
# idx : 0 , Current Loss(batch) : 1.7698464393615723, Correct Predictions(batch) : 81/128
# idx : 5 , Current Loss(batch) : 1.7269774675369263, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 1.7441399097442627, Correct Predictions(batch) : 88/128
# Epoch: 20, Loss (per batch) : 1.7565, Accuracy: 0.6593
# Test Accuracy: 0.6217
# Average Test Loss : 1.7773
# idx : 0 , Current Loss(batch) : 1.7760521173477173, Correct Predictions(batch) : 79/128
# idx : 5 , Current Loss(batch) : 1.728322982788086, Correct Predictions(batch) : 82/128
# idx : 10 , Current Loss(batch) : 1.6626911163330078, Correct Predictions(batch) : 100/128
# Epoch: 21, Loss (per batch) : 1.7339, Accuracy: 0.6635
# Test Accuracy: 0.6255
# Average Test Loss : 1.7764
# idx : 0 , Current Loss(batch) : 1.67915678024292, Correct Predictions(batch) : 87/128
# idx : 5 , Current Loss(batch) : 1.6748729944229126, Correct Predictions(batch) : 88/128
# idx : 10 , Current Loss(batch) : 1.7798360586166382, Correct Predictions(batch) : 82/128
# Epoch: 22, Loss (per batch) : 1.7130, Accuracy: 0.6688
# Test Accuracy: 0.6344
# Average Test Loss : 1.7609
# idx : 0 , Current Loss(batch) : 1.677643060684204, Correct Predictions(batch) : 92/128
# idx : 5 , Current Loss(batch) : 1.6771777868270874, Correct Predictions(batch) : 90/128
# idx : 10 , Current Loss(batch) : 1.7166783809661865, Correct Predictions(batch) : 85/128
# Epoch: 23, Loss (per batch) : 1.6929, Accuracy: 0.6746
# Test Accuracy: 0.6344
# Average Test Loss : 1.7544
# idx : 0 , Current Loss(batch) : 1.6715929508209229, Correct Predictions(batch) : 92/128
# idx : 5 , Current Loss(batch) : 1.6552560329437256, Correct Predictions(batch) : 91/128
# idx : 10 , Current Loss(batch) : 1.6185979843139648, Correct Predictions(batch) : 99/128
# Epoch: 24, Loss (per batch) : 1.6740, Accuracy: 0.6751
# Test Accuracy: 0.6306
# Average Test Loss : 1.7363
# idx : 0 , Current Loss(batch) : 1.6539554595947266, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 1.649622917175293, Correct Predictions(batch) : 89/128
# idx : 10 , Current Loss(batch) : 1.6498641967773438, Correct Predictions(batch) : 81/128
# Epoch: 25, Loss (per batch) : 1.6539, Accuracy: 0.6793
# Test Accuracy: 0.6357
# Average Test Loss : 1.7175
# idx : 0 , Current Loss(batch) : 1.6269177198410034, Correct Predictions(batch) : 88/128
# idx : 5 , Current Loss(batch) : 1.641204833984375, Correct Predictions(batch) : 88/128
# idx : 10 , Current Loss(batch) : 1.6408348083496094, Correct Predictions(batch) : 86/128
# Epoch: 26, Loss (per batch) : 1.6340, Accuracy: 0.6857
# Test Accuracy: 0.6331
# Average Test Loss : 1.6963
# idx : 0 , Current Loss(batch) : 1.6136677265167236, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.6206895112991333, Correct Predictions(batch) : 88/128
# idx : 10 , Current Loss(batch) : 1.6303542852401733, Correct Predictions(batch) : 91/128
# Epoch: 27, Loss (per batch) : 1.6161, Accuracy: 0.6883
# Test Accuracy: 0.6395
# Average Test Loss : 1.6712
# idx : 0 , Current Loss(batch) : 1.5454281568527222, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 1.5188020467758179, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 1.5570671558380127, Correct Predictions(batch) : 90/128
# Epoch: 28, Loss (per batch) : 1.5994, Accuracy: 0.6920
# Test Accuracy: 0.6382
# Average Test Loss : 1.6912
# idx : 0 , Current Loss(batch) : 1.5838416814804077, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.6211373805999756, Correct Predictions(batch) : 87/128
# idx : 10 , Current Loss(batch) : 1.5989607572555542, Correct Predictions(batch) : 85/128
# Epoch: 29, Loss (per batch) : 1.5808, Accuracy: 0.6973
# Test Accuracy: 0.6382
# Average Test Loss : 1.6443
# idx : 0 , Current Loss(batch) : 1.5421628952026367, Correct Predictions(batch) : 94/128
# idx : 5 , Current Loss(batch) : 1.5892351865768433, Correct Predictions(batch) : 86/128
# idx : 10 , Current Loss(batch) : 1.5348083972930908, Correct Predictions(batch) : 89/128
# Epoch: 30, Loss (per batch) : 1.5632, Accuracy: 0.6978
# Test Accuracy: 0.6395
# Average Test Loss : 1.6461
# idx : 0 , Current Loss(batch) : 1.5444585084915161, Correct Predictions(batch) : 89/128
# idx : 5 , Current Loss(batch) : 1.5564674139022827, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 1.5672892332077026, Correct Predictions(batch) : 88/128
# Epoch: 31, Loss (per batch) : 1.5466, Accuracy: 0.7010
# Test Accuracy: 0.6395
# Average Test Loss : 1.5983
# idx : 0 , Current Loss(batch) : 1.548216462135315, Correct Predictions(batch) : 83/128
# idx : 5 , Current Loss(batch) : 1.5878828763961792, Correct Predictions(batch) : 88/128
# idx : 10 , Current Loss(batch) : 1.4991267919540405, Correct Predictions(batch) : 96/128
# Epoch: 32, Loss (per batch) : 1.5296, Accuracy: 0.7052
# Test Accuracy: 0.6433
# Average Test Loss : 1.6083
# idx : 0 , Current Loss(batch) : 1.5605801343917847, Correct Predictions(batch) : 87/128
# idx : 5 , Current Loss(batch) : 1.5357418060302734, Correct Predictions(batch) : 90/128
# idx : 10 , Current Loss(batch) : 1.497115135192871, Correct Predictions(batch) : 90/128
# Epoch: 33, Loss (per batch) : 1.5132, Accuracy: 0.7063
# Test Accuracy: 0.6459
# Average Test Loss : 1.5915
# idx : 0 , Current Loss(batch) : 1.564644455909729, Correct Predictions(batch) : 86/128
# idx : 5 , Current Loss(batch) : 1.4848557710647583, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 1.4894992113113403, Correct Predictions(batch) : 93/128
# Epoch: 34, Loss (per batch) : 1.4981, Accuracy: 0.7084
# Test Accuracy: 0.6459
# Average Test Loss : 1.5711
# idx : 0 , Current Loss(batch) : 1.3962109088897705, Correct Predictions(batch) : 98/128
# idx : 5 , Current Loss(batch) : 1.5020216703414917, Correct Predictions(batch) : 84/128
# idx : 10 , Current Loss(batch) : 1.4668947458267212, Correct Predictions(batch) : 94/128
# Epoch: 35, Loss (per batch) : 1.4833, Accuracy: 0.7095
# Test Accuracy: 0.6497
# Average Test Loss : 1.5742
# idx : 0 , Current Loss(batch) : 1.4179356098175049, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 1.4485918283462524, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 1.512224555015564, Correct Predictions(batch) : 90/128
# Epoch: 36, Loss (per batch) : 1.4673, Accuracy: 0.7100
# Test Accuracy: 0.6522
# Average Test Loss : 1.5613
# idx : 0 , Current Loss(batch) : 1.4353537559509277, Correct Predictions(batch) : 97/128
# idx : 5 , Current Loss(batch) : 1.4590542316436768, Correct Predictions(batch) : 85/128
# idx : 10 , Current Loss(batch) : 1.3982785940170288, Correct Predictions(batch) : 98/128
# Epoch: 37, Loss (per batch) : 1.4537, Accuracy: 0.7137
# Test Accuracy: 0.6522
# Average Test Loss : 1.5324
# idx : 0 , Current Loss(batch) : 1.4682523012161255, Correct Predictions(batch) : 90/128
# idx : 5 , Current Loss(batch) : 1.4681702852249146, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 1.4615832567214966, Correct Predictions(batch) : 80/128
# Epoch: 38, Loss (per batch) : 1.4381, Accuracy: 0.7153
# Test Accuracy: 0.6497
# Average Test Loss : 1.5294
# idx : 0 , Current Loss(batch) : 1.4066789150238037, Correct Predictions(batch) : 99/128
# idx : 5 , Current Loss(batch) : 1.4591835737228394, Correct Predictions(batch) : 86/128
# idx : 10 , Current Loss(batch) : 1.4752635955810547, Correct Predictions(batch) : 87/128
# Epoch: 39, Loss (per batch) : 1.4253, Accuracy: 0.7179
# Test Accuracy: 0.6522
# Average Test Loss : 1.5195
# idx : 0 , Current Loss(batch) : 1.389939546585083, Correct Predictions(batch) : 93/128
# idx : 5 , Current Loss(batch) : 1.4390761852264404, Correct Predictions(batch) : 82/128
# idx : 10 , Current Loss(batch) : 1.4358408451080322, Correct Predictions(batch) : 91/128
# Epoch: 40, Loss (per batch) : 1.4101, Accuracy: 0.7184
# Test Accuracy: 0.6535
# Average Test Loss : 1.5000
# idx : 0 , Current Loss(batch) : 1.3762893676757812, Correct Predictions(batch) : 94/128
# idx : 5 , Current Loss(batch) : 1.3515037298202515, Correct Predictions(batch) : 95/128
# idx : 10 , Current Loss(batch) : 1.3801642656326294, Correct Predictions(batch) : 92/128
# Epoch: 41, Loss (per batch) : 1.3973, Accuracy: 0.7195
# Test Accuracy: 0.6535
# Average Test Loss : 1.4720
# idx : 0 , Current Loss(batch) : 1.4658944606781006, Correct Predictions(batch) : 88/128
# idx : 5 , Current Loss(batch) : 1.3767961263656616, Correct Predictions(batch) : 92/128
# idx : 10 , Current Loss(batch) : 1.4299079179763794, Correct Predictions(batch) : 87/128
# Epoch: 42, Loss (per batch) : 1.3849, Accuracy: 0.7216
# Test Accuracy: 0.6535
# Average Test Loss : 1.4794
# idx : 0 , Current Loss(batch) : 1.3688474893569946, Correct Predictions(batch) : 95/128
# idx : 5 , Current Loss(batch) : 1.335524320602417, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.390401840209961, Correct Predictions(batch) : 89/128
# Epoch: 43, Loss (per batch) : 1.3712, Accuracy: 0.7227
# Test Accuracy: 0.6561
# Average Test Loss : 1.4499
# idx : 0 , Current Loss(batch) : 1.3409802913665771, Correct Predictions(batch) : 91/128
# idx : 5 , Current Loss(batch) : 1.3570117950439453, Correct Predictions(batch) : 90/128
# idx : 10 , Current Loss(batch) : 1.384497880935669, Correct Predictions(batch) : 89/128
# Epoch: 44, Loss (per batch) : 1.3601, Accuracy: 0.7227
# Test Accuracy: 0.6573
# Average Test Loss : 1.4324
# idx : 0 , Current Loss(batch) : 1.4556964635849, Correct Predictions(batch) : 85/128
# idx : 5 , Current Loss(batch) : 1.4003212451934814, Correct Predictions(batch) : 89/128
# idx : 10 , Current Loss(batch) : 1.2279088497161865, Correct Predictions(batch) : 102/128
# Epoch: 45, Loss (per batch) : 1.3477, Accuracy: 0.7248
# Test Accuracy: 0.6548
# Average Test Loss : 1.4752
# idx : 0 , Current Loss(batch) : 1.3958072662353516, Correct Predictions(batch) : 90/128
# idx : 5 , Current Loss(batch) : 1.3320975303649902, Correct Predictions(batch) : 90/128
# idx : 10 , Current Loss(batch) : 1.3217403888702393, Correct Predictions(batch) : 89/128
# Epoch: 46, Loss (per batch) : 1.3344, Accuracy: 0.7248
# Test Accuracy: 0.6573
# Average Test Loss : 1.4627
# idx : 0 , Current Loss(batch) : 1.402927279472351, Correct Predictions(batch) : 82/128
# idx : 5 , Current Loss(batch) : 1.290658712387085, Correct Predictions(batch) : 97/128
# idx : 10 , Current Loss(batch) : 1.326562523841858, Correct Predictions(batch) : 94/128
# Epoch: 47, Loss (per batch) : 1.3235, Accuracy: 0.7264
# Test Accuracy: 0.6624
# Average Test Loss : 1.4107
# idx : 0 , Current Loss(batch) : 1.2598353624343872, Correct Predictions(batch) : 97/128
# idx : 5 , Current Loss(batch) : 1.285474181175232, Correct Predictions(batch) : 94/128
# idx : 10 , Current Loss(batch) : 1.3509641885757446, Correct Predictions(batch) : 90/128
# Epoch: 48, Loss (per batch) : 1.3133, Accuracy: 0.7269
# Test Accuracy: 0.6611
# Average Test Loss : 1.4183
# idx : 0 , Current Loss(batch) : 1.2352012395858765, Correct Predictions(batch) : 100/128
# idx : 5 , Current Loss(batch) : 1.266287088394165, Correct Predictions(batch) : 93/128
# idx : 10 , Current Loss(batch) : 1.434210181236267, Correct Predictions(batch) : 82/128
# Epoch: 49, Loss (per batch) : 1.3010, Accuracy: 0.7279
# Test Accuracy: 0.6599
# Average Test Loss : 1.4096

# %% [markdown]
# ## VALIDATION ACCURACY : 66.24

# %%
np.save(f'/content/gdrive/MyDrive/imagenette2-320/VIT_weights/a1_v_freeze.npy',a1_v)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/VIT_weights/b1_v_freeze.npy',b1_v)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/VIT_weights/c1_v_freeze.npy',c1_v)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/VIT_weights/d1_v.npy_freeze',d1_v)

# %%
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/a_.npy',a_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/b_.npy',b_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/c_.npy',c_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/d_.npy',d_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/a1_.npy',a1_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/b1_.npy',b1_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/c1_.npy',c1_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/d1_.npy',d1_)

# %%
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/a.npy',a_)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/b.npy',b)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/c.npy',c)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/d.npy',d)

# %%
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/a.npy',a)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/b.npy',b)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/c.npy',c)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/d.npy',d)

# %%
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/a1.npy',a1)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/b1.npy',b1)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/c1.npy',c1)
np.save(f'/content/gdrive/MyDrive/imagenette2-320/Resnet_weights/d1.npy',d1)
